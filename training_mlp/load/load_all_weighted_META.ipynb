# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from math import sqrt
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.cnn import cnn_4layer
from model.mlp import mlp_layer
# Out:
# 2024-01-13 22:02:43.948210: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# import random

# random.seed(10)
# print(random.random())

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data
# Out:
#                            price  price_dayahead  gen_coal  gen_gas
# time
# 2015-01-01 00:00:00+00:00  64.92           48.10    4755.0   5196.0  \
# 2015-01-01 01:00:00+00:00  64.48           47.33    4581.0   4857.0
# 2015-01-01 02:00:00+00:00  59.32           42.27    4131.0   4314.0
# 2015-01-01 03:00:00+00:00  56.04           38.41    3840.0   4130.0
# 2015-01-01 04:00:00+00:00  53.63           35.72    3590.0   4038.0
# ...                          ...             ...       ...      ...
# 2018-12-31 18:00:00+00:00  77.02           68.85    2628.0   7634.0
# 2018-12-31 19:00:00+00:00  76.16           68.40    2566.0   7241.0
# 2018-12-31 20:00:00+00:00  74.30           66.88    2422.0   7025.0
# 2018-12-31 21:00:00+00:00  69.89           63.93    2293.0   6562.0
# 2018-12-31 22:00:00+00:00  69.88           64.27    2166.0   6926.0
#
#                            load_actual  gen_lig  gen_oil  gen_oth_renew
# time
# 2015-01-01 00:00:00+00:00      24382.0    328.0    158.0           71.0  \
# 2015-01-01 01:00:00+00:00      22734.0    323.0    157.0           73.0
# 2015-01-01 02:00:00+00:00      21286.0    254.0    160.0           75.0
# 2015-01-01 03:00:00+00:00      20264.0    187.0    156.0           74.0
# 2015-01-01 04:00:00+00:00      19905.0    178.0    156.0           74.0
# ...                                ...      ...      ...            ...
# 2018-12-31 18:00:00+00:00      30653.0      0.0    178.0           95.0
# 2018-12-31 19:00:00+00:00      29735.0      0.0    174.0           95.0
# 2018-12-31 20:00:00+00:00      28071.0      0.0    168.0           94.0
# 2018-12-31 21:00:00+00:00      25801.0      0.0    163.0           93.0
# 2018-12-31 22:00:00+00:00      24455.0      0.0    163.0           92.0
#
#                            pressure_Barcelona  pressure_Bilbao  ...
# time                                                            ...
# 2015-01-01 00:00:00+00:00              1035.0           1035.0  ...  \
# 2015-01-01 01:00:00+00:00              1036.0           1036.0  ...
# 2015-01-01 02:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 03:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 04:00:00+00:00              1037.0           1035.0  ...
# ...                                       ...              ...  ...
# 2018-12-31 18:00:00+00:00              1027.0           1033.0  ...
# 2018-12-31 19:00:00+00:00              1027.0           1034.0  ...
# 2018-12-31 20:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 21:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 22:00:00+00:00              1028.0           1034.0  ...
#
#                            wind_deg_Bilbao  clouds_all_Bilbao  gen_hyd_river
# time
# 2015-01-01 00:00:00+00:00            229.0                0.0         1009.0  \
# 2015-01-01 01:00:00+00:00            224.0                0.0          973.0
# 2015-01-01 02:00:00+00:00            225.0                0.0          949.0
# 2015-01-01 03:00:00+00:00            221.0                0.0          953.0
# 2015-01-01 04:00:00+00:00            224.0                0.0          952.0
# ...                                    ...                ...            ...
# 2018-12-31 18:00:00+00:00             57.0                0.0         1135.0
# 2018-12-31 19:00:00+00:00              0.0                0.0         1172.0
# 2018-12-31 20:00:00+00:00            140.0                0.0         1148.0
# 2018-12-31 21:00:00+00:00            120.0                0.0         1128.0
# 2018-12-31 22:00:00+00:00            100.0                0.0         1069.0
#
#                            wind_deg_Seville  wind_speed_Barcelona
# time
# 2015-01-01 00:00:00+00:00              21.0                   7.0  \
# 2015-01-01 01:00:00+00:00              27.0                   7.0
# 2015-01-01 02:00:00+00:00              27.0                   7.0
# 2015-01-01 03:00:00+00:00              27.0                   7.0
# 2015-01-01 04:00:00+00:00              57.0                   5.0
# ...                                     ...                   ...
# 2018-12-31 18:00:00+00:00              30.0                   1.0
# 2018-12-31 19:00:00+00:00              30.0                   3.0
# 2018-12-31 20:00:00+00:00              50.0                   4.0
# 2018-12-31 21:00:00+00:00              60.0                   5.0
# 2018-12-31 22:00:00+00:00              50.0                   5.0
#
#                            wind_speed_Valencia  wind_speed_Bilbao  gen_wind
# time
# 2015-01-01 00:00:00+00:00                  1.0                0.0    5890.0  \
# 2015-01-01 01:00:00+00:00                  0.0                1.0    5461.0
# 2015-01-01 02:00:00+00:00                  0.0                1.0    5238.0
# 2015-01-01 03:00:00+00:00                  0.0                1.0    4935.0
# 2015-01-01 04:00:00+00:00                  2.0                1.0    4618.0
# ...                                        ...                ...       ...
# 2018-12-31 18:00:00+00:00                  2.0                0.0    3113.0
# 2018-12-31 19:00:00+00:00                  1.0                1.0    3288.0
# 2018-12-31 20:00:00+00:00                  3.0                1.0    3503.0
# 2018-12-31 21:00:00+00:00                  2.0                1.0    3586.0
# 2018-12-31 22:00:00+00:00                  2.0                2.0    3651.0
#
#                            wind_speed_Madrid  gen_hyd_pump
# time
# 2015-01-01 00:00:00+00:00                1.0         920.0
# 2015-01-01 01:00:00+00:00                1.0        1164.0
# 2015-01-01 02:00:00+00:00                1.0        1503.0
# 2015-01-01 03:00:00+00:00                1.0        1826.0
# 2015-01-01 04:00:00+00:00                0.0        2109.0
# ...                                      ...           ...
# 2018-12-31 18:00:00+00:00                1.0           1.0
# 2018-12-31 19:00:00+00:00                1.0           1.0
# 2018-12-31 20:00:00+00:00                1.0          50.0
# 2018-12-31 21:00:00+00:00                2.0         108.0
# 2018-12-31 22:00:00+00:00                1.0         108.0
#
# [35063 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
# plt.hist(data['pollution'], bins=20)

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 4
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### PM threshold

# %%
train_X_pm = train_X[:, 0, feature_idx]
print(train_X_pm.shape)

val_X_pm = val_X[:, 0, feature_idx]
print(val_X_pm.shape)

test_X_pm = test_X[:, 0, feature_idx]
print(test_X_pm.shape)
# Out:
# (24486,)
# (5247,)
# (5247,)

# %%
percentile = 95

merged_array = np.concatenate((train_X_pm, val_X_pm, test_X_pm))

percentile_pm = np.percentile(merged_array, percentile)

print("{}th Percentile of Daily Rain:".format(percentile), percentile_pm)
# Out:
# 95th Percentile of Daily Rain: 0.793594933402977

# %% [markdown]
# ### train_X_filter

# %%
train_X_extreme = train_X[train_X_pm > percentile_pm]
print(train_X_extreme.shape)

train_y_extreme = train_y[train_X_pm > percentile_pm]
print(train_y_extreme.shape)
# Out:
# (976, 72, 26)
# (976, 12)

# %%
train_X_normal = train_X[train_X_pm <= percentile_pm]
print(train_X_normal.shape)

train_y_normal = train_y[train_X_pm <= percentile_pm]
print(train_y_normal.shape)
# Out:
# (23510, 72, 26)
# (23510, 12)

# %% [markdown]
# ### val_X_filter

# %%
val_X_extreme = val_X[val_X_pm > percentile_pm]
print(val_X_extreme.shape)

val_y_extreme = val_y[val_X_pm > percentile_pm]
print(val_y_extreme.shape)
# Out:
# (501, 72, 26)
# (501, 12)

# %%
val_X_normal = val_X[val_X_pm <= percentile_pm]
print(val_X_normal.shape)

val_y_normal = val_y[val_X_pm <= percentile_pm]
print(val_y_normal.shape)
# Out:
# (4746, 72, 26)
# (4746, 12)

# %% [markdown]
# ### val_X_filter

# %%
train_X_extreme = train_X[train_X_pm > percentile_pm]
print(train_X_extreme.shape)

train_y_extreme = train_y[train_X_pm > percentile_pm]
print(train_y_extreme.shape)
# Out:
# (976, 72, 26)
# (976, 12)

# %%
train_X_normal = train_X[train_X_pm <= percentile_pm]
print(train_X_normal.shape)

train_y_normal = train_y[train_X_pm <= percentile_pm]
print(train_y_normal.shape)
# Out:
# (23510, 72, 26)
# (23510, 12)

# %% [markdown]
# ### test_X_filter

# %%
test_X_extreme = test_X[test_X_pm > percentile_pm]
print(test_X_extreme.shape)

test_y_extreme = test_y[test_X_pm > percentile_pm]
print(test_y_extreme.shape)
# Out:
# (272, 72, 26)
# (272, 12)

# %%
test_X_normal = test_X[test_X_pm <= percentile_pm]
print(test_X_normal.shape)

test_y_normal = test_y[test_X_pm <= percentile_pm]
print(test_y_normal.shape)
# Out:
# (4975, 72, 26)
# (4975, 12)

# %%
# Load your dataset
D_f, y_f = train_X, train_y                # Training data (includes both X_rain and X_norm)
D_g, y_g = val_X_extreme, val_y_extreme    # Validation data (only X_rain)
# D_g, y_g = test_X_extreme, test_y_extreme    # Validation data (only X_rain)

# %%
D_f.shape
# Out:
# (24486, 72, 26)

# %% [markdown]
# ### Model

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0  # 0.1
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )

# %%
# Define the forward function for the model
def forward(model, X, y, weights):
    predictions = model(X, training=True)
    loss = tf.reduce_mean(tf.losses.mean_squared_error(y, predictions) * weights)
    return loss, predictions


def backward(loss):
    # Compute gradients of loss with respect to model parameters
    gradients = tf.gradients(loss, model.trainable_variables)
    return gradients



# Assuming model, D_f, y_f, example_weights, etc. are defined

# Define the loss function
def calculate_loss(model, X, y, weights):
    predictions = model(X)
    individual_losses = tf.losses.mean_squared_error(y, predictions)  # This gives a loss per sample
    weighted_losses = individual_losses * weights
    return tf.reduce_mean(weighted_losses), individual_losses

# %%
# # Define the optimizer for the primary model
# optimizer = Adam(learning_rate=0.01)

# Initialize the example weights wi with ones
# example_weights = tf.ones(shape=(len(D_f)))

sample_weights_IPF = np.load('sample_weights_load_IPF.npy')
example_weights = tf.convert_to_tensor(sample_weights_IPF, dtype=tf.float32)


# Batch size
batch_size = 64

# %%
# Training loop
for t in range(100):  # Number of iterations
    # Shuffle the training data and example weights at the beginning of each epoch
    indices = np.arange(len(D_f))
    #np.random.shuffle(indices)
    D_f_shuffled = tf.gather(D_f, indices)
    y_f_shuffled = tf.gather(y_f, indices)

    
    example_weights_shuffled = tf.gather(example_weights, indices)
    #print("example_weights_shuffled:", example_weights_shuffled.numpy()[:10])
    
    
    # Convert example_weights_shuffled back to a tf.Variable if it's not one after tf.gather
    example_weights_shuffled = tf.Variable(example_weights_shuffled)
    #print("example_weights_shuffled:", example_weights_shuffled.numpy()[:10])

    
    # Iterate over mini-batches
    for i in range(0, len(D_f), batch_size):
        # Slice the mini-batch
        X_batch = D_f_shuffled[i:i+batch_size]
        y_batch = y_f_shuffled[i:i+batch_size]
        w_batch = example_weights_shuffled[i:i+batch_size]

        # Forward pass on the training data with example weights
        with tf.GradientTape() as tape:
            train_loss_f, _ = forward(model, X_batch, y_batch, w_batch)
        gradients_f = tape.gradient(train_loss_f, model.trainable_variables)

        # Apply gradients to update the model parameters
        model.optimizer.apply_gradients(zip(gradients_f, model.trainable_variables))

        
    # After processing all mini-batches, evaluate on validation set
    val_loss_g, val_predictions_g = forward(model, D_g, y_g, tf.ones(shape=(len(D_g), 1)))

    
    # Meta-learning step: Compute the influence of training example weights on validation loss
    with tf.GradientTape() as tape:
        # Re-compute training loss for shuffled data with current model parameters and example weights
        tape.watch(example_weights_shuffled)
        train_loss_f, _ = forward(model, D_f_shuffled, y_f_shuffled, example_weights_shuffled)

        
    # Now compute gradients of this loss w.r.t. the example weights
    example_weight_gradients = tape.gradient(train_loss_f, example_weights_shuffled)
    
    
    # Adjust example weights based on gradients: This is a simplistic approach; actual update rule may differ
    example_weight_updates = -0.001 * example_weight_gradients
    
    
    # Apply updates to the example weights
    example_weights_shuffled.assign_add(example_weight_updates)
    
    # Ensure example_weights remain non-negative and re-normalize
    example_weights_shuffled.assign(tf.maximum(example_weights_shuffled, 0))
    example_weights_shuffled.assign(example_weights_shuffled / tf.reduce_sum(example_weights_shuffled))
    
    
    # Update the original example weights
    indices_matrix = tf.reshape(indices, (len(indices), 1)) 
    example_weights = tf.tensor_scatter_nd_update(example_weights, indices_matrix, example_weights_shuffled)
    #print("example_weights:", example_weights[:3])
    

    
    # Log the progress
    print(f'Epoch {t+1}: Training Loss = {train_loss_f.numpy():.6f}, Validation Loss = {val_loss_g.numpy():.6f} \n')
# Out:
# Epoch 1: Training Loss = 0.002399, Validation Loss = 0.022145
#
# Epoch 2: Training Loss = 0.000001, Validation Loss = 0.021569
#
# Epoch 3: Training Loss = 0.000001, Validation Loss = 0.020952
#
# Epoch 4: Training Loss = 0.000001, Validation Loss = 0.020568
#
# Epoch 5: Training Loss = 0.000001, Validation Loss = 0.020248
#
# Epoch 6: Training Loss = 0.000001, Validation Loss = 0.019951
#
# Epoch 7: Training Loss = 0.000001, Validation Loss = 0.019684
#
# Epoch 8: Training Loss = 0.000001, Validation Loss = 0.019433
#
# Epoch 9: Training Loss = 0.000001, Validation Loss = 0.019202
#
# Epoch 10: Training Loss = 0.000001, Validation Loss = 0.018980
#
# Epoch 11: Training Loss = 0.000001, Validation Loss = 0.018753
#
# Epoch 12: Training Loss = 0.000001, Validation Loss = 0.018513
#
# Epoch 13: Training Loss = 0.000001, Validation Loss = 0.018247
#
# Epoch 14: Training Loss = 0.000001, Validation Loss = 0.017939
#
# Epoch 15: Training Loss = 0.000001, Validation Loss = 0.017575
#
# Epoch 16: Training Loss = 0.000001, Validation Loss = 0.017153
#
# Epoch 17: Training Loss = 0.000001, Validation Loss = 0.016679
#
# Epoch 18: Training Loss = 0.000001, Validation Loss = 0.016148
#
# Epoch 19: Training Loss = 0.000001, Validation Loss = 0.015622
#
# Epoch 20: Training Loss = 0.000001, Validation Loss = 0.015135
#
# Epoch 21: Training Loss = 0.000001, Validation Loss = 0.014634
#
# Epoch 22: Training Loss = 0.000001, Validation Loss = 0.014102
#
# Epoch 23: Training Loss = 0.000001, Validation Loss = 0.013533
#
# Epoch 24: Training Loss = 0.000001, Validation Loss = 0.012975
#
# Epoch 25: Training Loss = 0.000001, Validation Loss = 0.012319
#
# Epoch 26: Training Loss = 0.000001, Validation Loss = 0.011518
#
# Epoch 27: Training Loss = 0.000000, Validation Loss = 0.010811
#
# Epoch 28: Training Loss = 0.000000, Validation Loss = 0.010165
#
# Epoch 29: Training Loss = 0.000000, Validation Loss = 0.009507
#
# Epoch 30: Training Loss = 0.000000, Validation Loss = 0.008823
#
# Epoch 31: Training Loss = 0.000000, Validation Loss = 0.007966
#
# Epoch 32: Training Loss = 0.000000, Validation Loss = 0.007230
#
# Epoch 33: Training Loss = 0.000000, Validation Loss = 0.006917
#
# Epoch 34: Training Loss = 0.000000, Validation Loss = 0.006701
#
# Epoch 35: Training Loss = 0.000000, Validation Loss = 0.006519
#
# Epoch 36: Training Loss = 0.000000, Validation Loss = 0.006458
#
# Epoch 37: Training Loss = 0.000000, Validation Loss = 0.006765
#
# Epoch 38: Training Loss = 0.000000, Validation Loss = 0.007182
#
# Epoch 39: Training Loss = 0.000000, Validation Loss = 0.007663
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 28
#      26 # Forward pass on the training data with example weights
#      27 with tf.GradientTape() as tape:
# ---> 28     train_loss_f, _ = forward(model, X_batch, y_batch, w_batch)
#      29 gradients_f = tape.gradient(train_loss_f, model.trainable_variables)
#      31 # Apply gradients to update the model parameters
#
# Cell In[29], line 3, in forward(model, X, y, weights)
#       2 def forward(model, X, y, weights):
# ----> 3     predictions = model(X, training=True)
#       4     loss = tf.reduce_mean(tf.losses.mean_squared_error(y, predictions) * weights)
#       5     return loss, predictions
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/engine/training.py:557, in Model.__call__(self, *args, **kwargs)
#     553         super().__call__(inputs, *copied_args, **copied_kwargs)
#     555     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 557 return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/engine/base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/engine/functional.py:510, in Functional.call(self, inputs, training, mask)
#     491 @doc_controls.do_not_doc_inheritable
#     492 def call(self, inputs, training=None, mask=None):
#     493     """Calls the model on new inputs.
#     494
#     495     In this case `call` just reapplies
#    (...)
#     508         a list of tensors if there are more than one outputs.
#     509     """
# --> 510     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/engine/functional.py:667, in Functional._run_internal_graph(self, inputs, training, mask)
#     664     continue  # Node is not computable, try skipping.
#     666 args, kwargs = node.map_arguments(tensor_dict)
# --> 667 outputs = node.layer(*args, **kwargs)
#     669 # Update tensor_dict.
#     670 for x_id, y in zip(
#     671     node.flat_output_ids, tf.nest.flatten(outputs)
#     672 ):
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/engine/base_layer.py:1097, in Layer.__call__(self, *args, **kwargs)
#    1092     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1094 with autocast_variable.enable_auto_cast_variables(
#    1095     self._compute_dtype_object
#    1096 ):
# -> 1097     outputs = call_fn(inputs, *args, **kwargs)
#    1099 if self._activity_regularizer:
#    1100     self._handle_activity_regularization(inputs, outputs)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/keras/layers/core/dense.py:244, in Dense.call(self, inputs)
#     241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
# --> 244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#     245     # Reshape the output back to the original ndim of the input.
#     246     if not tf.executing_eagerly():
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/ops/math_ops.py:5131, in tensordot(a, b, axes, name)
#    5129     return ab_matmul
#    5130   else:
# -> 5131     return array_ops.reshape(
#    5132         ab_matmul, a_free_dims + b_free_dims, name=name)
#    5133 else:
#    5134   a_free_dims = ops.convert_to_tensor(a_free_dims, dtype=dtypes.int32)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/ops/array_ops.py:199, in reshape(tensor, shape, name)
#      63 @tf_export("reshape", v1=["reshape", "manip.reshape"])
#      64 @dispatch.add_dispatch_support
#      65 def reshape(tensor, shape, name=None):  # pylint: disable=redefined-outer-name
#      66   r"""Reshapes a tensor.
#      67
#      68   Given `tensor`, this operation returns a new `tf.Tensor` that has the same
#    (...)
#     197     A `Tensor`. Has the same type as `tensor`.
#     198   """
# --> 199   result = gen_array_ops.reshape(tensor, shape, name)
#     200   tensor_util.maybe_set_static_shape(result, shape)
#     201   return result
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:8546, in reshape(tensor, shape, name)
#    8544   pass
#    8545 try:
# -> 8546   return reshape_eager_fallback(
#    8547       tensor, shape, name=name, ctx=_ctx)
#    8548 except _core._SymbolicException:
#    8549   pass  # Add nodes to the TensorFlow graph.
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/ops/gen_array_ops.py:8571, in reshape_eager_fallback(tensor, shape, name, ctx)
#    8569 _inputs_flat = [tensor, shape]
#    8570 _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
# -> 8571 _result = _execute.execute(b"Reshape", 1, inputs=_inputs_flat, attrs=_attrs,
#    8572                            ctx=ctx, name=name)
#    8573 if _execute.must_record_gradient():
#    8574   _execute.record_gradient(
#    8575       "Reshape", _inputs_flat, _attrs, _result)
#
# File ~/miniconda3/envs/flood/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
example_weights = example_weights.numpy()
example_weights /= np.max(example_weights) 
# example_weights = (example_weights - np.min(example_weights)) / (np.max(example_weights) - np.min(example_weights)) + 0.1

# %%
plt.hist(example_weights, bins=20)
# Out:
# (array([21558.,  1669.,   464.,   328.,   288.,     0.,     0.,     0.,
#           105.,     0.,     0.,     0.,     0.,    50.,     0.,     0.,
#             0.,     0.,     0.,    24.]),
#  array([0.10013282, 0.14512618, 0.19011953, 0.23511289, 0.28010625,
#         0.32509962, 0.37009296, 0.41508633, 0.4600797 , 0.50507307,
#         0.55006641, 0.59505975, 0.64005315, 0.68504649, 0.73003983,
#         0.77503318, 0.82002658, 0.86501992, 0.91001326, 0.95500666,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
model.compile(optimizer='adam',
#               loss=[custom_weight_loss],
              loss='mse',
              metrics=['mae']
             )

es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models/load_all_weighted_META.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True,
#                      custom_objects={'custom_weight_loss':custom_weight_loss}
                    )


model.fit(train_X, train_y,
          validation_data=(test_X, test_y),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc],
          sample_weight=example_weights
         )
# Out:
# Epoch 1/1000
#
# Epoch 1: val_mae improved from inf to 0.06589, saving model to ../../saved_models/hydro_all_weighted_META.h5
# 48/48 - 1s - loss: 0.0013 - mae: 0.0775 - val_loss: 0.0078 - val_mae: 0.0659 - 1s/epoch - 26ms/step
# Epoch 2/1000
#
# Epoch 2: val_mae improved from 0.06589 to 0.06310, saving model to ../../saved_models/hydro_all_weighted_META.h5
# 48/48 - 0s - loss: 8.7489e-04 - mae: 0.0609 - val_loss: 0.0072 - val_mae: 0.0631 - 325ms/epoch - 7ms/step
# Epoch 3/1000
#
# Epoch 3: val_mae improved from 0.06310 to 0.06224, saving model to ../../saved_models/hydro_all_weighted_META.h5
# 48/48 - 0s - loss: 8.1917e-04 - mae: 0.0587 - val_loss: 0.0070 - val_mae: 0.0622 - 319ms/epoch - 7ms/step
# Epoch 4/1000
#
# Epoch 4: val_mae improved from 0.06224 to 0.06219, saving model to ../../saved_models/hydro_all_weighted_META.h5
# 48/48 - 0s - loss: 7.8445e-04 - mae: 0.0576 - val_loss: 0.0070 - val_mae: 0.0622 - 323ms/epoch - 7ms/step
# Epoch 5/1000
#
# Epoch 5: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.4700e-04 - mae: 0.0562 - val_loss: 0.0073 - val_mae: 0.0640 - 297ms/epoch - 6ms/step
# Epoch 6/1000
#
# Epoch 6: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.1905e-04 - mae: 0.0552 - val_loss: 0.0071 - val_mae: 0.0623 - 298ms/epoch - 6ms/step
# Epoch 7/1000
#
# Epoch 7: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.9026e-04 - mae: 0.0542 - val_loss: 0.0075 - val_mae: 0.0645 - 296ms/epoch - 6ms/step
# Epoch 8/1000
#
# Epoch 8: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.6348e-04 - mae: 0.0532 - val_loss: 0.0074 - val_mae: 0.0642 - 299ms/epoch - 6ms/step
# Epoch 9/1000
#
# Epoch 9: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.3714e-04 - mae: 0.0523 - val_loss: 0.0076 - val_mae: 0.0651 - 292ms/epoch - 6ms/step
# Epoch 10/1000
#
# Epoch 10: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.1140e-04 - mae: 0.0514 - val_loss: 0.0073 - val_mae: 0.0633 - 296ms/epoch - 6ms/step
# Epoch 11/1000
#
# Epoch 11: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8639e-04 - mae: 0.0503 - val_loss: 0.0078 - val_mae: 0.0661 - 292ms/epoch - 6ms/step
# Epoch 12/1000
#
# Epoch 12: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.6801e-04 - mae: 0.0497 - val_loss: 0.0079 - val_mae: 0.0658 - 297ms/epoch - 6ms/step
# Epoch 13/1000
#
# Epoch 13: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.3825e-04 - mae: 0.0484 - val_loss: 0.0088 - val_mae: 0.0704 - 292ms/epoch - 6ms/step
# Epoch 14/1000
#
# Epoch 14: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.1291e-04 - mae: 0.0474 - val_loss: 0.0083 - val_mae: 0.0673 - 296ms/epoch - 6ms/step
# Epoch 15/1000
#
# Epoch 15: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.9741e-04 - mae: 0.0469 - val_loss: 0.0092 - val_mae: 0.0714 - 296ms/epoch - 6ms/step
# Epoch 16/1000
#
# Epoch 16: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.6776e-04 - mae: 0.0455 - val_loss: 0.0094 - val_mae: 0.0715 - 295ms/epoch - 6ms/step
# Epoch 17/1000
#
# Epoch 17: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.4671e-04 - mae: 0.0445 - val_loss: 0.0095 - val_mae: 0.0716 - 298ms/epoch - 6ms/step
# Epoch 18/1000
#
# Epoch 18: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.3156e-04 - mae: 0.0438 - val_loss: 0.0099 - val_mae: 0.0730 - 297ms/epoch - 6ms/step
# Epoch 19/1000
#
# Epoch 19: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.0801e-04 - mae: 0.0427 - val_loss: 0.0101 - val_mae: 0.0743 - 293ms/epoch - 6ms/step
# Epoch 20/1000
#
# Epoch 20: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.0534e-04 - mae: 0.0427 - val_loss: 0.0103 - val_mae: 0.0751 - 290ms/epoch - 6ms/step
# Epoch 21/1000
#
# Epoch 21: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.7716e-04 - mae: 0.0412 - val_loss: 0.0105 - val_mae: 0.0765 - 293ms/epoch - 6ms/step
# Epoch 22/1000
#
# Epoch 22: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.6133e-04 - mae: 0.0404 - val_loss: 0.0109 - val_mae: 0.0770 - 290ms/epoch - 6ms/step
# Epoch 23/1000
#
# Epoch 23: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.4709e-04 - mae: 0.0397 - val_loss: 0.0115 - val_mae: 0.0799 - 292ms/epoch - 6ms/step
# Epoch 24/1000
#
# Epoch 24: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.4286e-04 - mae: 0.0396 - val_loss: 0.0119 - val_mae: 0.0809 - 291ms/epoch - 6ms/step
# Epoch 25/1000
#
# Epoch 25: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.2543e-04 - mae: 0.0386 - val_loss: 0.0124 - val_mae: 0.0828 - 292ms/epoch - 6ms/step
# Epoch 26/1000
#
# Epoch 26: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 3.0101e-04 - mae: 0.0370 - val_loss: 0.0122 - val_mae: 0.0819 - 291ms/epoch - 6ms/step
# Epoch 27/1000
#
# Epoch 27: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.8662e-04 - mae: 0.0362 - val_loss: 0.0125 - val_mae: 0.0829 - 288ms/epoch - 6ms/step
# Epoch 28/1000
#
# Epoch 28: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.8564e-04 - mae: 0.0362 - val_loss: 0.0132 - val_mae: 0.0854 - 292ms/epoch - 6ms/step
# Epoch 29/1000
#
# Epoch 29: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.7851e-04 - mae: 0.0358 - val_loss: 0.0125 - val_mae: 0.0840 - 291ms/epoch - 6ms/step
# Epoch 30/1000
#
# Epoch 30: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.6645e-04 - mae: 0.0351 - val_loss: 0.0136 - val_mae: 0.0864 - 296ms/epoch - 6ms/step
# Epoch 31/1000
#
# Epoch 31: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.5425e-04 - mae: 0.0342 - val_loss: 0.0130 - val_mae: 0.0854 - 299ms/epoch - 6ms/step
# Epoch 32/1000
#
# Epoch 32: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.4321e-04 - mae: 0.0334 - val_loss: 0.0139 - val_mae: 0.0878 - 293ms/epoch - 6ms/step
# Epoch 33/1000
#
# Epoch 33: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.3932e-04 - mae: 0.0332 - val_loss: 0.0139 - val_mae: 0.0881 - 293ms/epoch - 6ms/step
# Epoch 34/1000
#
# Epoch 34: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.2435e-04 - mae: 0.0322 - val_loss: 0.0141 - val_mae: 0.0887 - 293ms/epoch - 6ms/step
# Epoch 35/1000
#
# Epoch 35: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.1962e-04 - mae: 0.0319 - val_loss: 0.0135 - val_mae: 0.0870 - 297ms/epoch - 6ms/step
# Epoch 36/1000
#
# Epoch 36: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.1295e-04 - mae: 0.0313 - val_loss: 0.0141 - val_mae: 0.0888 - 301ms/epoch - 6ms/step
# Epoch 37/1000
#
# Epoch 37: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.0080e-04 - mae: 0.0304 - val_loss: 0.0148 - val_mae: 0.0909 - 294ms/epoch - 6ms/step
# Epoch 38/1000
#
# Epoch 38: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.9994e-04 - mae: 0.0305 - val_loss: 0.0148 - val_mae: 0.0911 - 290ms/epoch - 6ms/step
# Epoch 39/1000
#
# Epoch 39: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.9117e-04 - mae: 0.0298 - val_loss: 0.0154 - val_mae: 0.0930 - 295ms/epoch - 6ms/step
# Epoch 40/1000
#
# Epoch 40: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 2.0111e-04 - mae: 0.0306 - val_loss: 0.0154 - val_mae: 0.0930 - 295ms/epoch - 6ms/step
# Epoch 41/1000
#
# Epoch 41: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.8451e-04 - mae: 0.0292 - val_loss: 0.0161 - val_mae: 0.0950 - 295ms/epoch - 6ms/step
# Epoch 42/1000
#
# Epoch 42: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.8739e-04 - mae: 0.0295 - val_loss: 0.0154 - val_mae: 0.0932 - 311ms/epoch - 6ms/step
# Epoch 43/1000
#
# Epoch 43: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.7576e-04 - mae: 0.0285 - val_loss: 0.0157 - val_mae: 0.0946 - 301ms/epoch - 6ms/step
# Epoch 44/1000
#
# Epoch 44: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.7429e-04 - mae: 0.0285 - val_loss: 0.0158 - val_mae: 0.0945 - 289ms/epoch - 6ms/step
# Epoch 45/1000
#
# Epoch 45: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.6042e-04 - mae: 0.0273 - val_loss: 0.0159 - val_mae: 0.0954 - 292ms/epoch - 6ms/step
# Epoch 46/1000
#
# Epoch 46: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.6441e-04 - mae: 0.0276 - val_loss: 0.0161 - val_mae: 0.0959 - 292ms/epoch - 6ms/step
# Epoch 47/1000
#
# Epoch 47: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.5316e-04 - mae: 0.0266 - val_loss: 0.0170 - val_mae: 0.0981 - 292ms/epoch - 6ms/step
# Epoch 48/1000
#
# Epoch 48: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.5632e-04 - mae: 0.0270 - val_loss: 0.0164 - val_mae: 0.0966 - 293ms/epoch - 6ms/step
# Epoch 49/1000
#
# Epoch 49: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.4834e-04 - mae: 0.0263 - val_loss: 0.0170 - val_mae: 0.0985 - 290ms/epoch - 6ms/step
# Epoch 50/1000
#
# Epoch 50: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.4604e-04 - mae: 0.0261 - val_loss: 0.0168 - val_mae: 0.0978 - 292ms/epoch - 6ms/step
# Epoch 51/1000
#
# Epoch 51: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.4109e-04 - mae: 0.0256 - val_loss: 0.0167 - val_mae: 0.0981 - 292ms/epoch - 6ms/step
# Epoch 52/1000
#
# Epoch 52: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.3824e-04 - mae: 0.0253 - val_loss: 0.0174 - val_mae: 0.0996 - 292ms/epoch - 6ms/step
# Epoch 53/1000
#
# Epoch 53: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.3509e-04 - mae: 0.0250 - val_loss: 0.0175 - val_mae: 0.0998 - 293ms/epoch - 6ms/step
# Epoch 54/1000
#
# Epoch 54: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.3293e-04 - mae: 0.0249 - val_loss: 0.0175 - val_mae: 0.1000 - 293ms/epoch - 6ms/step
# Epoch 55/1000
#
# Epoch 55: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.4198e-04 - mae: 0.0257 - val_loss: 0.0182 - val_mae: 0.1020 - 294ms/epoch - 6ms/step
# Epoch 56/1000
#
# Epoch 56: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.2519e-04 - mae: 0.0241 - val_loss: 0.0176 - val_mae: 0.1008 - 293ms/epoch - 6ms/step
# Epoch 57/1000
#
# Epoch 57: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.3249e-04 - mae: 0.0248 - val_loss: 0.0179 - val_mae: 0.1016 - 291ms/epoch - 6ms/step
# Epoch 58/1000
#
# Epoch 58: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.2521e-04 - mae: 0.0241 - val_loss: 0.0176 - val_mae: 0.1007 - 294ms/epoch - 6ms/step
# Epoch 59/1000
#
# Epoch 59: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.2333e-04 - mae: 0.0239 - val_loss: 0.0174 - val_mae: 0.1005 - 295ms/epoch - 6ms/step
# Epoch 60/1000
#
# Epoch 60: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1918e-04 - mae: 0.0235 - val_loss: 0.0181 - val_mae: 0.1021 - 296ms/epoch - 6ms/step
# Epoch 61/1000
#
# Epoch 61: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1699e-04 - mae: 0.0233 - val_loss: 0.0185 - val_mae: 0.1028 - 292ms/epoch - 6ms/step
# Epoch 62/1000
#
# Epoch 62: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1847e-04 - mae: 0.0235 - val_loss: 0.0181 - val_mae: 0.1021 - 294ms/epoch - 6ms/step
# Epoch 63/1000
#
# Epoch 63: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1633e-04 - mae: 0.0233 - val_loss: 0.0183 - val_mae: 0.1029 - 295ms/epoch - 6ms/step
# Epoch 64/1000
#
# Epoch 64: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.2028e-04 - mae: 0.0237 - val_loss: 0.0183 - val_mae: 0.1030 - 295ms/epoch - 6ms/step
# Epoch 65/1000
#
# Epoch 65: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1481e-04 - mae: 0.0231 - val_loss: 0.0188 - val_mae: 0.1036 - 294ms/epoch - 6ms/step
# Epoch 66/1000
#
# Epoch 66: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1643e-04 - mae: 0.0232 - val_loss: 0.0187 - val_mae: 0.1040 - 295ms/epoch - 6ms/step
# Epoch 67/1000
#
# Epoch 67: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0846e-04 - mae: 0.0224 - val_loss: 0.0188 - val_mae: 0.1042 - 292ms/epoch - 6ms/step
# Epoch 68/1000
#
# Epoch 68: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1252e-04 - mae: 0.0228 - val_loss: 0.0192 - val_mae: 0.1055 - 291ms/epoch - 6ms/step
# Epoch 69/1000
#
# Epoch 69: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0547e-04 - mae: 0.0221 - val_loss: 0.0191 - val_mae: 0.1053 - 292ms/epoch - 6ms/step
# Epoch 70/1000
#
# Epoch 70: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.1680e-04 - mae: 0.0234 - val_loss: 0.0190 - val_mae: 0.1054 - 295ms/epoch - 6ms/step
# Epoch 71/1000
#
# Epoch 71: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0617e-04 - mae: 0.0222 - val_loss: 0.0187 - val_mae: 0.1043 - 295ms/epoch - 6ms/step
# Epoch 72/1000
#
# Epoch 72: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0131e-04 - mae: 0.0217 - val_loss: 0.0187 - val_mae: 0.1039 - 296ms/epoch - 6ms/step
# Epoch 73/1000
#
# Epoch 73: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0509e-04 - mae: 0.0221 - val_loss: 0.0192 - val_mae: 0.1058 - 293ms/epoch - 6ms/step
# Epoch 74/1000
#
# Epoch 74: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.5653e-05 - mae: 0.0210 - val_loss: 0.0194 - val_mae: 0.1059 - 295ms/epoch - 6ms/step
# Epoch 75/1000
#
# Epoch 75: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.4411e-05 - mae: 0.0209 - val_loss: 0.0198 - val_mae: 0.1073 - 293ms/epoch - 6ms/step
# Epoch 76/1000
#
# Epoch 76: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.3905e-05 - mae: 0.0208 - val_loss: 0.0197 - val_mae: 0.1068 - 296ms/epoch - 6ms/step
# Epoch 77/1000
#
# Epoch 77: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.4194e-05 - mae: 0.0209 - val_loss: 0.0199 - val_mae: 0.1074 - 295ms/epoch - 6ms/step
# Epoch 78/1000
#
# Epoch 78: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.0907e-05 - mae: 0.0205 - val_loss: 0.0196 - val_mae: 0.1069 - 293ms/epoch - 6ms/step
# Epoch 79/1000
#
# Epoch 79: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.7617e-05 - mae: 0.0201 - val_loss: 0.0201 - val_mae: 0.1084 - 295ms/epoch - 6ms/step
# Epoch 80/1000
#
# Epoch 80: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.1579e-05 - mae: 0.0206 - val_loss: 0.0200 - val_mae: 0.1082 - 294ms/epoch - 6ms/step
# Epoch 81/1000
#
# Epoch 81: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.6843e-05 - mae: 0.0212 - val_loss: 0.0197 - val_mae: 0.1073 - 294ms/epoch - 6ms/step
# Epoch 82/1000
#
# Epoch 82: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.7591e-05 - mae: 0.0201 - val_loss: 0.0205 - val_mae: 0.1093 - 294ms/epoch - 6ms/step
# Epoch 83/1000
#
# Epoch 83: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.5984e-05 - mae: 0.0211 - val_loss: 0.0208 - val_mae: 0.1100 - 295ms/epoch - 6ms/step
# Epoch 84/1000
#
# Epoch 84: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.8481e-05 - mae: 0.0202 - val_loss: 0.0203 - val_mae: 0.1087 - 296ms/epoch - 6ms/step
# Epoch 85/1000
#
# Epoch 85: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.8519e-05 - mae: 0.0202 - val_loss: 0.0198 - val_mae: 0.1076 - 290ms/epoch - 6ms/step
# Epoch 86/1000
#
# Epoch 86: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 1.0860e-04 - mae: 0.0226 - val_loss: 0.0195 - val_mae: 0.1066 - 293ms/epoch - 6ms/step
# Epoch 87/1000
#
# Epoch 87: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 9.2074e-05 - mae: 0.0207 - val_loss: 0.0202 - val_mae: 0.1086 - 299ms/epoch - 6ms/step
# Epoch 88/1000
#
# Epoch 88: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.9281e-05 - mae: 0.0203 - val_loss: 0.0197 - val_mae: 0.1074 - 299ms/epoch - 6ms/step
# Epoch 89/1000
#
# Epoch 89: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.2476e-05 - mae: 0.0195 - val_loss: 0.0202 - val_mae: 0.1085 - 296ms/epoch - 6ms/step
# Epoch 90/1000
#
# Epoch 90: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.7940e-05 - mae: 0.0188 - val_loss: 0.0206 - val_mae: 0.1097 - 297ms/epoch - 6ms/step
# Epoch 91/1000
#
# Epoch 91: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.1827e-05 - mae: 0.0194 - val_loss: 0.0207 - val_mae: 0.1097 - 297ms/epoch - 6ms/step
# Epoch 92/1000
#
# Epoch 92: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.1737e-05 - mae: 0.0194 - val_loss: 0.0204 - val_mae: 0.1093 - 299ms/epoch - 6ms/step
# Epoch 93/1000
#
# Epoch 93: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.0844e-05 - mae: 0.0193 - val_loss: 0.0208 - val_mae: 0.1092 - 298ms/epoch - 6ms/step
# Epoch 94/1000
#
# Epoch 94: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.3573e-05 - mae: 0.0196 - val_loss: 0.0209 - val_mae: 0.1101 - 295ms/epoch - 6ms/step
# Epoch 95/1000
#
# Epoch 95: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.0413e-05 - mae: 0.0192 - val_loss: 0.0207 - val_mae: 0.1094 - 294ms/epoch - 6ms/step
# Epoch 96/1000
#
# Epoch 96: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.2653e-05 - mae: 0.0195 - val_loss: 0.0210 - val_mae: 0.1105 - 293ms/epoch - 6ms/step
# Epoch 97/1000
#
# Epoch 97: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.9573e-05 - mae: 0.0191 - val_loss: 0.0209 - val_mae: 0.1101 - 294ms/epoch - 6ms/step
# Epoch 98/1000
#
# Epoch 98: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.0281e-05 - mae: 0.0192 - val_loss: 0.0209 - val_mae: 0.1101 - 296ms/epoch - 6ms/step
# Epoch 99/1000
#
# Epoch 99: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.5058e-05 - mae: 0.0185 - val_loss: 0.0211 - val_mae: 0.1107 - 295ms/epoch - 6ms/step
# Epoch 100/1000
#
# Epoch 100: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.5248e-05 - mae: 0.0186 - val_loss: 0.0213 - val_mae: 0.1114 - 294ms/epoch - 6ms/step
# Epoch 101/1000
#
# Epoch 101: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.7123e-05 - mae: 0.0189 - val_loss: 0.0219 - val_mae: 0.1124 - 303ms/epoch - 6ms/step
# Epoch 102/1000
#
# Epoch 102: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.1328e-05 - mae: 0.0180 - val_loss: 0.0208 - val_mae: 0.1102 - 295ms/epoch - 6ms/step
# Epoch 103/1000
#
# Epoch 103: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.2844e-05 - mae: 0.0196 - val_loss: 0.0207 - val_mae: 0.1101 - 291ms/epoch - 6ms/step
# Epoch 104/1000
#
# Epoch 104: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.8868e-05 - mae: 0.0204 - val_loss: 0.0214 - val_mae: 0.1116 - 293ms/epoch - 6ms/step
# Epoch 105/1000
#
# Epoch 105: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.8830e-05 - mae: 0.0191 - val_loss: 0.0210 - val_mae: 0.1103 - 293ms/epoch - 6ms/step
# Epoch 106/1000
#
# Epoch 106: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.1639e-05 - mae: 0.0181 - val_loss: 0.0215 - val_mae: 0.1116 - 294ms/epoch - 6ms/step
# Epoch 107/1000
#
# Epoch 107: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.2744e-05 - mae: 0.0183 - val_loss: 0.0215 - val_mae: 0.1116 - 292ms/epoch - 6ms/step
# Epoch 108/1000
#
# Epoch 108: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.9488e-05 - mae: 0.0178 - val_loss: 0.0218 - val_mae: 0.1125 - 298ms/epoch - 6ms/step
# Epoch 109/1000
#
# Epoch 109: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.8261e-05 - mae: 0.0177 - val_loss: 0.0223 - val_mae: 0.1135 - 297ms/epoch - 6ms/step
# Epoch 110/1000
#
# Epoch 110: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.0963e-05 - mae: 0.0180 - val_loss: 0.0219 - val_mae: 0.1122 - 298ms/epoch - 6ms/step
# Epoch 111/1000
#
# Epoch 111: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.5082e-05 - mae: 0.0186 - val_loss: 0.0219 - val_mae: 0.1122 - 299ms/epoch - 6ms/step
# Epoch 112/1000
#
# Epoch 112: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.3163e-05 - mae: 0.0183 - val_loss: 0.0221 - val_mae: 0.1129 - 296ms/epoch - 6ms/step
# Epoch 113/1000
#
# Epoch 113: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.6445e-05 - mae: 0.0174 - val_loss: 0.0223 - val_mae: 0.1132 - 295ms/epoch - 6ms/step
# Epoch 114/1000
#
# Epoch 114: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.3539e-05 - mae: 0.0184 - val_loss: 0.0223 - val_mae: 0.1134 - 296ms/epoch - 6ms/step
# Epoch 115/1000
#
# Epoch 115: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.6782e-05 - mae: 0.0188 - val_loss: 0.0217 - val_mae: 0.1121 - 298ms/epoch - 6ms/step
# Epoch 116/1000
#
# Epoch 116: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.6444e-05 - mae: 0.0188 - val_loss: 0.0221 - val_mae: 0.1131 - 296ms/epoch - 6ms/step
# Epoch 117/1000
#
# Epoch 117: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.2805e-05 - mae: 0.0183 - val_loss: 0.0221 - val_mae: 0.1129 - 299ms/epoch - 6ms/step
# Epoch 118/1000
#
# Epoch 118: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.7819e-05 - mae: 0.0176 - val_loss: 0.0225 - val_mae: 0.1137 - 300ms/epoch - 6ms/step
# Epoch 119/1000
#
# Epoch 119: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.3951e-05 - mae: 0.0170 - val_loss: 0.0224 - val_mae: 0.1141 - 297ms/epoch - 6ms/step
# Epoch 120/1000
#
# Epoch 120: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 8.1712e-05 - mae: 0.0195 - val_loss: 0.0229 - val_mae: 0.1154 - 299ms/epoch - 6ms/step
# Epoch 121/1000
#
# Epoch 121: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.4638e-05 - mae: 0.0186 - val_loss: 0.0223 - val_mae: 0.1132 - 296ms/epoch - 6ms/step
# Epoch 122/1000
#
# Epoch 122: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.7059e-05 - mae: 0.0175 - val_loss: 0.0224 - val_mae: 0.1134 - 299ms/epoch - 6ms/step
# Epoch 123/1000
#
# Epoch 123: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.2732e-05 - mae: 0.0169 - val_loss: 0.0224 - val_mae: 0.1134 - 299ms/epoch - 6ms/step
# Epoch 124/1000
#
# Epoch 124: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.4112e-05 - mae: 0.0171 - val_loss: 0.0231 - val_mae: 0.1151 - 298ms/epoch - 6ms/step
# Epoch 125/1000
#
# Epoch 125: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.2653e-05 - mae: 0.0169 - val_loss: 0.0223 - val_mae: 0.1132 - 298ms/epoch - 6ms/step
# Epoch 126/1000
#
# Epoch 126: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.2761e-05 - mae: 0.0169 - val_loss: 0.0223 - val_mae: 0.1134 - 295ms/epoch - 6ms/step
# Epoch 127/1000
#
# Epoch 127: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.2420e-05 - mae: 0.0183 - val_loss: 0.0225 - val_mae: 0.1135 - 296ms/epoch - 6ms/step
# Epoch 128/1000
#
# Epoch 128: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.9744e-05 - mae: 0.0179 - val_loss: 0.0222 - val_mae: 0.1133 - 296ms/epoch - 6ms/step
# Epoch 129/1000
#
# Epoch 129: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.7820e-05 - mae: 0.0176 - val_loss: 0.0227 - val_mae: 0.1146 - 295ms/epoch - 6ms/step
# Epoch 130/1000
#
# Epoch 130: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.3040e-05 - mae: 0.0170 - val_loss: 0.0228 - val_mae: 0.1146 - 300ms/epoch - 6ms/step
# Epoch 131/1000
#
# Epoch 131: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8828e-05 - mae: 0.0163 - val_loss: 0.0228 - val_mae: 0.1147 - 297ms/epoch - 6ms/step
# Epoch 132/1000
#
# Epoch 132: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8068e-05 - mae: 0.0162 - val_loss: 0.0234 - val_mae: 0.1160 - 295ms/epoch - 6ms/step
# Epoch 133/1000
#
# Epoch 133: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.4706e-05 - mae: 0.0172 - val_loss: 0.0238 - val_mae: 0.1168 - 299ms/epoch - 6ms/step
# Epoch 134/1000
#
# Epoch 134: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.4010e-05 - mae: 0.0185 - val_loss: 0.0228 - val_mae: 0.1143 - 296ms/epoch - 6ms/step
# Epoch 135/1000
#
# Epoch 135: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.6967e-05 - mae: 0.0176 - val_loss: 0.0228 - val_mae: 0.1140 - 305ms/epoch - 6ms/step
# Epoch 136/1000
#
# Epoch 136: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8033e-05 - mae: 0.0162 - val_loss: 0.0233 - val_mae: 0.1154 - 296ms/epoch - 6ms/step
# Epoch 137/1000
#
# Epoch 137: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.7959e-05 - mae: 0.0162 - val_loss: 0.0235 - val_mae: 0.1162 - 294ms/epoch - 6ms/step
# Epoch 138/1000
#
# Epoch 138: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.9571e-05 - mae: 0.0164 - val_loss: 0.0227 - val_mae: 0.1141 - 293ms/epoch - 6ms/step
# Epoch 139/1000
#
# Epoch 139: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8159e-05 - mae: 0.0163 - val_loss: 0.0238 - val_mae: 0.1172 - 299ms/epoch - 6ms/step
# Epoch 140/1000
#
# Epoch 140: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.5225e-05 - mae: 0.0173 - val_loss: 0.0234 - val_mae: 0.1164 - 295ms/epoch - 6ms/step
# Epoch 141/1000
#
# Epoch 141: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.6177e-05 - mae: 0.0174 - val_loss: 0.0234 - val_mae: 0.1159 - 296ms/epoch - 6ms/step
# Epoch 142/1000
#
# Epoch 142: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.5680e-05 - mae: 0.0159 - val_loss: 0.0239 - val_mae: 0.1166 - 296ms/epoch - 6ms/step
# Epoch 143/1000
#
# Epoch 143: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.9511e-05 - mae: 0.0179 - val_loss: 0.0231 - val_mae: 0.1149 - 297ms/epoch - 6ms/step
# Epoch 144/1000
#
# Epoch 144: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.4028e-05 - mae: 0.0172 - val_loss: 0.0233 - val_mae: 0.1154 - 294ms/epoch - 6ms/step
# Epoch 145/1000
#
# Epoch 145: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.8452e-05 - mae: 0.0163 - val_loss: 0.0238 - val_mae: 0.1167 - 292ms/epoch - 6ms/step
# Epoch 146/1000
#
# Epoch 146: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.6945e-05 - mae: 0.0161 - val_loss: 0.0237 - val_mae: 0.1164 - 297ms/epoch - 6ms/step
# Epoch 147/1000
#
# Epoch 147: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.4672e-05 - mae: 0.0157 - val_loss: 0.0238 - val_mae: 0.1166 - 297ms/epoch - 6ms/step
# Epoch 148/1000
#
# Epoch 148: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.5729e-05 - mae: 0.0159 - val_loss: 0.0240 - val_mae: 0.1170 - 296ms/epoch - 6ms/step
# Epoch 149/1000
#
# Epoch 149: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.5930e-05 - mae: 0.0159 - val_loss: 0.0243 - val_mae: 0.1180 - 299ms/epoch - 6ms/step
# Epoch 150/1000
#
# Epoch 150: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.4438e-05 - mae: 0.0157 - val_loss: 0.0240 - val_mae: 0.1167 - 295ms/epoch - 6ms/step
# Epoch 151/1000
#
# Epoch 151: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.6279e-05 - mae: 0.0175 - val_loss: 0.0241 - val_mae: 0.1179 - 298ms/epoch - 6ms/step
# Epoch 152/1000
#
# Epoch 152: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.3194e-05 - mae: 0.0185 - val_loss: 0.0238 - val_mae: 0.1164 - 294ms/epoch - 6ms/step
# Epoch 153/1000
#
# Epoch 153: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.7323e-05 - mae: 0.0161 - val_loss: 0.0241 - val_mae: 0.1175 - 294ms/epoch - 6ms/step
# Epoch 154/1000
#
# Epoch 154: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.7817e-05 - mae: 0.0163 - val_loss: 0.0238 - val_mae: 0.1169 - 295ms/epoch - 6ms/step
# Epoch 155/1000
#
# Epoch 155: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.2662e-05 - mae: 0.0154 - val_loss: 0.0243 - val_mae: 0.1180 - 296ms/epoch - 6ms/step
# Epoch 156/1000
#
# Epoch 156: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.3681e-05 - mae: 0.0156 - val_loss: 0.0244 - val_mae: 0.1184 - 293ms/epoch - 6ms/step
# Epoch 157/1000
#
# Epoch 157: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.3774e-05 - mae: 0.0172 - val_loss: 0.0248 - val_mae: 0.1192 - 292ms/epoch - 6ms/step
# Epoch 158/1000
#
# Epoch 158: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.5674e-05 - mae: 0.0159 - val_loss: 0.0241 - val_mae: 0.1175 - 297ms/epoch - 6ms/step
# Epoch 159/1000
#
# Epoch 159: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.3889e-05 - mae: 0.0156 - val_loss: 0.0243 - val_mae: 0.1177 - 300ms/epoch - 6ms/step
# Epoch 160/1000
#
# Epoch 160: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.9374e-05 - mae: 0.0165 - val_loss: 0.0244 - val_mae: 0.1177 - 292ms/epoch - 6ms/step
# Epoch 161/1000
#
# Epoch 161: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.0897e-05 - mae: 0.0167 - val_loss: 0.0245 - val_mae: 0.1179 - 295ms/epoch - 6ms/step
# Epoch 162/1000
#
# Epoch 162: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0308e-05 - mae: 0.0151 - val_loss: 0.0246 - val_mae: 0.1186 - 297ms/epoch - 6ms/step
# Epoch 163/1000
#
# Epoch 163: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.3106e-05 - mae: 0.0155 - val_loss: 0.0251 - val_mae: 0.1194 - 292ms/epoch - 6ms/step
# Epoch 164/1000
#
# Epoch 164: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.0818e-05 - mae: 0.0167 - val_loss: 0.0246 - val_mae: 0.1179 - 290ms/epoch - 6ms/step
# Epoch 165/1000
#
# Epoch 165: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.0267e-05 - mae: 0.0181 - val_loss: 0.0248 - val_mae: 0.1193 - 294ms/epoch - 6ms/step
# Epoch 166/1000
#
# Epoch 166: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.1578e-05 - mae: 0.0153 - val_loss: 0.0249 - val_mae: 0.1191 - 300ms/epoch - 6ms/step
# Epoch 167/1000
#
# Epoch 167: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.7940e-05 - mae: 0.0146 - val_loss: 0.0249 - val_mae: 0.1192 - 299ms/epoch - 6ms/step
# Epoch 168/1000
#
# Epoch 168: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.9431e-05 - mae: 0.0149 - val_loss: 0.0254 - val_mae: 0.1205 - 295ms/epoch - 6ms/step
# Epoch 169/1000
#
# Epoch 169: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0606e-05 - mae: 0.0151 - val_loss: 0.0251 - val_mae: 0.1194 - 296ms/epoch - 6ms/step
# Epoch 170/1000
#
# Epoch 170: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.5393e-05 - mae: 0.0159 - val_loss: 0.0253 - val_mae: 0.1203 - 295ms/epoch - 6ms/step
# Epoch 171/1000
#
# Epoch 171: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0760e-05 - mae: 0.0151 - val_loss: 0.0252 - val_mae: 0.1199 - 297ms/epoch - 6ms/step
# Epoch 172/1000
#
# Epoch 172: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 7.5419e-05 - mae: 0.0187 - val_loss: 0.0252 - val_mae: 0.1201 - 296ms/epoch - 6ms/step
# Epoch 173/1000
#
# Epoch 173: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.4226e-05 - mae: 0.0157 - val_loss: 0.0254 - val_mae: 0.1202 - 301ms/epoch - 6ms/step
# Epoch 174/1000
#
# Epoch 174: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.7985e-05 - mae: 0.0147 - val_loss: 0.0251 - val_mae: 0.1192 - 297ms/epoch - 6ms/step
# Epoch 175/1000
#
# Epoch 175: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.9690e-05 - mae: 0.0150 - val_loss: 0.0255 - val_mae: 0.1204 - 302ms/epoch - 6ms/step
# Epoch 176/1000
#
# Epoch 176: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.5756e-05 - mae: 0.0143 - val_loss: 0.0255 - val_mae: 0.1205 - 298ms/epoch - 6ms/step
# Epoch 177/1000
#
# Epoch 177: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0008e-05 - mae: 0.0150 - val_loss: 0.0257 - val_mae: 0.1208 - 296ms/epoch - 6ms/step
# Epoch 178/1000
#
# Epoch 178: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.1509e-05 - mae: 0.0153 - val_loss: 0.0265 - val_mae: 0.1238 - 294ms/epoch - 6ms/step
# Epoch 179/1000
#
# Epoch 179: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.1102e-05 - mae: 0.0152 - val_loss: 0.0258 - val_mae: 0.1213 - 294ms/epoch - 6ms/step
# Epoch 180/1000
#
# Epoch 180: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.3968e-05 - mae: 0.0140 - val_loss: 0.0258 - val_mae: 0.1212 - 300ms/epoch - 6ms/step
# Epoch 181/1000
#
# Epoch 181: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.8190e-05 - mae: 0.0147 - val_loss: 0.0259 - val_mae: 0.1216 - 298ms/epoch - 6ms/step
# Epoch 182/1000
#
# Epoch 182: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0357e-05 - mae: 0.0151 - val_loss: 0.0258 - val_mae: 0.1211 - 298ms/epoch - 6ms/step
# Epoch 183/1000
#
# Epoch 183: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.4148e-05 - mae: 0.0157 - val_loss: 0.0261 - val_mae: 0.1226 - 297ms/epoch - 6ms/step
# Epoch 184/1000
#
# Epoch 184: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.4767e-05 - mae: 0.0173 - val_loss: 0.0260 - val_mae: 0.1219 - 297ms/epoch - 6ms/step
# Epoch 185/1000
#
# Epoch 185: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0051e-05 - mae: 0.0150 - val_loss: 0.0260 - val_mae: 0.1217 - 298ms/epoch - 6ms/step
# Epoch 186/1000
#
# Epoch 186: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.4600e-05 - mae: 0.0141 - val_loss: 0.0256 - val_mae: 0.1202 - 297ms/epoch - 6ms/step
# Epoch 187/1000
#
# Epoch 187: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.5259e-05 - mae: 0.0142 - val_loss: 0.0260 - val_mae: 0.1216 - 296ms/epoch - 6ms/step
# Epoch 188/1000
#
# Epoch 188: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.4974e-05 - mae: 0.0142 - val_loss: 0.0261 - val_mae: 0.1215 - 297ms/epoch - 6ms/step
# Epoch 189/1000
#
# Epoch 189: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.9638e-05 - mae: 0.0150 - val_loss: 0.0264 - val_mae: 0.1222 - 293ms/epoch - 6ms/step
# Epoch 190/1000
#
# Epoch 190: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.7340e-05 - mae: 0.0162 - val_loss: 0.0259 - val_mae: 0.1215 - 293ms/epoch - 6ms/step
# Epoch 191/1000
#
# Epoch 191: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.6666e-05 - mae: 0.0145 - val_loss: 0.0260 - val_mae: 0.1215 - 296ms/epoch - 6ms/step
# Epoch 192/1000
#
# Epoch 192: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.9272e-05 - mae: 0.0165 - val_loss: 0.0254 - val_mae: 0.1198 - 295ms/epoch - 6ms/step
# Epoch 193/1000
#
# Epoch 193: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.7371e-05 - mae: 0.0162 - val_loss: 0.0264 - val_mae: 0.1235 - 292ms/epoch - 6ms/step
# Epoch 194/1000
#
# Epoch 194: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.7071e-05 - mae: 0.0146 - val_loss: 0.0264 - val_mae: 0.1228 - 290ms/epoch - 6ms/step
# Epoch 195/1000
#
# Epoch 195: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.3969e-05 - mae: 0.0140 - val_loss: 0.0259 - val_mae: 0.1211 - 296ms/epoch - 6ms/step
# Epoch 196/1000
#
# Epoch 196: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.5980e-05 - mae: 0.0144 - val_loss: 0.0261 - val_mae: 0.1220 - 298ms/epoch - 6ms/step
# Epoch 197/1000
#
# Epoch 197: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.1363e-05 - mae: 0.0136 - val_loss: 0.0264 - val_mae: 0.1222 - 298ms/epoch - 6ms/step
# Epoch 198/1000
#
# Epoch 198: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.2622e-05 - mae: 0.0138 - val_loss: 0.0266 - val_mae: 0.1231 - 294ms/epoch - 6ms/step
# Epoch 199/1000
#
# Epoch 199: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.5407e-05 - mae: 0.0143 - val_loss: 0.0267 - val_mae: 0.1231 - 294ms/epoch - 6ms/step
# Epoch 200/1000
#
# Epoch 200: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 6.0358e-05 - mae: 0.0167 - val_loss: 0.0261 - val_mae: 0.1221 - 293ms/epoch - 6ms/step
# Epoch 201/1000
#
# Epoch 201: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 5.0648e-05 - mae: 0.0152 - val_loss: 0.0265 - val_mae: 0.1229 - 294ms/epoch - 6ms/step
# Epoch 202/1000
#
# Epoch 202: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.3238e-05 - mae: 0.0139 - val_loss: 0.0260 - val_mae: 0.1212 - 295ms/epoch - 6ms/step
# Epoch 203/1000
#
# Epoch 203: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.8794e-05 - mae: 0.0149 - val_loss: 0.0265 - val_mae: 0.1227 - 292ms/epoch - 6ms/step
# Epoch 204/1000
#
# Epoch 204: val_mae did not improve from 0.06219
# 48/48 - 0s - loss: 4.2032e-05 - mae: 0.0137 - val_loss: 0.0268 - val_mae: 0.1235 - 295ms/epoch - 6ms/step
# Epoch 204: early stopping
