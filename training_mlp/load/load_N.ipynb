# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from math import sqrt
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.mlp import mlp_layer
# Out:
# 2024-02-02 14:37:54.738053: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# import random

# random.seed(10)
# print(random.random())

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data
# Out:
#                            price  price_dayahead  gen_coal  gen_gas  \
# time
# 2015-01-01 00:00:00+00:00  64.92           48.10    4755.0   5196.0
# 2015-01-01 01:00:00+00:00  64.48           47.33    4581.0   4857.0
# 2015-01-01 02:00:00+00:00  59.32           42.27    4131.0   4314.0
# 2015-01-01 03:00:00+00:00  56.04           38.41    3840.0   4130.0
# 2015-01-01 04:00:00+00:00  53.63           35.72    3590.0   4038.0
# ...                          ...             ...       ...      ...
# 2018-12-31 18:00:00+00:00  77.02           68.85    2628.0   7634.0
# 2018-12-31 19:00:00+00:00  76.16           68.40    2566.0   7241.0
# 2018-12-31 20:00:00+00:00  74.30           66.88    2422.0   7025.0
# 2018-12-31 21:00:00+00:00  69.89           63.93    2293.0   6562.0
# 2018-12-31 22:00:00+00:00  69.88           64.27    2166.0   6926.0
#
#                            load_actual  gen_lig  gen_oil  gen_oth_renew  \
# time
# 2015-01-01 00:00:00+00:00      24382.0    328.0    158.0           71.0
# 2015-01-01 01:00:00+00:00      22734.0    323.0    157.0           73.0
# 2015-01-01 02:00:00+00:00      21286.0    254.0    160.0           75.0
# 2015-01-01 03:00:00+00:00      20264.0    187.0    156.0           74.0
# 2015-01-01 04:00:00+00:00      19905.0    178.0    156.0           74.0
# ...                                ...      ...      ...            ...
# 2018-12-31 18:00:00+00:00      30653.0      0.0    178.0           95.0
# 2018-12-31 19:00:00+00:00      29735.0      0.0    174.0           95.0
# 2018-12-31 20:00:00+00:00      28071.0      0.0    168.0           94.0
# 2018-12-31 21:00:00+00:00      25801.0      0.0    163.0           93.0
# 2018-12-31 22:00:00+00:00      24455.0      0.0    163.0           92.0
#
#                            pressure_Barcelona  pressure_Bilbao  ...  \
# time                                                            ...
# 2015-01-01 00:00:00+00:00              1035.0           1035.0  ...
# 2015-01-01 01:00:00+00:00              1036.0           1036.0  ...
# 2015-01-01 02:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 03:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 04:00:00+00:00              1037.0           1035.0  ...
# ...                                       ...              ...  ...
# 2018-12-31 18:00:00+00:00              1027.0           1033.0  ...
# 2018-12-31 19:00:00+00:00              1027.0           1034.0  ...
# 2018-12-31 20:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 21:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 22:00:00+00:00              1028.0           1034.0  ...
#
#                            wind_deg_Bilbao  clouds_all_Bilbao  gen_hyd_river  \
# time
# 2015-01-01 00:00:00+00:00            229.0                0.0         1009.0
# 2015-01-01 01:00:00+00:00            224.0                0.0          973.0
# 2015-01-01 02:00:00+00:00            225.0                0.0          949.0
# 2015-01-01 03:00:00+00:00            221.0                0.0          953.0
# 2015-01-01 04:00:00+00:00            224.0                0.0          952.0
# ...                                    ...                ...            ...
# 2018-12-31 18:00:00+00:00             57.0                0.0         1135.0
# 2018-12-31 19:00:00+00:00              0.0                0.0         1172.0
# 2018-12-31 20:00:00+00:00            140.0                0.0         1148.0
# 2018-12-31 21:00:00+00:00            120.0                0.0         1128.0
# 2018-12-31 22:00:00+00:00            100.0                0.0         1069.0
#
#                            wind_deg_Seville  wind_speed_Barcelona  \
# time
# 2015-01-01 00:00:00+00:00              21.0                   7.0
# 2015-01-01 01:00:00+00:00              27.0                   7.0
# 2015-01-01 02:00:00+00:00              27.0                   7.0
# 2015-01-01 03:00:00+00:00              27.0                   7.0
# 2015-01-01 04:00:00+00:00              57.0                   5.0
# ...                                     ...                   ...
# 2018-12-31 18:00:00+00:00              30.0                   1.0
# 2018-12-31 19:00:00+00:00              30.0                   3.0
# 2018-12-31 20:00:00+00:00              50.0                   4.0
# 2018-12-31 21:00:00+00:00              60.0                   5.0
# 2018-12-31 22:00:00+00:00              50.0                   5.0
#
#                            wind_speed_Valencia  wind_speed_Bilbao  gen_wind  \
# time
# 2015-01-01 00:00:00+00:00                  1.0                0.0    5890.0
# 2015-01-01 01:00:00+00:00                  0.0                1.0    5461.0
# 2015-01-01 02:00:00+00:00                  0.0                1.0    5238.0
# 2015-01-01 03:00:00+00:00                  0.0                1.0    4935.0
# 2015-01-01 04:00:00+00:00                  2.0                1.0    4618.0
# ...                                        ...                ...       ...
# 2018-12-31 18:00:00+00:00                  2.0                0.0    3113.0
# 2018-12-31 19:00:00+00:00                  1.0                1.0    3288.0
# 2018-12-31 20:00:00+00:00                  3.0                1.0    3503.0
# 2018-12-31 21:00:00+00:00                  2.0                1.0    3586.0
# 2018-12-31 22:00:00+00:00                  2.0                2.0    3651.0
#
#                            wind_speed_Madrid  gen_hyd_pump
# time
# 2015-01-01 00:00:00+00:00                1.0         920.0
# 2015-01-01 01:00:00+00:00                1.0        1164.0
# 2015-01-01 02:00:00+00:00                1.0        1503.0
# 2015-01-01 03:00:00+00:00                1.0        1826.0
# 2015-01-01 04:00:00+00:00                0.0        2109.0
# ...                                      ...           ...
# 2018-12-31 18:00:00+00:00                1.0           1.0
# 2018-12-31 19:00:00+00:00                1.0           1.0
# 2018-12-31 20:00:00+00:00                1.0          50.0
# 2018-12-31 21:00:00+00:00                2.0         108.0
# 2018-12-31 22:00:00+00:00                1.0         108.0
#
# [35063 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
print(data['load_actual'].min())
print(data['load_actual'].max())
# Out:
# 18041.0
# 41015.0

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
# for col in data.columns:
#     plt.hist(data[col], bins=20)
#     plt.title(col)
#     plt.show()
#     plt.close()

# %%
np.percentile(data['gen_gas'], 95)
# Out:
# 10259.0

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 4
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### Load threshold

# %%
train_X_pm = train_X[:, 0, feature_idx]
print(train_X_pm.shape)

val_X_pm = val_X[:, 0, feature_idx]
print(val_X_pm.shape)

test_X_pm = test_X[:, 0, feature_idx]
print(test_X_pm.shape)
# Out:
# (24486,)
# (5247,)
# (5247,)

# %%
percentile = 95

merged_array = np.concatenate((train_X_pm, val_X_pm, test_X_pm))

percentile_pm = np.percentile(merged_array, percentile)

print("{}th Percentile of Daily Rain:".format(percentile), percentile_pm)
# Out:
# 95th Percentile of Daily Rain: 0.793594933402977

# %% [markdown]
# ### train_X_filter

# %%
train_X_extreme = train_X[train_X_pm > percentile_pm]
print(train_X_extreme.shape)

train_y_extreme = train_y[train_X_pm > percentile_pm]
print(train_y_extreme.shape)
# Out:
# (976, 72, 26)
# (976, 12)

# %%
train_X_normal = train_X[train_X_pm <= percentile_pm]
print(train_X_normal.shape)

train_y_normal = train_y[train_X_pm <= percentile_pm]
print(train_y_normal.shape)
# Out:
# (23510, 72, 26)
# (23510, 12)

# %% [markdown]
# ### val_X_filter

# %%
val_X_extreme = val_X[val_X_pm > percentile_pm]
print(val_X_extreme.shape)

val_y_extreme = val_y[val_X_pm > percentile_pm]
print(val_y_extreme.shape)
# Out:
# (501, 72, 26)
# (501, 12)

# %%
val_X_normal = val_X[val_X_pm <= percentile_pm]
print(val_X_normal.shape)

val_y_normal = val_y[val_X_pm <= percentile_pm]
print(val_y_normal.shape)
# Out:
# (4746, 72, 26)
# (4746, 12)

# %% [markdown]
# ### test_X_filter

# %%
test_X_extreme = test_X[test_X_pm > percentile_pm]
print(test_X_extreme.shape)

test_y_extreme = test_y[test_X_pm > percentile_pm]
print(test_y_extreme.shape)
# Out:
# (272, 72, 26)
# (272, 12)

# %%
test_X_normal = test_X[test_X_pm <= percentile_pm]
print(test_X_normal.shape)

test_y_normal = test_y[test_X_pm <= percentile_pm]
print(test_y_normal.shape)
# Out:
# (4975, 72, 26)
# (4975, 12)

# %% [markdown]
# ### Model & training

# %%
# plt.hist(train_y[:,0])

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0.0  # 0.1
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

# %%
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
#                                                           decay_steps=decay_steps,
#                                                           decay_rate=decay_rate)

# model.compile(optimizer=Adam(learning_rate=lr_schedule),
#               loss='mse',
#               metrics=['mae']
#              )

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )


es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models_mlp/load_N.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True
                    )


model.fit(train_X_normal, train_y_normal,
          validation_data=(val_X_normal, val_y_normal),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc]
         )
# Out:
# Epoch 1/1000
# 46/46 - 2s - loss: 0.0611 - mae: 0.2000 - val_loss: 0.0483 - val_mae: 0.1878
#
# Epoch 00001: val_mae improved from inf to 0.18777, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 2/1000
# 46/46 - 1s - loss: 0.0303 - mae: 0.1448 - val_loss: 0.0287 - val_mae: 0.1379
#
# Epoch 00002: val_mae improved from 0.18777 to 0.13794, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 3/1000
# 46/46 - 1s - loss: 0.0175 - mae: 0.1041 - val_loss: 0.0175 - val_mae: 0.1025
#
# Epoch 00003: val_mae improved from 0.13794 to 0.10245, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 4/1000
# 46/46 - 1s - loss: 0.0127 - mae: 0.0868 - val_loss: 0.0162 - val_mae: 0.0968
#
# Epoch 00004: val_mae improved from 0.10245 to 0.09679, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 5/1000
# 46/46 - 1s - loss: 0.0113 - mae: 0.0814 - val_loss: 0.0149 - val_mae: 0.0931
#
# Epoch 00005: val_mae improved from 0.09679 to 0.09311, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 6/1000
# 46/46 - 1s - loss: 0.0102 - mae: 0.0769 - val_loss: 0.0146 - val_mae: 0.0911
#
# Epoch 00006: val_mae improved from 0.09311 to 0.09107, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 7/1000
# 46/46 - 1s - loss: 0.0094 - mae: 0.0734 - val_loss: 0.0136 - val_mae: 0.0886
#
# Epoch 00007: val_mae improved from 0.09107 to 0.08861, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 8/1000
# 46/46 - 1s - loss: 0.0086 - mae: 0.0699 - val_loss: 0.0134 - val_mae: 0.0886
#
# Epoch 00008: val_mae improved from 0.08861 to 0.08858, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 9/1000
# 46/46 - 1s - loss: 0.0078 - mae: 0.0666 - val_loss: 0.0119 - val_mae: 0.0817
#
# Epoch 00009: val_mae improved from 0.08858 to 0.08174, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 10/1000
# 46/46 - 1s - loss: 0.0067 - mae: 0.0607 - val_loss: 0.0115 - val_mae: 0.0812
#
# Epoch 00010: val_mae improved from 0.08174 to 0.08117, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 11/1000
# 46/46 - 1s - loss: 0.0060 - mae: 0.0579 - val_loss: 0.0108 - val_mae: 0.0776
#
# Epoch 00011: val_mae improved from 0.08117 to 0.07759, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 12/1000
# 46/46 - 1s - loss: 0.0055 - mae: 0.0552 - val_loss: 0.0109 - val_mae: 0.0781
#
# Epoch 00012: val_mae did not improve from 0.07759
# Epoch 13/1000
# 46/46 - 1s - loss: 0.0052 - mae: 0.0538 - val_loss: 0.0108 - val_mae: 0.0775
#
# Epoch 00013: val_mae improved from 0.07759 to 0.07752, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 14/1000
# 46/46 - 1s - loss: 0.0049 - mae: 0.0519 - val_loss: 0.0109 - val_mae: 0.0775
#
# Epoch 00014: val_mae improved from 0.07752 to 0.07747, saving model to ../../saved_models_mlp/load_N.h5
# Epoch 15/1000
# 46/46 - 1s - loss: 0.0046 - mae: 0.0506 - val_loss: 0.0111 - val_mae: 0.0783
#
# Epoch 00015: val_mae did not improve from 0.07747
# Epoch 16/1000
# 46/46 - 1s - loss: 0.0044 - mae: 0.0497 - val_loss: 0.0115 - val_mae: 0.0797
#
# Epoch 00016: val_mae did not improve from 0.07747
# Epoch 17/1000
# 46/46 - 1s - loss: 0.0041 - mae: 0.0482 - val_loss: 0.0116 - val_mae: 0.0797
#
# Epoch 00017: val_mae did not improve from 0.07747
# Epoch 18/1000
# 46/46 - 1s - loss: 0.0040 - mae: 0.0475 - val_loss: 0.0127 - val_mae: 0.0833
#
# Epoch 00018: val_mae did not improve from 0.07747
# Epoch 19/1000
# 46/46 - 1s - loss: 0.0038 - mae: 0.0463 - val_loss: 0.0122 - val_mae: 0.0818
#
# Epoch 00019: val_mae did not improve from 0.07747
# Epoch 20/1000
# 46/46 - 1s - loss: 0.0037 - mae: 0.0458 - val_loss: 0.0130 - val_mae: 0.0857
#
# Epoch 00020: val_mae did not improve from 0.07747
# Epoch 21/1000
# 46/46 - 1s - loss: 0.0035 - mae: 0.0445 - val_loss: 0.0126 - val_mae: 0.0829
#
# Epoch 00021: val_mae did not improve from 0.07747
# Epoch 22/1000
# 46/46 - 1s - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0130 - val_mae: 0.0844
#
# Epoch 00022: val_mae did not improve from 0.07747
# Epoch 23/1000
# 46/46 - 1s - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0128 - val_mae: 0.0839
#
# Epoch 00023: val_mae did not improve from 0.07747
# Epoch 24/1000
# 46/46 - 1s - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0135 - val_mae: 0.0855
#
# Epoch 00024: val_mae did not improve from 0.07747
# Epoch 25/1000
# 46/46 - 1s - loss: 0.0029 - mae: 0.0409 - val_loss: 0.0145 - val_mae: 0.0891
#
# Epoch 00025: val_mae did not improve from 0.07747
# Epoch 26/1000
# 46/46 - 1s - loss: 0.0027 - mae: 0.0399 - val_loss: 0.0141 - val_mae: 0.0873
#
# Epoch 00026: val_mae did not improve from 0.07747
# Epoch 27/1000
# 46/46 - 1s - loss: 0.0027 - mae: 0.0393 - val_loss: 0.0142 - val_mae: 0.0877
#
# Epoch 00027: val_mae did not improve from 0.07747
# Epoch 28/1000
# 46/46 - 1s - loss: 0.0027 - mae: 0.0395 - val_loss: 0.0148 - val_mae: 0.0900
#
# Epoch 00028: val_mae did not improve from 0.07747
# Epoch 29/1000
# 46/46 - 1s - loss: 0.0025 - mae: 0.0380 - val_loss: 0.0149 - val_mae: 0.0900
#
# Epoch 00029: val_mae did not improve from 0.07747
# Epoch 30/1000
# 46/46 - 1s - loss: 0.0024 - mae: 0.0372 - val_loss: 0.0154 - val_mae: 0.0922
#
# Epoch 00030: val_mae did not improve from 0.07747
# Epoch 31/1000
# 46/46 - 1s - loss: 0.0023 - mae: 0.0366 - val_loss: 0.0158 - val_mae: 0.0928
#
# Epoch 00031: val_mae did not improve from 0.07747
# Epoch 32/1000
# 46/46 - 1s - loss: 0.0023 - mae: 0.0369 - val_loss: 0.0154 - val_mae: 0.0914
#
# Epoch 00032: val_mae did not improve from 0.07747
# Epoch 33/1000
# 46/46 - 1s - loss: 0.0024 - mae: 0.0376 - val_loss: 0.0153 - val_mae: 0.0916
#
# Epoch 00033: val_mae did not improve from 0.07747
# Epoch 34/1000
# 46/46 - 1s - loss: 0.0021 - mae: 0.0352 - val_loss: 0.0154 - val_mae: 0.0913
#
# Epoch 00034: val_mae did not improve from 0.07747
# Epoch 35/1000
# 46/46 - 1s - loss: 0.0021 - mae: 0.0350 - val_loss: 0.0166 - val_mae: 0.0956
#
# Epoch 00035: val_mae did not improve from 0.07747
# Epoch 36/1000
# 46/46 - 1s - loss: 0.0020 - mae: 0.0341 - val_loss: 0.0166 - val_mae: 0.0948
#
# Epoch 00036: val_mae did not improve from 0.07747
# Epoch 37/1000
# 46/46 - 1s - loss: 0.0020 - mae: 0.0339 - val_loss: 0.0164 - val_mae: 0.0943
#
# Epoch 00037: val_mae did not improve from 0.07747
# Epoch 38/1000
# 46/46 - 1s - loss: 0.0019 - mae: 0.0338 - val_loss: 0.0176 - val_mae: 0.0987
#
# Epoch 00038: val_mae did not improve from 0.07747
# Epoch 39/1000
# 46/46 - 1s - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0173 - val_mae: 0.0974
#
# Epoch 00039: val_mae did not improve from 0.07747
# Epoch 40/1000
# 46/46 - 1s - loss: 0.0018 - mae: 0.0321 - val_loss: 0.0176 - val_mae: 0.0980
#
# Epoch 00040: val_mae did not improve from 0.07747
# Epoch 41/1000
# 46/46 - 1s - loss: 0.0017 - mae: 0.0319 - val_loss: 0.0172 - val_mae: 0.0964
#
# Epoch 00041: val_mae did not improve from 0.07747
# Epoch 42/1000
# 46/46 - 1s - loss: 0.0017 - mae: 0.0321 - val_loss: 0.0175 - val_mae: 0.0973
#
# Epoch 00042: val_mae did not improve from 0.07747
# Epoch 43/1000
# 46/46 - 1s - loss: 0.0016 - mae: 0.0306 - val_loss: 0.0174 - val_mae: 0.0973
#
# Epoch 00043: val_mae did not improve from 0.07747
# Epoch 44/1000
# 46/46 - 1s - loss: 0.0015 - mae: 0.0301 - val_loss: 0.0182 - val_mae: 0.0996
#
# Epoch 00044: val_mae did not improve from 0.07747
# Epoch 45/1000
# 46/46 - 1s - loss: 0.0015 - mae: 0.0295 - val_loss: 0.0186 - val_mae: 0.1003
#
# Epoch 00045: val_mae did not improve from 0.07747
# Epoch 46/1000
# 46/46 - 1s - loss: 0.0015 - mae: 0.0292 - val_loss: 0.0185 - val_mae: 0.1002
#
# Epoch 00046: val_mae did not improve from 0.07747
# Epoch 47/1000
# 46/46 - 1s - loss: 0.0014 - mae: 0.0288 - val_loss: 0.0188 - val_mae: 0.1014
#
# Epoch 00047: val_mae did not improve from 0.07747
# Epoch 48/1000
# 46/46 - 1s - loss: 0.0014 - mae: 0.0288 - val_loss: 0.0195 - val_mae: 0.1030
#
# Epoch 00048: val_mae did not improve from 0.07747
# Epoch 49/1000
# 46/46 - 1s - loss: 0.0014 - mae: 0.0287 - val_loss: 0.0191 - val_mae: 0.1016
#
# Epoch 00049: val_mae did not improve from 0.07747
# Epoch 50/1000
# 46/46 - 1s - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0184 - val_mae: 0.1000
#
# Epoch 00050: val_mae did not improve from 0.07747
# Epoch 51/1000
# 46/46 - 1s - loss: 0.0013 - mae: 0.0275 - val_loss: 0.0194 - val_mae: 0.1028
#
# Epoch 00051: val_mae did not improve from 0.07747
# Epoch 52/1000
# 46/46 - 1s - loss: 0.0013 - mae: 0.0272 - val_loss: 0.0190 - val_mae: 0.1012
#
# Epoch 00052: val_mae did not improve from 0.07747
# Epoch 53/1000
# 46/46 - 1s - loss: 0.0012 - mae: 0.0268 - val_loss: 0.0193 - val_mae: 0.1026
#
# Epoch 00053: val_mae did not improve from 0.07747
# Epoch 54/1000
# 46/46 - 1s - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0196 - val_mae: 0.1027
#
# Epoch 00054: val_mae did not improve from 0.07747
# Epoch 55/1000
# 46/46 - 1s - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0198 - val_mae: 0.1036
#
# Epoch 00055: val_mae did not improve from 0.07747
# Epoch 56/1000
# 46/46 - 1s - loss: 0.0013 - mae: 0.0279 - val_loss: 0.0201 - val_mae: 0.1053
#
# Epoch 00056: val_mae did not improve from 0.07747
# Epoch 57/1000
# 46/46 - 1s - loss: 0.0012 - mae: 0.0263 - val_loss: 0.0203 - val_mae: 0.1054
#
# Epoch 00057: val_mae did not improve from 0.07747
# Epoch 58/1000
# 46/46 - 1s - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0207 - val_mae: 0.1064
#
# Epoch 00058: val_mae did not improve from 0.07747
# Epoch 59/1000
# 46/46 - 1s - loss: 0.0011 - mae: 0.0249 - val_loss: 0.0205 - val_mae: 0.1060
#
# Epoch 00059: val_mae did not improve from 0.07747
# Epoch 60/1000
# 46/46 - 1s - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0208 - val_mae: 0.1072
#
# Epoch 00060: val_mae did not improve from 0.07747
# Epoch 61/1000
# 46/46 - 1s - loss: 0.0011 - mae: 0.0248 - val_loss: 0.0209 - val_mae: 0.1074
#
# Epoch 00061: val_mae did not improve from 0.07747
# Epoch 62/1000
# 46/46 - 1s - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0205 - val_mae: 0.1064
#
# Epoch 00062: val_mae did not improve from 0.07747
# Epoch 63/1000
# 46/46 - 1s - loss: 0.0010 - mae: 0.0244 - val_loss: 0.0209 - val_mae: 0.1072
#
# Epoch 00063: val_mae did not improve from 0.07747
# Epoch 64/1000
# 46/46 - 1s - loss: 0.0010 - mae: 0.0243 - val_loss: 0.0206 - val_mae: 0.1067
#
# Epoch 00064: val_mae did not improve from 0.07747
# Epoch 65/1000
# 46/46 - 1s - loss: 9.8929e-04 - mae: 0.0240 - val_loss: 0.0212 - val_mae: 0.1081
#
# Epoch 00065: val_mae did not improve from 0.07747
# Epoch 66/1000
# 46/46 - 1s - loss: 0.0010 - mae: 0.0242 - val_loss: 0.0211 - val_mae: 0.1080
#
# Epoch 00066: val_mae did not improve from 0.07747
# Epoch 67/1000
# 46/46 - 1s - loss: 0.0010 - mae: 0.0244 - val_loss: 0.0215 - val_mae: 0.1089
#
# Epoch 00067: val_mae did not improve from 0.07747
# Epoch 68/1000
# 46/46 - 1s - loss: 9.6316e-04 - mae: 0.0237 - val_loss: 0.0218 - val_mae: 0.1099
#
# Epoch 00068: val_mae did not improve from 0.07747
# Epoch 69/1000
# 46/46 - 1s - loss: 9.1163e-04 - mae: 0.0230 - val_loss: 0.0214 - val_mae: 0.1092
#
# Epoch 00069: val_mae did not improve from 0.07747
# Epoch 70/1000
# 46/46 - 1s - loss: 8.7791e-04 - mae: 0.0225 - val_loss: 0.0221 - val_mae: 0.1109
#
# Epoch 00070: val_mae did not improve from 0.07747
# Epoch 71/1000
# 46/46 - 1s - loss: 9.4584e-04 - mae: 0.0235 - val_loss: 0.0216 - val_mae: 0.1094
#
# Epoch 00071: val_mae did not improve from 0.07747
# Epoch 72/1000
# 46/46 - 1s - loss: 9.3992e-04 - mae: 0.0234 - val_loss: 0.0221 - val_mae: 0.1112
#
# Epoch 00072: val_mae did not improve from 0.07747
# Epoch 73/1000
# 46/46 - 1s - loss: 8.9131e-04 - mae: 0.0227 - val_loss: 0.0222 - val_mae: 0.1113
#
# Epoch 00073: val_mae did not improve from 0.07747
# Epoch 74/1000
# 46/46 - 1s - loss: 8.6745e-04 - mae: 0.0224 - val_loss: 0.0227 - val_mae: 0.1124
#
# Epoch 00074: val_mae did not improve from 0.07747
# Epoch 75/1000
# 46/46 - 1s - loss: 8.5072e-04 - mae: 0.0222 - val_loss: 0.0222 - val_mae: 0.1113
#
# Epoch 00075: val_mae did not improve from 0.07747
# Epoch 76/1000
# 46/46 - 1s - loss: 8.4277e-04 - mae: 0.0221 - val_loss: 0.0226 - val_mae: 0.1127
#
# Epoch 00076: val_mae did not improve from 0.07747
# Epoch 77/1000
# 46/46 - 1s - loss: 8.9577e-04 - mae: 0.0229 - val_loss: 0.0218 - val_mae: 0.1103
#
# Epoch 00077: val_mae did not improve from 0.07747
# Epoch 78/1000
# 46/46 - 1s - loss: 9.0815e-04 - mae: 0.0231 - val_loss: 0.0225 - val_mae: 0.1124
#
# Epoch 00078: val_mae did not improve from 0.07747
# Epoch 79/1000
# 46/46 - 1s - loss: 8.1991e-04 - mae: 0.0218 - val_loss: 0.0228 - val_mae: 0.1132
#
# Epoch 00079: val_mae did not improve from 0.07747
# Epoch 80/1000
# 46/46 - 1s - loss: 7.7966e-04 - mae: 0.0212 - val_loss: 0.0227 - val_mae: 0.1129
#
# Epoch 00080: val_mae did not improve from 0.07747
# Epoch 81/1000
# 46/46 - 1s - loss: 7.9537e-04 - mae: 0.0214 - val_loss: 0.0234 - val_mae: 0.1153
#
# Epoch 00081: val_mae did not improve from 0.07747
# Epoch 82/1000
# 46/46 - 1s - loss: 8.2386e-04 - mae: 0.0219 - val_loss: 0.0229 - val_mae: 0.1135
#
# Epoch 00082: val_mae did not improve from 0.07747
# Epoch 83/1000
# 46/46 - 1s - loss: 7.4836e-04 - mae: 0.0207 - val_loss: 0.0228 - val_mae: 0.1134
#
# Epoch 00083: val_mae did not improve from 0.07747
# Epoch 84/1000
# 46/46 - 1s - loss: 7.3485e-04 - mae: 0.0205 - val_loss: 0.0233 - val_mae: 0.1148
#
# Epoch 00084: val_mae did not improve from 0.07747
# Epoch 85/1000
# 46/46 - 1s - loss: 7.5860e-04 - mae: 0.0209 - val_loss: 0.0233 - val_mae: 0.1146
#
# Epoch 00085: val_mae did not improve from 0.07747
# Epoch 86/1000
# 46/46 - 1s - loss: 7.6601e-04 - mae: 0.0210 - val_loss: 0.0233 - val_mae: 0.1150
#
# Epoch 00086: val_mae did not improve from 0.07747
# Epoch 87/1000
# 46/46 - 1s - loss: 8.2415e-04 - mae: 0.0220 - val_loss: 0.0229 - val_mae: 0.1136
#
# Epoch 00087: val_mae did not improve from 0.07747
# Epoch 88/1000
# 46/46 - 1s - loss: 7.3452e-04 - mae: 0.0205 - val_loss: 0.0232 - val_mae: 0.1142
#
# Epoch 00088: val_mae did not improve from 0.07747
# Epoch 89/1000
# 46/46 - 1s - loss: 7.4899e-04 - mae: 0.0208 - val_loss: 0.0232 - val_mae: 0.1145
#
# Epoch 00089: val_mae did not improve from 0.07747
# Epoch 90/1000
# 46/46 - 1s - loss: 7.1036e-04 - mae: 0.0202 - val_loss: 0.0235 - val_mae: 0.1153
#
# Epoch 00090: val_mae did not improve from 0.07747
# Epoch 91/1000
# 46/46 - 1s - loss: 6.9122e-04 - mae: 0.0199 - val_loss: 0.0238 - val_mae: 0.1166
#
# Epoch 00091: val_mae did not improve from 0.07747
# Epoch 92/1000
# 46/46 - 1s - loss: 7.2504e-04 - mae: 0.0204 - val_loss: 0.0237 - val_mae: 0.1158
#
# Epoch 00092: val_mae did not improve from 0.07747
# Epoch 93/1000
# 46/46 - 1s - loss: 7.8701e-04 - mae: 0.0214 - val_loss: 0.0235 - val_mae: 0.1161
#
# Epoch 00093: val_mae did not improve from 0.07747
# Epoch 94/1000
# 46/46 - 1s - loss: 7.0826e-04 - mae: 0.0202 - val_loss: 0.0238 - val_mae: 0.1167
#
# Epoch 00094: val_mae did not improve from 0.07747
# Epoch 95/1000
# 46/46 - 1s - loss: 6.6597e-04 - mae: 0.0195 - val_loss: 0.0244 - val_mae: 0.1182
#
# Epoch 00095: val_mae did not improve from 0.07747
# Epoch 96/1000
# 46/46 - 1s - loss: 6.6333e-04 - mae: 0.0195 - val_loss: 0.0244 - val_mae: 0.1188
#
# Epoch 00096: val_mae did not improve from 0.07747
# Epoch 97/1000
# 46/46 - 1s - loss: 7.3168e-04 - mae: 0.0206 - val_loss: 0.0237 - val_mae: 0.1159
#
# Epoch 00097: val_mae did not improve from 0.07747
# Epoch 98/1000
# 46/46 - 1s - loss: 6.8955e-04 - mae: 0.0199 - val_loss: 0.0238 - val_mae: 0.1166
#
# Epoch 00098: val_mae did not improve from 0.07747
# Epoch 99/1000
# 46/46 - 1s - loss: 6.5715e-04 - mae: 0.0194 - val_loss: 0.0247 - val_mae: 0.1191
#
# Epoch 00099: val_mae did not improve from 0.07747
# Epoch 100/1000
# 46/46 - 1s - loss: 7.0178e-04 - mae: 0.0201 - val_loss: 0.0235 - val_mae: 0.1160
#
# Epoch 00100: val_mae did not improve from 0.07747
# Epoch 101/1000
# 46/46 - 1s - loss: 6.1098e-04 - mae: 0.0186 - val_loss: 0.0242 - val_mae: 0.1179
#
# Epoch 00101: val_mae did not improve from 0.07747
# Epoch 102/1000
# 46/46 - 1s - loss: 6.3651e-04 - mae: 0.0190 - val_loss: 0.0239 - val_mae: 0.1168
#
# Epoch 00102: val_mae did not improve from 0.07747
# Epoch 103/1000
# 46/46 - 1s - loss: 6.5802e-04 - mae: 0.0194 - val_loss: 0.0244 - val_mae: 0.1185
#
# Epoch 00103: val_mae did not improve from 0.07747
# Epoch 104/1000
# 46/46 - 1s - loss: 6.2879e-04 - mae: 0.0189 - val_loss: 0.0239 - val_mae: 0.1170
#
# Epoch 00104: val_mae did not improve from 0.07747
# Epoch 105/1000
# 46/46 - 1s - loss: 6.4553e-04 - mae: 0.0192 - val_loss: 0.0243 - val_mae: 0.1180
#
# Epoch 00105: val_mae did not improve from 0.07747
# Epoch 106/1000
# 46/46 - 1s - loss: 6.2910e-04 - mae: 0.0189 - val_loss: 0.0246 - val_mae: 0.1185
#
# Epoch 00106: val_mae did not improve from 0.07747
# Epoch 107/1000
# 46/46 - 1s - loss: 6.0384e-04 - mae: 0.0185 - val_loss: 0.0238 - val_mae: 0.1164
#
# Epoch 00107: val_mae did not improve from 0.07747
# Epoch 108/1000
# 46/46 - 1s - loss: 7.0199e-04 - mae: 0.0203 - val_loss: 0.0240 - val_mae: 0.1172
#
# Epoch 00108: val_mae did not improve from 0.07747
# Epoch 109/1000
# 46/46 - 1s - loss: 6.3017e-04 - mae: 0.0190 - val_loss: 0.0237 - val_mae: 0.1161
#
# Epoch 00109: val_mae did not improve from 0.07747
# Epoch 110/1000
# 46/46 - 1s - loss: 5.8004e-04 - mae: 0.0181 - val_loss: 0.0244 - val_mae: 0.1181
# Epoch 00110: val_mae did not improve from 0.07747
# Epoch 111/1000
# 46/46 - 1s - loss: 6.2322e-04 - mae: 0.0189 - val_loss: 0.0245 - val_mae: 0.1187
#
# Epoch 00111: val_mae did not improve from 0.07747
# Epoch 112/1000
# 46/46 - 1s - loss: 5.8773e-04 - mae: 0.0183 - val_loss: 0.0248 - val_mae: 0.1198
#
# Epoch 00112: val_mae did not improve from 0.07747
# Epoch 113/1000
# 46/46 - 1s - loss: 5.9378e-04 - mae: 0.0184 - val_loss: 0.0248 - val_mae: 0.1193
#
# Epoch 00113: val_mae did not improve from 0.07747
# Epoch 114/1000
# 46/46 - 1s - loss: 6.1144e-04 - mae: 0.0187 - val_loss: 0.0245 - val_mae: 0.1187
#
# Epoch 00114: val_mae did not improve from 0.07747
# Epoch 00114: early stopping
