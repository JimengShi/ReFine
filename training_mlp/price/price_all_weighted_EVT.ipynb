# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import genpareto
from math import sqrt
from tensorflow import keras
import tensorflow as tf
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.cnn import cnn_4layer
from model.mlp import mlp_layer
# Out:
# 2024-01-10 12:31:32.315120: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
import random

random.seed(10)
print(random.random())
# Out:
# 0.5714025946899135

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data
# Out:
#                            price  price_dayahead  gen_coal  gen_gas  \
# time
# 2015-01-01 00:00:00+00:00  64.92           48.10    4755.0   5196.0
# 2015-01-01 01:00:00+00:00  64.48           47.33    4581.0   4857.0
# 2015-01-01 02:00:00+00:00  59.32           42.27    4131.0   4314.0
# 2015-01-01 03:00:00+00:00  56.04           38.41    3840.0   4130.0
# 2015-01-01 04:00:00+00:00  53.63           35.72    3590.0   4038.0
# ...                          ...             ...       ...      ...
# 2018-12-31 18:00:00+00:00  77.02           68.85    2628.0   7634.0
# 2018-12-31 19:00:00+00:00  76.16           68.40    2566.0   7241.0
# 2018-12-31 20:00:00+00:00  74.30           66.88    2422.0   7025.0
# 2018-12-31 21:00:00+00:00  69.89           63.93    2293.0   6562.0
# 2018-12-31 22:00:00+00:00  69.88           64.27    2166.0   6926.0
#
#                            load_actual  gen_lig  gen_oil  gen_oth_renew  \
# time
# 2015-01-01 00:00:00+00:00      24382.0    328.0    158.0           71.0
# 2015-01-01 01:00:00+00:00      22734.0    323.0    157.0           73.0
# 2015-01-01 02:00:00+00:00      21286.0    254.0    160.0           75.0
# 2015-01-01 03:00:00+00:00      20264.0    187.0    156.0           74.0
# 2015-01-01 04:00:00+00:00      19905.0    178.0    156.0           74.0
# ...                                ...      ...      ...            ...
# 2018-12-31 18:00:00+00:00      30653.0      0.0    178.0           95.0
# 2018-12-31 19:00:00+00:00      29735.0      0.0    174.0           95.0
# 2018-12-31 20:00:00+00:00      28071.0      0.0    168.0           94.0
# 2018-12-31 21:00:00+00:00      25801.0      0.0    163.0           93.0
# 2018-12-31 22:00:00+00:00      24455.0      0.0    163.0           92.0
#
#                            pressure_Barcelona  pressure_Bilbao  ...  \
# time                                                            ...
# 2015-01-01 00:00:00+00:00              1035.0           1035.0  ...
# 2015-01-01 01:00:00+00:00              1036.0           1036.0  ...
# 2015-01-01 02:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 03:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 04:00:00+00:00              1037.0           1035.0  ...
# ...                                       ...              ...  ...
# 2018-12-31 18:00:00+00:00              1027.0           1033.0  ...
# 2018-12-31 19:00:00+00:00              1027.0           1034.0  ...
# 2018-12-31 20:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 21:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 22:00:00+00:00              1028.0           1034.0  ...
#
#                            wind_deg_Bilbao  clouds_all_Bilbao  gen_hyd_river  \
# time
# 2015-01-01 00:00:00+00:00            229.0                0.0         1009.0
# 2015-01-01 01:00:00+00:00            224.0                0.0          973.0
# 2015-01-01 02:00:00+00:00            225.0                0.0          949.0
# 2015-01-01 03:00:00+00:00            221.0                0.0          953.0
# 2015-01-01 04:00:00+00:00            224.0                0.0          952.0
# ...                                    ...                ...            ...
# 2018-12-31 18:00:00+00:00             57.0                0.0         1135.0
# 2018-12-31 19:00:00+00:00              0.0                0.0         1172.0
# 2018-12-31 20:00:00+00:00            140.0                0.0         1148.0
# 2018-12-31 21:00:00+00:00            120.0                0.0         1128.0
# 2018-12-31 22:00:00+00:00            100.0                0.0         1069.0
#
#                            wind_deg_Seville  wind_speed_Barcelona  \
# time
# 2015-01-01 00:00:00+00:00              21.0                   7.0
# 2015-01-01 01:00:00+00:00              27.0                   7.0
# 2015-01-01 02:00:00+00:00              27.0                   7.0
# 2015-01-01 03:00:00+00:00              27.0                   7.0
# 2015-01-01 04:00:00+00:00              57.0                   5.0
# ...                                     ...                   ...
# 2018-12-31 18:00:00+00:00              30.0                   1.0
# 2018-12-31 19:00:00+00:00              30.0                   3.0
# 2018-12-31 20:00:00+00:00              50.0                   4.0
# 2018-12-31 21:00:00+00:00              60.0                   5.0
# 2018-12-31 22:00:00+00:00              50.0                   5.0
#
#                            wind_speed_Valencia  wind_speed_Bilbao  gen_wind  \
# time
# 2015-01-01 00:00:00+00:00                  1.0                0.0    5890.0
# 2015-01-01 01:00:00+00:00                  0.0                1.0    5461.0
# 2015-01-01 02:00:00+00:00                  0.0                1.0    5238.0
# 2015-01-01 03:00:00+00:00                  0.0                1.0    4935.0
# 2015-01-01 04:00:00+00:00                  2.0                1.0    4618.0
# ...                                        ...                ...       ...
# 2018-12-31 18:00:00+00:00                  2.0                0.0    3113.0
# 2018-12-31 19:00:00+00:00                  1.0                1.0    3288.0
# 2018-12-31 20:00:00+00:00                  3.0                1.0    3503.0
# 2018-12-31 21:00:00+00:00                  2.0                1.0    3586.0
# 2018-12-31 22:00:00+00:00                  2.0                2.0    3651.0
#
#                            wind_speed_Madrid  gen_hyd_pump
# time
# 2015-01-01 00:00:00+00:00                1.0         920.0
# 2015-01-01 01:00:00+00:00                1.0        1164.0
# 2015-01-01 02:00:00+00:00                1.0        1503.0
# 2015-01-01 03:00:00+00:00                1.0        1826.0
# 2015-01-01 04:00:00+00:00                0.0        2109.0
# ...                                      ...           ...
# 2018-12-31 18:00:00+00:00                1.0           1.0
# 2018-12-31 19:00:00+00:00                1.0           1.0
# 2018-12-31 20:00:00+00:00                1.0          50.0
# 2018-12-31 21:00:00+00:00                2.0         108.0
# 2018-12-31 22:00:00+00:00                1.0         108.0
#
# [35063 rows x 26 columns]

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 0
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### PM threshold

# %%
train_X_pm = train_X[:, 0, feature_idx]
print(train_X_pm.shape)

val_X_pm = val_X[:, 0, feature_idx]
print(val_X_pm.shape)

test_X_pm = test_X[:, 0, feature_idx]
print(test_X_pm.shape)
# Out:
# (24486,)
# (5247,)
# (5247,)

# %%
percentile = 95

merged_array = np.concatenate((train_X_pm, val_X_pm, test_X_pm))

percentile_pm = np.percentile(merged_array, percentile)

print("{}th Percentile of Daily Rain:".format(percentile), percentile_pm)
# Out:
# 95th Percentile of Daily Rain: 0.7037105569454176

# %%
len(train_X_pm[train_X_pm > percentile_pm])
# Out:
# 696

# %%
# Extract excesses over the threshold from the heavy pm data only
excesses = np.abs(train_X_pm[train_X_pm > percentile_pm] - percentile_pm)
excesses.shape
# Out:
# (696,)

# %%
# Fit Generalized Pareto Distribution (GPD) to excesses - returns shape (c), loc, scale for fitted distribution
c, loc, scale = genpareto.fit(excesses)


# Define a function to calculate weights based on the survival function of the GPD
def calculate_weights(pm, c, loc, scale, threshold):
    """
    survival function, also known as the complementary cumulative distribution function (CCDF), 
    is a function that gives the probability that a random variable X is greater than a certain value x
    """
    # Weights are the inverse of the survival function
    weights = np.where(pm > threshold, 
                       1 / (1 - genpareto.cdf(pm-threshold, c, loc=loc, scale=scale)),
#                        1 - genpareto.cdf(threshold - loc, c, loc=loc, scale=scale),
                       1.0
                      )  # Assign a default weight of 1 for non-extreme events

    # Normalize weights (optional, for stability in training)
    weights /= np.max(weights)
#     weights = (weights - np.min(weights)) / (np.max(weights) - np.min(weights)) + 0.1
#     weights = weights + 0.1
#     weights = np.exp(weights)
#     weights /= np.sum(weights)
    return weights

# Calculate weights for each sample in your dataset
weights = calculate_weights(train_X_pm, c, loc, scale, percentile_pm)
weights.shape
# Out:
# (24486,)

# %%
plt.hist(weights, bins=20)
# Out:
# (array([2.3873e+04, 5.9000e+01, 9.8000e+01, 7.2000e+01, 7.5000e+01,
#         6.3000e+01, 3.7000e+01, 2.3000e+01, 2.7000e+01, 2.5000e+01,
#         2.4000e+01, 1.6000e+01, 1.4000e+01, 2.2000e+01, 2.0000e+01,
#         1.4000e+01, 9.0000e+00, 4.0000e+00, 7.0000e+00, 4.0000e+00]),
#  array([0.18535948, 0.2260915 , 0.26682353, 0.30755556, 0.34828758,
#         0.38901961, 0.42975163, 0.47048366, 0.51121569, 0.55194771,
#         0.59267974, 0.63341177, 0.67414379, 0.71487582, 0.75560784,
#         0.79633987, 0.8370719 , 0.87780392, 0.91853595, 0.95926797,
#         1.        ]),
#  <BarContainer object of 20 artists>)

# %%
np.save('sample_weights_price_EVT.npy', weights)

# %% [markdown]
# ### Model

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0.0
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

# %%
model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )


es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models/price_all_weighted_EVT_95.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True,
                    )


model.fit(train_X, train_y,
          validation_data=(val_X, val_y),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc],
          sample_weight=weights
         )
# Out:
# Epoch 1/1000
# 48/48 - 2s - loss: 0.0070 - mae: 0.1356 - val_loss: 0.0148 - val_mae: 0.0973
#
# Epoch 00001: val_mae improved from inf to 0.09725, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 2/1000
# 48/48 - 1s - loss: 0.0020 - mae: 0.0789 - val_loss: 0.0129 - val_mae: 0.0905
#
# Epoch 00002: val_mae improved from 0.09725 to 0.09047, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 3/1000
# 48/48 - 1s - loss: 0.0017 - mae: 0.0725 - val_loss: 0.0111 - val_mae: 0.0852
#
# Epoch 00003: val_mae improved from 0.09047 to 0.08522, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 4/1000
# 48/48 - 1s - loss: 0.0012 - mae: 0.0597 - val_loss: 0.0065 - val_mae: 0.0622
#
# Epoch 00004: val_mae improved from 0.08522 to 0.06216, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 5/1000
# 48/48 - 1s - loss: 7.8270e-04 - mae: 0.0484 - val_loss: 0.0061 - val_mae: 0.0604
#
# Epoch 00005: val_mae improved from 0.06216 to 0.06044, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 6/1000
# 48/48 - 1s - loss: 7.0376e-04 - mae: 0.0459 - val_loss: 0.0059 - val_mae: 0.0598
#
# Epoch 00006: val_mae improved from 0.06044 to 0.05979, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 7/1000
# 48/48 - 1s - loss: 6.5510e-04 - mae: 0.0442 - val_loss: 0.0055 - val_mae: 0.0571
#
# Epoch 00007: val_mae improved from 0.05979 to 0.05712, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 8/1000
# 48/48 - 1s - loss: 6.2250e-04 - mae: 0.0430 - val_loss: 0.0055 - val_mae: 0.0572
#
# Epoch 00008: val_mae did not improve from 0.05712
# Epoch 9/1000
# 48/48 - 1s - loss: 5.7420e-04 - mae: 0.0411 - val_loss: 0.0051 - val_mae: 0.0532
#
# Epoch 00009: val_mae improved from 0.05712 to 0.05324, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 10/1000
# 48/48 - 1s - loss: 5.4456e-04 - mae: 0.0400 - val_loss: 0.0049 - val_mae: 0.0527
#
# Epoch 00010: val_mae improved from 0.05324 to 0.05266, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 11/1000
# 48/48 - 1s - loss: 5.4001e-04 - mae: 0.0400 - val_loss: 0.0049 - val_mae: 0.0523
#
# Epoch 00011: val_mae improved from 0.05266 to 0.05234, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 12/1000
# 48/48 - 1s - loss: 5.1721e-04 - mae: 0.0391 - val_loss: 0.0050 - val_mae: 0.0520
#
# Epoch 00012: val_mae improved from 0.05234 to 0.05202, saving model to ../../saved_models/energy_all_weighted_EVT_95.h5
# Epoch 13/1000
# 48/48 - 1s - loss: 5.0357e-04 - mae: 0.0387 - val_loss: 0.0059 - val_mae: 0.0593
#
# Epoch 00013: val_mae did not improve from 0.05202
# Epoch 14/1000
# 48/48 - 1s - loss: 4.9717e-04 - mae: 0.0386 - val_loss: 0.0054 - val_mae: 0.0554
#
# Epoch 00014: val_mae did not improve from 0.05202
# Epoch 15/1000
# 48/48 - 1s - loss: 4.5631e-04 - mae: 0.0369 - val_loss: 0.0052 - val_mae: 0.0534
#
# Epoch 00015: val_mae did not improve from 0.05202
# Epoch 16/1000
# 48/48 - 1s - loss: 4.3954e-04 - mae: 0.0363 - val_loss: 0.0057 - val_mae: 0.0575
#
# Epoch 00016: val_mae did not improve from 0.05202
# Epoch 17/1000
# 48/48 - 1s - loss: 4.3431e-04 - mae: 0.0362 - val_loss: 0.0055 - val_mae: 0.0556
#
# Epoch 00017: val_mae did not improve from 0.05202
# Epoch 18/1000
# 48/48 - 1s - loss: 4.1566e-04 - mae: 0.0354 - val_loss: 0.0057 - val_mae: 0.0569
#
# Epoch 00018: val_mae did not improve from 0.05202
# Epoch 19/1000
# 48/48 - 1s - loss: 4.1074e-04 - mae: 0.0353 - val_loss: 0.0057 - val_mae: 0.0561
#
# Epoch 00019: val_mae did not improve from 0.05202
# Epoch 20/1000
# 48/48 - 1s - loss: 3.8647e-04 - mae: 0.0342 - val_loss: 0.0061 - val_mae: 0.0594
#
# Epoch 00020: val_mae did not improve from 0.05202
# Epoch 21/1000
# 48/48 - 1s - loss: 3.7162e-04 - mae: 0.0335 - val_loss: 0.0061 - val_mae: 0.0591
#
# Epoch 00021: val_mae did not improve from 0.05202
# Epoch 22/1000
# 48/48 - 1s - loss: 3.5747e-04 - mae: 0.0330 - val_loss: 0.0072 - val_mae: 0.0655
#
# Epoch 00022: val_mae did not improve from 0.05202
# Epoch 23/1000
# 48/48 - 1s - loss: 3.6448e-04 - mae: 0.0334 - val_loss: 0.0068 - val_mae: 0.0631
#
# Epoch 00023: val_mae did not improve from 0.05202
# Epoch 24/1000
# 48/48 - 1s - loss: 3.4996e-04 - mae: 0.0328 - val_loss: 0.0064 - val_mae: 0.0598
#
# Epoch 00024: val_mae did not improve from 0.05202
# Epoch 25/1000
# 48/48 - 1s - loss: 3.3003e-04 - mae: 0.0317 - val_loss: 0.0066 - val_mae: 0.0615
#
# Epoch 00025: val_mae did not improve from 0.05202
# Epoch 26/1000
# 48/48 - 1s - loss: 3.1151e-04 - mae: 0.0308 - val_loss: 0.0072 - val_mae: 0.0644
#
# Epoch 00026: val_mae did not improve from 0.05202
# Epoch 27/1000
# 48/48 - 1s - loss: 3.1634e-04 - mae: 0.0312 - val_loss: 0.0068 - val_mae: 0.0622
#
# Epoch 00027: val_mae did not improve from 0.05202
# Epoch 28/1000
# 48/48 - 1s - loss: 2.9847e-04 - mae: 0.0302 - val_loss: 0.0070 - val_mae: 0.0634
#
# Epoch 00028: val_mae did not improve from 0.05202
# Epoch 29/1000
# 48/48 - 1s - loss: 2.8615e-04 - mae: 0.0296 - val_loss: 0.0071 - val_mae: 0.0640
#
# Epoch 00029: val_mae did not improve from 0.05202
# Epoch 30/1000
# 48/48 - 1s - loss: 2.8873e-04 - mae: 0.0299 - val_loss: 0.0074 - val_mae: 0.0658
#
# Epoch 00030: val_mae did not improve from 0.05202
# Epoch 31/1000
# 48/48 - 1s - loss: 2.7836e-04 - mae: 0.0294 - val_loss: 0.0073 - val_mae: 0.0645
#
# Epoch 00031: val_mae did not improve from 0.05202
# Epoch 32/1000
# 48/48 - 1s - loss: 2.7718e-04 - mae: 0.0294 - val_loss: 0.0073 - val_mae: 0.0649
#
# Epoch 00032: val_mae did not improve from 0.05202
# Epoch 33/1000
# 48/48 - 1s - loss: 2.5512e-04 - mae: 0.0281 - val_loss: 0.0070 - val_mae: 0.0634
#
# Epoch 00033: val_mae did not improve from 0.05202
# Epoch 34/1000
# 48/48 - 1s - loss: 2.5387e-04 - mae: 0.0281 - val_loss: 0.0075 - val_mae: 0.0659
#
# Epoch 00034: val_mae did not improve from 0.05202
# Epoch 35/1000
# 48/48 - 1s - loss: 2.4556e-04 - mae: 0.0276 - val_loss: 0.0081 - val_mae: 0.0687
#
# Epoch 00035: val_mae did not improve from 0.05202
# Epoch 36/1000
# 48/48 - 1s - loss: 2.4855e-04 - mae: 0.0278 - val_loss: 0.0077 - val_mae: 0.0664
#
# Epoch 00036: val_mae did not improve from 0.05202
# Epoch 37/1000
# 48/48 - 1s - loss: 2.4966e-04 - mae: 0.0279 - val_loss: 0.0069 - val_mae: 0.0628
#
# Epoch 00037: val_mae did not improve from 0.05202
# Epoch 38/1000
# 48/48 - 1s - loss: 2.6647e-04 - mae: 0.0289 - val_loss: 0.0074 - val_mae: 0.0646
#
# Epoch 00038: val_mae did not improve from 0.05202
# Epoch 39/1000
# 48/48 - 1s - loss: 2.4815e-04 - mae: 0.0278 - val_loss: 0.0083 - val_mae: 0.0694
#
# Epoch 00039: val_mae did not improve from 0.05202
# Epoch 40/1000
# 48/48 - 1s - loss: 2.4358e-04 - mae: 0.0276 - val_loss: 0.0083 - val_mae: 0.0695
#
# Epoch 00040: val_mae did not improve from 0.05202
# Epoch 41/1000
# 48/48 - 1s - loss: 2.1869e-04 - mae: 0.0261 - val_loss: 0.0079 - val_mae: 0.0678
#
# Epoch 00041: val_mae did not improve from 0.05202
# Epoch 42/1000
# 48/48 - 1s - loss: 2.3479e-04 - mae: 0.0271 - val_loss: 0.0075 - val_mae: 0.0651
#
# Epoch 00042: val_mae did not improve from 0.05202
# Epoch 43/1000
# 48/48 - 1s - loss: 2.3654e-04 - mae: 0.0272 - val_loss: 0.0077 - val_mae: 0.0666
#
# Epoch 00043: val_mae did not improve from 0.05202
# Epoch 44/1000
# 48/48 - 1s - loss: 2.1001e-04 - mae: 0.0256 - val_loss: 0.0077 - val_mae: 0.0663
#
# Epoch 00044: val_mae did not improve from 0.05202
# Epoch 45/1000
# 48/48 - 1s - loss: 2.0725e-04 - mae: 0.0254 - val_loss: 0.0080 - val_mae: 0.0677
#
# Epoch 00045: val_mae did not improve from 0.05202
# Epoch 46/1000
# 48/48 - 1s - loss: 2.0327e-04 - mae: 0.0252 - val_loss: 0.0085 - val_mae: 0.0702
#
# Epoch 00046: val_mae did not improve from 0.05202
# Epoch 47/1000
# 48/48 - 1s - loss: 1.9243e-04 - mae: 0.0244 - val_loss: 0.0081 - val_mae: 0.0679
#
# Epoch 00047: val_mae did not improve from 0.05202
# Epoch 48/1000
# 48/48 - 1s - loss: 2.0228e-04 - mae: 0.0252 - val_loss: 0.0081 - val_mae: 0.0681
#
# Epoch 00048: val_mae did not improve from 0.05202
# Epoch 49/1000
# 48/48 - 1s - loss: 1.9920e-04 - mae: 0.0249 - val_loss: 0.0090 - val_mae: 0.0726
#
# Epoch 00049: val_mae did not improve from 0.05202
# Epoch 50/1000
# 48/48 - 1s - loss: 1.8615e-04 - mae: 0.0241 - val_loss: 0.0082 - val_mae: 0.0688
#
# Epoch 00050: val_mae did not improve from 0.05202
# Epoch 51/1000
# 48/48 - 1s - loss: 1.8616e-04 - mae: 0.0241 - val_loss: 0.0084 - val_mae: 0.0696
#
# Epoch 00051: val_mae did not improve from 0.05202
# Epoch 52/1000
# 48/48 - 1s - loss: 1.8300e-04 - mae: 0.0239 - val_loss: 0.0084 - val_mae: 0.0701
#
# Epoch 00052: val_mae did not improve from 0.05202
# Epoch 53/1000
# 48/48 - 1s - loss: 1.8022e-04 - mae: 0.0237 - val_loss: 0.0084 - val_mae: 0.0694
#
# Epoch 00053: val_mae did not improve from 0.05202
# Epoch 54/1000
# 48/48 - 1s - loss: 1.8376e-04 - mae: 0.0240 - val_loss: 0.0087 - val_mae: 0.0714
#
# Epoch 00054: val_mae did not improve from 0.05202
# Epoch 55/1000
# 48/48 - 1s - loss: 1.7636e-04 - mae: 0.0235 - val_loss: 0.0088 - val_mae: 0.0712
#
# Epoch 00055: val_mae did not improve from 0.05202
# Epoch 56/1000
# 48/48 - 1s - loss: 1.8613e-04 - mae: 0.0242 - val_loss: 0.0092 - val_mae: 0.0733
#
# Epoch 00056: val_mae did not improve from 0.05202
# Epoch 57/1000
# 48/48 - 1s - loss: 1.7387e-04 - mae: 0.0233 - val_loss: 0.0084 - val_mae: 0.0697
#
# Epoch 00057: val_mae did not improve from 0.05202
# Epoch 58/1000
# 48/48 - 1s - loss: 1.6573e-04 - mae: 0.0227 - val_loss: 0.0094 - val_mae: 0.0741
#
# Epoch 00058: val_mae did not improve from 0.05202
# Epoch 59/1000
# 48/48 - 1s - loss: 1.6903e-04 - mae: 0.0230 - val_loss: 0.0089 - val_mae: 0.0717
#
# Epoch 00059: val_mae did not improve from 0.05202
# Epoch 60/1000
# 48/48 - 1s - loss: 1.5823e-04 - mae: 0.0222 - val_loss: 0.0101 - val_mae: 0.0771
#
# Epoch 00060: val_mae did not improve from 0.05202
# Epoch 61/1000
# 48/48 - 1s - loss: 1.5414e-04 - mae: 0.0219 - val_loss: 0.0093 - val_mae: 0.0730
#
# Epoch 00061: val_mae did not improve from 0.05202
# Epoch 62/1000
# 48/48 - 1s - loss: 1.5115e-04 - mae: 0.0217 - val_loss: 0.0095 - val_mae: 0.0740
#
# Epoch 00062: val_mae did not improve from 0.05202
# Epoch 63/1000
# 48/48 - 1s - loss: 1.6186e-04 - mae: 0.0225 - val_loss: 0.0092 - val_mae: 0.0722
#
# Epoch 00063: val_mae did not improve from 0.05202
# Epoch 64/1000
# 48/48 - 1s - loss: 1.6465e-04 - mae: 0.0227 - val_loss: 0.0096 - val_mae: 0.0749
#
# Epoch 00064: val_mae did not improve from 0.05202
# Epoch 65/1000
# 48/48 - 1s - loss: 1.4620e-04 - mae: 0.0214 - val_loss: 0.0102 - val_mae: 0.0777
#
# Epoch 00065: val_mae did not improve from 0.05202
# Epoch 66/1000
# 48/48 - 1s - loss: 1.4699e-04 - mae: 0.0215 - val_loss: 0.0104 - val_mae: 0.0787
#
# Epoch 00066: val_mae did not improve from 0.05202
# Epoch 67/1000
# 48/48 - 1s - loss: 1.6221e-04 - mae: 0.0226 - val_loss: 0.0093 - val_mae: 0.0738
#
# Epoch 00067: val_mae did not improve from 0.05202
# Epoch 68/1000
# 48/48 - 1s - loss: 1.4693e-04 - mae: 0.0215 - val_loss: 0.0102 - val_mae: 0.0774
#
# Epoch 00068: val_mae did not improve from 0.05202
# Epoch 69/1000
# 48/48 - 1s - loss: 1.4711e-04 - mae: 0.0215 - val_loss: 0.0104 - val_mae: 0.0776
#
# Epoch 00069: val_mae did not improve from 0.05202
# Epoch 70/1000
# 48/48 - 1s - loss: 1.4006e-04 - mae: 0.0209 - val_loss: 0.0096 - val_mae: 0.0740
#
# Epoch 00070: val_mae did not improve from 0.05202
# Epoch 71/1000
# 48/48 - 1s - loss: 1.3867e-04 - mae: 0.0209 - val_loss: 0.0095 - val_mae: 0.0740
#
# Epoch 00071: val_mae did not improve from 0.05202
# Epoch 72/1000
# 48/48 - 1s - loss: 1.3480e-04 - mae: 0.0206 - val_loss: 0.0100 - val_mae: 0.0764
#
# Epoch 00072: val_mae did not improve from 0.05202
# Epoch 73/1000
# 48/48 - 1s - loss: 1.4069e-04 - mae: 0.0210 - val_loss: 0.0109 - val_mae: 0.0804
#
# Epoch 00073: val_mae did not improve from 0.05202
# Epoch 74/1000
# 48/48 - 1s - loss: 1.3548e-04 - mae: 0.0206 - val_loss: 0.0103 - val_mae: 0.0774
#
# Epoch 00074: val_mae did not improve from 0.05202
# Epoch 75/1000
# 48/48 - 1s - loss: 1.3423e-04 - mae: 0.0205 - val_loss: 0.0105 - val_mae: 0.0785
#
# Epoch 00075: val_mae did not improve from 0.05202
# Epoch 76/1000
# 48/48 - 1s - loss: 1.2774e-04 - mae: 0.0200 - val_loss: 0.0102 - val_mae: 0.0772
#
# Epoch 00076: val_mae did not improve from 0.05202
# Epoch 77/1000
# 48/48 - 1s - loss: 1.4297e-04 - mae: 0.0213 - val_loss: 0.0101 - val_mae: 0.0775
#
# Epoch 00077: val_mae did not improve from 0.05202
# Epoch 78/1000
# 48/48 - 1s - loss: 1.3404e-04 - mae: 0.0205 - val_loss: 0.0105 - val_mae: 0.0790
#
# Epoch 00078: val_mae did not improve from 0.05202
# Epoch 79/1000
# 48/48 - 1s - loss: 1.2960e-04 - mae: 0.0202 - val_loss: 0.0109 - val_mae: 0.0807
#
# Epoch 00079: val_mae did not improve from 0.05202
# Epoch 80/1000
# 48/48 - 1s - loss: 1.3645e-04 - mae: 0.0208 - val_loss: 0.0104 - val_mae: 0.0775
#
# Epoch 00080: val_mae did not improve from 0.05202
# Epoch 81/1000
# 48/48 - 1s - loss: 1.3125e-04 - mae: 0.0203 - val_loss: 0.0101 - val_mae: 0.0766
#
# Epoch 00081: val_mae did not improve from 0.05202
# Epoch 82/1000
# 48/48 - 1s - loss: 1.1546e-04 - mae: 0.0190 - val_loss: 0.0105 - val_mae: 0.0787
#
# Epoch 00082: val_mae did not improve from 0.05202
# Epoch 83/1000
# 48/48 - 1s - loss: 1.2754e-04 - mae: 0.0201 - val_loss: 0.0107 - val_mae: 0.0792
#
# Epoch 00083: val_mae did not improve from 0.05202
# Epoch 84/1000
# 48/48 - 1s - loss: 1.1739e-04 - mae: 0.0192 - val_loss: 0.0102 - val_mae: 0.0771
#
# Epoch 00084: val_mae did not improve from 0.05202
# Epoch 85/1000
# 48/48 - 1s - loss: 1.3984e-04 - mae: 0.0211 - val_loss: 0.0107 - val_mae: 0.0795
#
# Epoch 00085: val_mae did not improve from 0.05202
# Epoch 86/1000
# 48/48 - 1s - loss: 1.1400e-04 - mae: 0.0189 - val_loss: 0.0101 - val_mae: 0.0769
#
# Epoch 00086: val_mae did not improve from 0.05202
# Epoch 87/1000
# 48/48 - 1s - loss: 1.1002e-04 - mae: 0.0185 - val_loss: 0.0109 - val_mae: 0.0804
#
# Epoch 00087: val_mae did not improve from 0.05202
# Epoch 88/1000
# 48/48 - 1s - loss: 1.1718e-04 - mae: 0.0192 - val_loss: 0.0105 - val_mae: 0.0785
#
# Epoch 00088: val_mae did not improve from 0.05202
# Epoch 89/1000
# 48/48 - 1s - loss: 1.2887e-04 - mae: 0.0202 - val_loss: 0.0103 - val_mae: 0.0777
#
# Epoch 00089: val_mae did not improve from 0.05202
# Epoch 90/1000
# 48/48 - 1s - loss: 1.2191e-04 - mae: 0.0196 - val_loss: 0.0113 - val_mae: 0.0827
#
# Epoch 00090: val_mae did not improve from 0.05202
# Epoch 91/1000
# 48/48 - 1s - loss: 1.0804e-04 - mae: 0.0184 - val_loss: 0.0107 - val_mae: 0.0792
#
# Epoch 00091: val_mae did not improve from 0.05202
# Epoch 92/1000
# 48/48 - 1s - loss: 1.0827e-04 - mae: 0.0185 - val_loss: 0.0112 - val_mae: 0.0816
#
# Epoch 00092: val_mae did not improve from 0.05202
# Epoch 93/1000
# 48/48 - 1s - loss: 1.0288e-04 - mae: 0.0179 - val_loss: 0.0109 - val_mae: 0.0804
#
# Epoch 00093: val_mae did not improve from 0.05202
# Epoch 94/1000
# 48/48 - 1s - loss: 1.1408e-04 - mae: 0.0190 - val_loss: 0.0109 - val_mae: 0.0807
#
# Epoch 00094: val_mae did not improve from 0.05202
# Epoch 95/1000
# 48/48 - 1s - loss: 1.3271e-04 - mae: 0.0206 - val_loss: 0.0108 - val_mae: 0.0803
#
# Epoch 00095: val_mae did not improve from 0.05202
# Epoch 96/1000
# 48/48 - 1s - loss: 1.0870e-04 - mae: 0.0185 - val_loss: 0.0109 - val_mae: 0.0802
#
# Epoch 00096: val_mae did not improve from 0.05202
# Epoch 97/1000
# 48/48 - 1s - loss: 1.0036e-04 - mae: 0.0177 - val_loss: 0.0111 - val_mae: 0.0813
#
# Epoch 00097: val_mae did not improve from 0.05202
# Epoch 98/1000
# 48/48 - 1s - loss: 1.0679e-04 - mae: 0.0183 - val_loss: 0.0113 - val_mae: 0.0823
#
# Epoch 00098: val_mae did not improve from 0.05202
# Epoch 99/1000
# 48/48 - 1s - loss: 1.0080e-04 - mae: 0.0178 - val_loss: 0.0111 - val_mae: 0.0814
#
# Epoch 00099: val_mae did not improve from 0.05202
# Epoch 100/1000
# 48/48 - 1s - loss: 9.6992e-05 - mae: 0.0175 - val_loss: 0.0106 - val_mae: 0.0792
#
# Epoch 00100: val_mae did not improve from 0.05202
# Epoch 101/1000
# 48/48 - 1s - loss: 1.0500e-04 - mae: 0.0182 - val_loss: 0.0108 - val_mae: 0.0804
#
# Epoch 00101: val_mae did not improve from 0.05202
# Epoch 102/1000
# 48/48 - 1s - loss: 1.0314e-04 - mae: 0.0180 - val_loss: 0.0112 - val_mae: 0.0817
#
# Epoch 00102: val_mae did not improve from 0.05202
# Epoch 103/1000
# 48/48 - 1s - loss: 9.3644e-05 - mae: 0.0171 - val_loss: 0.0115 - val_mae: 0.0832
#
# Epoch 00103: val_mae did not improve from 0.05202
# Epoch 104/1000
# 48/48 - 1s - loss: 1.0385e-04 - mae: 0.0181 - val_loss: 0.0104 - val_mae: 0.0781
#
# Epoch 00104: val_mae did not improve from 0.05202
# Epoch 105/1000
# 48/48 - 1s - loss: 9.5093e-05 - mae: 0.0173 - val_loss: 0.0117 - val_mae: 0.0841
#
# Epoch 00105: val_mae did not improve from 0.05202
# Epoch 106/1000
# 48/48 - 1s - loss: 1.0375e-04 - mae: 0.0181 - val_loss: 0.0111 - val_mae: 0.0814
#
# Epoch 00106: val_mae did not improve from 0.05202
# Epoch 107/1000
# 48/48 - 1s - loss: 9.0522e-05 - mae: 0.0168 - val_loss: 0.0106 - val_mae: 0.0792
#
# Epoch 00107: val_mae did not improve from 0.05202
# Epoch 108/1000
# 48/48 - 1s - loss: 9.5385e-05 - mae: 0.0173 - val_loss: 0.0109 - val_mae: 0.0805
# Epoch 00108: val_mae did not improve from 0.05202
# Epoch 109/1000
# 48/48 - 1s - loss: 9.0994e-05 - mae: 0.0169 - val_loss: 0.0110 - val_mae: 0.0809
#
# Epoch 00109: val_mae did not improve from 0.05202
# Epoch 110/1000
# 48/48 - 1s - loss: 8.7940e-05 - mae: 0.0166 - val_loss: 0.0112 - val_mae: 0.0815
#
# Epoch 00110: val_mae did not improve from 0.05202
# Epoch 111/1000
# 48/48 - 1s - loss: 9.1076e-05 - mae: 0.0169 - val_loss: 0.0121 - val_mae: 0.0859
#
# Epoch 00111: val_mae did not improve from 0.05202
# Epoch 112/1000
# 48/48 - 1s - loss: 1.0252e-04 - mae: 0.0180 - val_loss: 0.0119 - val_mae: 0.0850
#
# Epoch 00112: val_mae did not improve from 0.05202
# Epoch 113/1000
# 48/48 - 1s - loss: 1.2032e-04 - mae: 0.0196 - val_loss: 0.0115 - val_mae: 0.0834
#
# Epoch 00113: val_mae did not improve from 0.05202
# Epoch 114/1000
# 48/48 - 1s - loss: 9.0564e-05 - mae: 0.0169 - val_loss: 0.0112 - val_mae: 0.0818
#
# Epoch 00114: val_mae did not improve from 0.05202
# Epoch 115/1000
# 48/48 - 1s - loss: 8.6902e-05 - mae: 0.0165 - val_loss: 0.0114 - val_mae: 0.0822
#
# Epoch 00115: val_mae did not improve from 0.05202
# Epoch 116/1000
# 48/48 - 1s - loss: 8.8720e-05 - mae: 0.0167 - val_loss: 0.0112 - val_mae: 0.0816
#
# Epoch 00116: val_mae did not improve from 0.05202
# Epoch 117/1000
# 48/48 - 1s - loss: 8.3901e-05 - mae: 0.0162 - val_loss: 0.0114 - val_mae: 0.0827
#
# Epoch 00117: val_mae did not improve from 0.05202
# Epoch 118/1000
# 48/48 - 1s - loss: 8.8144e-05 - mae: 0.0166 - val_loss: 0.0117 - val_mae: 0.0839
#
# Epoch 00118: val_mae did not improve from 0.05202
# Epoch 119/1000
# 48/48 - 1s - loss: 8.9101e-05 - mae: 0.0168 - val_loss: 0.0113 - val_mae: 0.0819
#
# Epoch 00119: val_mae did not improve from 0.05202
# Epoch 120/1000
# 48/48 - 1s - loss: 8.1004e-05 - mae: 0.0159 - val_loss: 0.0115 - val_mae: 0.0822
#
# Epoch 00120: val_mae did not improve from 0.05202
# Epoch 121/1000
# 48/48 - 1s - loss: 8.8878e-05 - mae: 0.0167 - val_loss: 0.0115 - val_mae: 0.0823
#
# Epoch 00121: val_mae did not improve from 0.05202
# Epoch 122/1000
# 48/48 - 1s - loss: 8.8827e-05 - mae: 0.0167 - val_loss: 0.0118 - val_mae: 0.0841
#
# Epoch 00122: val_mae did not improve from 0.05202
# Epoch 123/1000
# 48/48 - 1s - loss: 9.5496e-05 - mae: 0.0174 - val_loss: 0.0113 - val_mae: 0.0821
#
# Epoch 00123: val_mae did not improve from 0.05202
# Epoch 124/1000
# 48/48 - 1s - loss: 9.5451e-05 - mae: 0.0174 - val_loss: 0.0115 - val_mae: 0.0829
#
# Epoch 00124: val_mae did not improve from 0.05202
# Epoch 125/1000
# 48/48 - 1s - loss: 8.0744e-05 - mae: 0.0159 - val_loss: 0.0118 - val_mae: 0.0840
#
# Epoch 00125: val_mae did not improve from 0.05202
# Epoch 126/1000
# 48/48 - 1s - loss: 8.3268e-05 - mae: 0.0161 - val_loss: 0.0114 - val_mae: 0.0821
#
# Epoch 00126: val_mae did not improve from 0.05202
# Epoch 127/1000
# 48/48 - 1s - loss: 7.6025e-05 - mae: 0.0154 - val_loss: 0.0114 - val_mae: 0.0820
#
# Epoch 00127: val_mae did not improve from 0.05202
# Epoch 128/1000
# 48/48 - 1s - loss: 8.0576e-05 - mae: 0.0159 - val_loss: 0.0129 - val_mae: 0.0892
#
# Epoch 00128: val_mae did not improve from 0.05202
# Epoch 129/1000
# 48/48 - 1s - loss: 9.1750e-05 - mae: 0.0170 - val_loss: 0.0115 - val_mae: 0.0824
#
# Epoch 00129: val_mae did not improve from 0.05202
# Epoch 130/1000
# 48/48 - 1s - loss: 7.7008e-05 - mae: 0.0155 - val_loss: 0.0113 - val_mae: 0.0820
#
# Epoch 00130: val_mae did not improve from 0.05202
# Epoch 131/1000
# 48/48 - 1s - loss: 8.4675e-05 - mae: 0.0163 - val_loss: 0.0113 - val_mae: 0.0817
#
# Epoch 00131: val_mae did not improve from 0.05202
# Epoch 132/1000
# 48/48 - 1s - loss: 7.7239e-05 - mae: 0.0155 - val_loss: 0.0117 - val_mae: 0.0837
#
# Epoch 00132: val_mae did not improve from 0.05202
# Epoch 133/1000
# 48/48 - 1s - loss: 8.0158e-05 - mae: 0.0158 - val_loss: 0.0117 - val_mae: 0.0836
#
# Epoch 00133: val_mae did not improve from 0.05202
# Epoch 134/1000
# 48/48 - 1s - loss: 8.7115e-05 - mae: 0.0165 - val_loss: 0.0115 - val_mae: 0.0831
#
# Epoch 00134: val_mae did not improve from 0.05202
# Epoch 135/1000
# 48/48 - 1s - loss: 7.3249e-05 - mae: 0.0151 - val_loss: 0.0119 - val_mae: 0.0842
#
# Epoch 00135: val_mae did not improve from 0.05202
# Epoch 136/1000
# 48/48 - 1s - loss: 8.1008e-05 - mae: 0.0159 - val_loss: 0.0121 - val_mae: 0.0848
#
# Epoch 00136: val_mae did not improve from 0.05202
# Epoch 137/1000
# 48/48 - 1s - loss: 8.4131e-05 - mae: 0.0163 - val_loss: 0.0116 - val_mae: 0.0833
#
# Epoch 00137: val_mae did not improve from 0.05202
# Epoch 138/1000
# 48/48 - 1s - loss: 7.9443e-05 - mae: 0.0158 - val_loss: 0.0112 - val_mae: 0.0817
#
# Epoch 00138: val_mae did not improve from 0.05202
# Epoch 139/1000
# 48/48 - 1s - loss: 7.5448e-05 - mae: 0.0154 - val_loss: 0.0121 - val_mae: 0.0852
#
# Epoch 00139: val_mae did not improve from 0.05202
# Epoch 140/1000
# 48/48 - 1s - loss: 7.9147e-05 - mae: 0.0158 - val_loss: 0.0119 - val_mae: 0.0844
#
# Epoch 00140: val_mae did not improve from 0.05202
# Epoch 141/1000
# 48/48 - 1s - loss: 7.8787e-05 - mae: 0.0157 - val_loss: 0.0118 - val_mae: 0.0840
#
# Epoch 00141: val_mae did not improve from 0.05202
# Epoch 142/1000
# 48/48 - 1s - loss: 6.8837e-05 - mae: 0.0147 - val_loss: 0.0119 - val_mae: 0.0843
#
# Epoch 00142: val_mae did not improve from 0.05202
# Epoch 143/1000
# 48/48 - 1s - loss: 7.2529e-05 - mae: 0.0151 - val_loss: 0.0118 - val_mae: 0.0837
#
# Epoch 00143: val_mae did not improve from 0.05202
# Epoch 144/1000
# 48/48 - 1s - loss: 6.8100e-05 - mae: 0.0146 - val_loss: 0.0119 - val_mae: 0.0842
#
# Epoch 00144: val_mae did not improve from 0.05202
# Epoch 145/1000
# 48/48 - 1s - loss: 7.5950e-05 - mae: 0.0154 - val_loss: 0.0130 - val_mae: 0.0893
#
# Epoch 00145: val_mae did not improve from 0.05202
# Epoch 146/1000
# 48/48 - 1s - loss: 8.9762e-05 - mae: 0.0167 - val_loss: 0.0116 - val_mae: 0.0832
#
# Epoch 00146: val_mae did not improve from 0.05202
# Epoch 147/1000
# 48/48 - 1s - loss: 7.7157e-05 - mae: 0.0156 - val_loss: 0.0120 - val_mae: 0.0845
#
# Epoch 00147: val_mae did not improve from 0.05202
# Epoch 148/1000
# 48/48 - 1s - loss: 7.5323e-05 - mae: 0.0154 - val_loss: 0.0122 - val_mae: 0.0856
#
# Epoch 00148: val_mae did not improve from 0.05202
# Epoch 149/1000
# 48/48 - 1s - loss: 8.5383e-05 - mae: 0.0164 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00149: val_mae did not improve from 0.05202
# Epoch 150/1000
# 48/48 - 1s - loss: 6.6899e-05 - mae: 0.0144 - val_loss: 0.0118 - val_mae: 0.0841
#
# Epoch 00150: val_mae did not improve from 0.05202
# Epoch 151/1000
# 48/48 - 1s - loss: 6.6546e-05 - mae: 0.0144 - val_loss: 0.0122 - val_mae: 0.0856
#
# Epoch 00151: val_mae did not improve from 0.05202
# Epoch 152/1000
# 48/48 - 1s - loss: 7.4738e-05 - mae: 0.0153 - val_loss: 0.0120 - val_mae: 0.0848
#
# Epoch 00152: val_mae did not improve from 0.05202
# Epoch 153/1000
# 48/48 - 1s - loss: 1.0650e-04 - mae: 0.0183 - val_loss: 0.0119 - val_mae: 0.0840
#
# Epoch 00153: val_mae did not improve from 0.05202
# Epoch 154/1000
# 48/48 - 1s - loss: 6.8496e-05 - mae: 0.0146 - val_loss: 0.0121 - val_mae: 0.0852
#
# Epoch 00154: val_mae did not improve from 0.05202
# Epoch 155/1000
# 48/48 - 1s - loss: 7.8883e-05 - mae: 0.0158 - val_loss: 0.0120 - val_mae: 0.0846
#
# Epoch 00155: val_mae did not improve from 0.05202
# Epoch 156/1000
# 48/48 - 1s - loss: 6.2413e-05 - mae: 0.0139 - val_loss: 0.0118 - val_mae: 0.0837
#
# Epoch 00156: val_mae did not improve from 0.05202
# Epoch 157/1000
# 48/48 - 1s - loss: 6.0429e-05 - mae: 0.0137 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00157: val_mae did not improve from 0.05202
# Epoch 158/1000
# 48/48 - 1s - loss: 6.2219e-05 - mae: 0.0139 - val_loss: 0.0122 - val_mae: 0.0855
#
# Epoch 00158: val_mae did not improve from 0.05202
# Epoch 159/1000
# 48/48 - 1s - loss: 7.0250e-05 - mae: 0.0148 - val_loss: 0.0120 - val_mae: 0.0845
#
# Epoch 00159: val_mae did not improve from 0.05202
# Epoch 160/1000
# 48/48 - 1s - loss: 6.9009e-05 - mae: 0.0147 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00160: val_mae did not improve from 0.05202
# Epoch 161/1000
# 48/48 - 1s - loss: 7.5403e-05 - mae: 0.0154 - val_loss: 0.0123 - val_mae: 0.0860
#
# Epoch 00161: val_mae did not improve from 0.05202
# Epoch 162/1000
# 48/48 - 1s - loss: 7.0105e-05 - mae: 0.0148 - val_loss: 0.0120 - val_mae: 0.0851
#
# Epoch 00162: val_mae did not improve from 0.05202
# Epoch 163/1000
# 48/48 - 1s - loss: 6.4551e-05 - mae: 0.0142 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00163: val_mae did not improve from 0.05202
# Epoch 164/1000
# 48/48 - 1s - loss: 7.2446e-05 - mae: 0.0151 - val_loss: 0.0123 - val_mae: 0.0860
# Epoch 00164: val_mae did not improve from 0.05202
# Epoch 165/1000
# 48/48 - 1s - loss: 6.2360e-05 - mae: 0.0140 - val_loss: 0.0123 - val_mae: 0.0859
#
# Epoch 00165: val_mae did not improve from 0.05202
# Epoch 166/1000
# 48/48 - 1s - loss: 6.0923e-05 - mae: 0.0137 - val_loss: 0.0123 - val_mae: 0.0858
#
# Epoch 00166: val_mae did not improve from 0.05202
# Epoch 167/1000
# 48/48 - 1s - loss: 6.0616e-05 - mae: 0.0137 - val_loss: 0.0120 - val_mae: 0.0846
#
# Epoch 00167: val_mae did not improve from 0.05202
# Epoch 168/1000
# 48/48 - 1s - loss: 9.0852e-05 - mae: 0.0170 - val_loss: 0.0127 - val_mae: 0.0875
#
# Epoch 00168: val_mae did not improve from 0.05202
# Epoch 169/1000
# 48/48 - 1s - loss: 7.1277e-05 - mae: 0.0150 - val_loss: 0.0119 - val_mae: 0.0840
#
# Epoch 00169: val_mae did not improve from 0.05202
# Epoch 170/1000
# 48/48 - 1s - loss: 6.7106e-05 - mae: 0.0145 - val_loss: 0.0119 - val_mae: 0.0842
#
# Epoch 00170: val_mae did not improve from 0.05202
# Epoch 171/1000
# 48/48 - 1s - loss: 6.7581e-05 - mae: 0.0146 - val_loss: 0.0121 - val_mae: 0.0851
#
# Epoch 00171: val_mae did not improve from 0.05202
# Epoch 172/1000
# 48/48 - 1s - loss: 5.7519e-05 - mae: 0.0134 - val_loss: 0.0123 - val_mae: 0.0858
#
# Epoch 00172: val_mae did not improve from 0.05202
# Epoch 173/1000
# 48/48 - 1s - loss: 5.8197e-05 - mae: 0.0135 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00173: val_mae did not improve from 0.05202
# Epoch 174/1000
# 48/48 - 1s - loss: 6.2844e-05 - mae: 0.0140 - val_loss: 0.0123 - val_mae: 0.0856
#
# Epoch 00174: val_mae did not improve from 0.05202
# Epoch 175/1000
# 48/48 - 1s - loss: 5.6166e-05 - mae: 0.0132 - val_loss: 0.0124 - val_mae: 0.0865
#
# Epoch 00175: val_mae did not improve from 0.05202
# Epoch 176/1000
# 48/48 - 1s - loss: 6.6318e-05 - mae: 0.0144 - val_loss: 0.0120 - val_mae: 0.0845
#
# Epoch 00176: val_mae did not improve from 0.05202
# Epoch 177/1000
# 48/48 - 1s - loss: 5.9621e-05 - mae: 0.0136 - val_loss: 0.0123 - val_mae: 0.0859
#
# Epoch 00177: val_mae did not improve from 0.05202
# Epoch 178/1000
# 48/48 - 1s - loss: 7.2660e-05 - mae: 0.0151 - val_loss: 0.0122 - val_mae: 0.0860
#
# Epoch 00178: val_mae did not improve from 0.05202
# Epoch 179/1000
# 48/48 - 1s - loss: 7.2352e-05 - mae: 0.0151 - val_loss: 0.0120 - val_mae: 0.0846
#
# Epoch 00179: val_mae did not improve from 0.05202
# Epoch 180/1000
# 48/48 - 1s - loss: 5.5610e-05 - mae: 0.0131 - val_loss: 0.0126 - val_mae: 0.0872
#
# Epoch 00180: val_mae did not improve from 0.05202
# Epoch 181/1000
# 48/48 - 1s - loss: 6.8152e-05 - mae: 0.0147 - val_loss: 0.0118 - val_mae: 0.0837
#
# Epoch 00181: val_mae did not improve from 0.05202
# Epoch 182/1000
# 48/48 - 1s - loss: 6.4561e-05 - mae: 0.0142 - val_loss: 0.0124 - val_mae: 0.0864
#
# Epoch 00182: val_mae did not improve from 0.05202
# Epoch 183/1000
# 48/48 - 1s - loss: 5.5846e-05 - mae: 0.0132 - val_loss: 0.0121 - val_mae: 0.0854
#
# Epoch 00183: val_mae did not improve from 0.05202
# Epoch 184/1000
# 48/48 - 1s - loss: 5.6629e-05 - mae: 0.0133 - val_loss: 0.0124 - val_mae: 0.0863
#
# Epoch 00184: val_mae did not improve from 0.05202
# Epoch 185/1000
# 48/48 - 1s - loss: 6.8337e-05 - mae: 0.0147 - val_loss: 0.0125 - val_mae: 0.0867
#
# Epoch 00185: val_mae did not improve from 0.05202
# Epoch 186/1000
# 48/48 - 1s - loss: 6.7975e-05 - mae: 0.0147 - val_loss: 0.0121 - val_mae: 0.0852
#
# Epoch 00186: val_mae did not improve from 0.05202
# Epoch 187/1000
# 48/48 - 1s - loss: 6.3529e-05 - mae: 0.0141 - val_loss: 0.0124 - val_mae: 0.0865
#
# Epoch 00187: val_mae did not improve from 0.05202
# Epoch 188/1000
# 48/48 - 1s - loss: 5.5600e-05 - mae: 0.0132 - val_loss: 0.0121 - val_mae: 0.0849
#
# Epoch 00188: val_mae did not improve from 0.05202
# Epoch 189/1000
# 48/48 - 1s - loss: 5.9946e-05 - mae: 0.0137 - val_loss: 0.0126 - val_mae: 0.0870
#
# Epoch 00189: val_mae did not improve from 0.05202
# Epoch 190/1000
# 48/48 - 1s - loss: 6.1485e-05 - mae: 0.0139 - val_loss: 0.0122 - val_mae: 0.0858
#
# Epoch 00190: val_mae did not improve from 0.05202
# Epoch 191/1000
# 48/48 - 1s - loss: 5.9099e-05 - mae: 0.0136 - val_loss: 0.0121 - val_mae: 0.0849
#
# Epoch 00191: val_mae did not improve from 0.05202
# Epoch 192/1000
# 48/48 - 1s - loss: 6.0292e-05 - mae: 0.0138 - val_loss: 0.0122 - val_mae: 0.0853
#
# Epoch 00192: val_mae did not improve from 0.05202
# Epoch 193/1000
# 48/48 - 1s - loss: 5.4792e-05 - mae: 0.0131 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00193: val_mae did not improve from 0.05202
# Epoch 194/1000
# 48/48 - 1s - loss: 6.4380e-05 - mae: 0.0143 - val_loss: 0.0122 - val_mae: 0.0853
#
# Epoch 00194: val_mae did not improve from 0.05202
# Epoch 195/1000
# 48/48 - 1s - loss: 5.9870e-05 - mae: 0.0137 - val_loss: 0.0121 - val_mae: 0.0851
#
# Epoch 00195: val_mae did not improve from 0.05202
# Epoch 196/1000
# 48/48 - 1s - loss: 6.0694e-05 - mae: 0.0138 - val_loss: 0.0123 - val_mae: 0.0861
#
# Epoch 00196: val_mae did not improve from 0.05202
# Epoch 197/1000
# 48/48 - 1s - loss: 5.6963e-05 - mae: 0.0133 - val_loss: 0.0124 - val_mae: 0.0863
#
# Epoch 00197: val_mae did not improve from 0.05202
# Epoch 198/1000
# 48/48 - 1s - loss: 5.3190e-05 - mae: 0.0129 - val_loss: 0.0126 - val_mae: 0.0872
#
# Epoch 00198: val_mae did not improve from 0.05202
# Epoch 199/1000
# 48/48 - 1s - loss: 7.3730e-05 - mae: 0.0153 - val_loss: 0.0121 - val_mae: 0.0852
#
# Epoch 00199: val_mae did not improve from 0.05202
# Epoch 200/1000
# 48/48 - 1s - loss: 5.5176e-05 - mae: 0.0131 - val_loss: 0.0121 - val_mae: 0.0850
#
# Epoch 00200: val_mae did not improve from 0.05202
# Epoch 201/1000
# 48/48 - 1s - loss: 4.8872e-05 - mae: 0.0123 - val_loss: 0.0122 - val_mae: 0.0858
#
# Epoch 00201: val_mae did not improve from 0.05202
# Epoch 202/1000
# 48/48 - 1s - loss: 7.2460e-05 - mae: 0.0152 - val_loss: 0.0119 - val_mae: 0.0847
#
# Epoch 00202: val_mae did not improve from 0.05202
# Epoch 203/1000
# 48/48 - 1s - loss: 5.9354e-05 - mae: 0.0137 - val_loss: 0.0124 - val_mae: 0.0865
#
# Epoch 00203: val_mae did not improve from 0.05202
# Epoch 204/1000
# 48/48 - 1s - loss: 5.6043e-05 - mae: 0.0132 - val_loss: 0.0122 - val_mae: 0.0854
#
# Epoch 00204: val_mae did not improve from 0.05202
# Epoch 205/1000
# 48/48 - 1s - loss: 5.5112e-05 - mae: 0.0131 - val_loss: 0.0122 - val_mae: 0.0855
#
# Epoch 00205: val_mae did not improve from 0.05202
# Epoch 206/1000
# 48/48 - 1s - loss: 4.7728e-05 - mae: 0.0121 - val_loss: 0.0125 - val_mae: 0.0868
#
# Epoch 00206: val_mae did not improve from 0.05202
# Epoch 207/1000
# 48/48 - 1s - loss: 5.5916e-05 - mae: 0.0133 - val_loss: 0.0123 - val_mae: 0.0856
#
# Epoch 00207: val_mae did not improve from 0.05202
# Epoch 208/1000
# 48/48 - 1s - loss: 5.0827e-05 - mae: 0.0126 - val_loss: 0.0125 - val_mae: 0.0867
#
# Epoch 00208: val_mae did not improve from 0.05202
# Epoch 209/1000
# 48/48 - 1s - loss: 6.2457e-05 - mae: 0.0139 - val_loss: 0.0126 - val_mae: 0.0874
#
# Epoch 00209: val_mae did not improve from 0.05202
# Epoch 210/1000
# 48/48 - 1s - loss: 5.7799e-05 - mae: 0.0134 - val_loss: 0.0122 - val_mae: 0.0855
#
# Epoch 00210: val_mae did not improve from 0.05202
# Epoch 211/1000
# 48/48 - 1s - loss: 6.2097e-05 - mae: 0.0140 - val_loss: 0.0121 - val_mae: 0.0855
#
# Epoch 00211: val_mae did not improve from 0.05202
# Epoch 212/1000
# 48/48 - 1s - loss: 5.4551e-05 - mae: 0.0131 - val_loss: 0.0124 - val_mae: 0.0864
#
# Epoch 00212: val_mae did not improve from 0.05202
# Epoch 00212: early stopping
