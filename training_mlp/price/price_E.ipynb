# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from math import sqrt
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.mlp import mlp_layer

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# import random

# random.seed(10)
# print(random.random())

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data
# Out:
#                            price  price_dayahead  gen_coal  gen_gas  \
# time
# 2015-01-01 00:00:00+00:00  64.92           48.10    4755.0   5196.0
# 2015-01-01 01:00:00+00:00  64.48           47.33    4581.0   4857.0
# 2015-01-01 02:00:00+00:00  59.32           42.27    4131.0   4314.0
# 2015-01-01 03:00:00+00:00  56.04           38.41    3840.0   4130.0
# 2015-01-01 04:00:00+00:00  53.63           35.72    3590.0   4038.0
# ...                          ...             ...       ...      ...
# 2018-12-31 18:00:00+00:00  77.02           68.85    2628.0   7634.0
# 2018-12-31 19:00:00+00:00  76.16           68.40    2566.0   7241.0
# 2018-12-31 20:00:00+00:00  74.30           66.88    2422.0   7025.0
# 2018-12-31 21:00:00+00:00  69.89           63.93    2293.0   6562.0
# 2018-12-31 22:00:00+00:00  69.88           64.27    2166.0   6926.0
#
#                            load_actual  gen_lig  gen_oil  gen_oth_renew  \
# time
# 2015-01-01 00:00:00+00:00      24382.0    328.0    158.0           71.0
# 2015-01-01 01:00:00+00:00      22734.0    323.0    157.0           73.0
# 2015-01-01 02:00:00+00:00      21286.0    254.0    160.0           75.0
# 2015-01-01 03:00:00+00:00      20264.0    187.0    156.0           74.0
# 2015-01-01 04:00:00+00:00      19905.0    178.0    156.0           74.0
# ...                                ...      ...      ...            ...
# 2018-12-31 18:00:00+00:00      30653.0      0.0    178.0           95.0
# 2018-12-31 19:00:00+00:00      29735.0      0.0    174.0           95.0
# 2018-12-31 20:00:00+00:00      28071.0      0.0    168.0           94.0
# 2018-12-31 21:00:00+00:00      25801.0      0.0    163.0           93.0
# 2018-12-31 22:00:00+00:00      24455.0      0.0    163.0           92.0
#
#                            pressure_Barcelona  pressure_Bilbao  ...  \
# time                                                            ...
# 2015-01-01 00:00:00+00:00              1035.0           1035.0  ...
# 2015-01-01 01:00:00+00:00              1036.0           1036.0  ...
# 2015-01-01 02:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 03:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 04:00:00+00:00              1037.0           1035.0  ...
# ...                                       ...              ...  ...
# 2018-12-31 18:00:00+00:00              1027.0           1033.0  ...
# 2018-12-31 19:00:00+00:00              1027.0           1034.0  ...
# 2018-12-31 20:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 21:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 22:00:00+00:00              1028.0           1034.0  ...
#
#                            wind_deg_Bilbao  clouds_all_Bilbao  gen_hyd_river  \
# time
# 2015-01-01 00:00:00+00:00            229.0                0.0         1009.0
# 2015-01-01 01:00:00+00:00            224.0                0.0          973.0
# 2015-01-01 02:00:00+00:00            225.0                0.0          949.0
# 2015-01-01 03:00:00+00:00            221.0                0.0          953.0
# 2015-01-01 04:00:00+00:00            224.0                0.0          952.0
# ...                                    ...                ...            ...
# 2018-12-31 18:00:00+00:00             57.0                0.0         1135.0
# 2018-12-31 19:00:00+00:00              0.0                0.0         1172.0
# 2018-12-31 20:00:00+00:00            140.0                0.0         1148.0
# 2018-12-31 21:00:00+00:00            120.0                0.0         1128.0
# 2018-12-31 22:00:00+00:00            100.0                0.0         1069.0
#
#                            wind_deg_Seville  wind_speed_Barcelona  \
# time
# 2015-01-01 00:00:00+00:00              21.0                   7.0
# 2015-01-01 01:00:00+00:00              27.0                   7.0
# 2015-01-01 02:00:00+00:00              27.0                   7.0
# 2015-01-01 03:00:00+00:00              27.0                   7.0
# 2015-01-01 04:00:00+00:00              57.0                   5.0
# ...                                     ...                   ...
# 2018-12-31 18:00:00+00:00              30.0                   1.0
# 2018-12-31 19:00:00+00:00              30.0                   3.0
# 2018-12-31 20:00:00+00:00              50.0                   4.0
# 2018-12-31 21:00:00+00:00              60.0                   5.0
# 2018-12-31 22:00:00+00:00              50.0                   5.0
#
#                            wind_speed_Valencia  wind_speed_Bilbao  gen_wind  \
# time
# 2015-01-01 00:00:00+00:00                  1.0                0.0    5890.0
# 2015-01-01 01:00:00+00:00                  0.0                1.0    5461.0
# 2015-01-01 02:00:00+00:00                  0.0                1.0    5238.0
# 2015-01-01 03:00:00+00:00                  0.0                1.0    4935.0
# 2015-01-01 04:00:00+00:00                  2.0                1.0    4618.0
# ...                                        ...                ...       ...
# 2018-12-31 18:00:00+00:00                  2.0                0.0    3113.0
# 2018-12-31 19:00:00+00:00                  1.0                1.0    3288.0
# 2018-12-31 20:00:00+00:00                  3.0                1.0    3503.0
# 2018-12-31 21:00:00+00:00                  2.0                1.0    3586.0
# 2018-12-31 22:00:00+00:00                  2.0                2.0    3651.0
#
#                            wind_speed_Madrid  gen_hyd_pump
# time
# 2015-01-01 00:00:00+00:00                1.0         920.0
# 2015-01-01 01:00:00+00:00                1.0        1164.0
# 2015-01-01 02:00:00+00:00                1.0        1503.0
# 2015-01-01 03:00:00+00:00                1.0        1826.0
# 2015-01-01 04:00:00+00:00                0.0        2109.0
# ...                                      ...           ...
# 2018-12-31 18:00:00+00:00                1.0           1.0
# 2018-12-31 19:00:00+00:00                1.0           1.0
# 2018-12-31 20:00:00+00:00                1.0          50.0
# 2018-12-31 21:00:00+00:00                2.0         108.0
# 2018-12-31 22:00:00+00:00                1.0         108.0
#
# [35063 rows x 26 columns]

# %%
print(data['price'].min())
print(data['price'].max())
# Out:
# 9.33
# 116.8

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
# for col in data.columns:
#     plt.hist(data[col], bins=20)
#     plt.title(col)
#     plt.show()
#     plt.close()

# %%
np.percentile(data['price'], 95)
# Out:
# 79.17

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 0
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### Price threshold

# %%
train_X_pm = train_X[:, 0, feature_idx]
print(train_X_pm.shape)

val_X_pm = val_X[:, 0, feature_idx]
print(val_X_pm.shape)

test_X_pm = test_X[:, 0, feature_idx]
print(test_X_pm.shape)
# Out:
# (24486,)
# (5247,)
# (5247,)

# %%
percentile = 95

merged_array = np.concatenate((train_X_pm, val_X_pm, test_X_pm))

percentile_pm = np.percentile(merged_array, percentile)

print("{}th Percentile of Daily Rain:".format(percentile), percentile_pm)
# Out:
# 95th Percentile of Daily Rain: 0.7037105569454176

# %% [markdown]
# ### train_X_filter

# %%
train_X_extreme = train_X[train_X_pm > percentile_pm]
print(train_X_extreme.shape)

train_y_extreme = train_y[train_X_pm > percentile_pm]
print(train_y_extreme.shape)
# Out:
# (696, 72, 26)
# (696, 12)

# %%
train_X_normal = train_X[train_X_pm <= percentile_pm]
print(train_X_normal.shape)

train_y_normal = train_y[train_X_pm <= percentile_pm]
print(train_y_normal.shape)
# Out:
# (23790, 72, 26)
# (23790, 12)

# %% [markdown]
# ### val_X_filter

# %%
val_X_extreme = val_X[val_X_pm > percentile_pm]
print(val_X_extreme.shape)

val_y_extreme = val_y[val_X_pm > percentile_pm]
print(val_y_extreme.shape)
# Out:
# (55, 72, 26)
# (55, 12)

# %%
val_X_normal = val_X[val_X_pm <= percentile_pm]
print(val_X_normal.shape)

val_y_normal = val_y[val_X_pm <= percentile_pm]
print(val_y_normal.shape)
# Out:
# (5192, 72, 26)
# (5192, 12)

# %% [markdown]
# ### test_X_filter

# %%
test_X_extreme = test_X[test_X_pm > percentile_pm]
print(test_X_extreme.shape)

test_y_extreme = test_y[test_X_pm > percentile_pm]
print(test_y_extreme.shape)
# Out:
# (998, 72, 26)
# (998, 12)

# %%
test_X_normal = test_X[test_X_pm <= percentile_pm]
print(test_X_normal.shape)

test_y_normal = test_y[test_X_pm <= percentile_pm]
print(test_y_normal.shape)
# Out:
# (4249, 72, 26)
# (4249, 12)

# %% [markdown]
# ### Model & training

# %%
# plt.hist(train_y[:,0])

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0.0  # 0.1
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

# %%
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
#                                                           decay_steps=decay_steps,
#                                                           decay_rate=decay_rate)

# model.compile(optimizer=Adam(learning_rate=lr_schedule),
#               loss='mse',
#               metrics=['mae']
#              )

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )


es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models/price_E.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True
                    )


model.fit(train_X_extreme, train_y_extreme,
          validation_data=(val_X_extreme, val_y_extreme),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc]
         )
# Out:
# 2024-02-02 15:23:01.567704: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-02-02 15:23:01.568491: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1700105000 Hz
# Epoch 1/1000
# 2024-02-02 15:23:02.983909: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2/2 - 3s - loss: 0.4167 - mae: 0.6213 - val_loss: 0.2612 - val_mae: 0.4920
#
# Epoch 00001: val_mae improved from inf to 0.49204, saving model to ../../saved_models/price_E.h5
# Epoch 2/1000
# 2/2 - 0s - loss: 0.3372 - mae: 0.5553 - val_loss: 0.1591 - val_mae: 0.3755
#
# Epoch 00002: val_mae improved from 0.49204 to 0.37548, saving model to ../../saved_models/price_E.h5
# Epoch 3/1000
# 2/2 - 0s - loss: 0.2119 - mae: 0.4260 - val_loss: 0.0339 - val_mae: 0.1451
#
# Epoch 00003: val_mae improved from 0.37548 to 0.14511, saving model to ../../saved_models/price_E.h5
# Epoch 4/1000
# 2/2 - 0s - loss: 0.0582 - mae: 0.1954 - val_loss: 0.1707 - val_mae: 0.3714
#
# Epoch 00004: val_mae did not improve from 0.14511
# Epoch 5/1000
# 2/2 - 0s - loss: 0.1059 - mae: 0.2788 - val_loss: 0.1103 - val_mae: 0.3006
#
# Epoch 00005: val_mae did not improve from 0.14511
# Epoch 6/1000
# 2/2 - 0s - loss: 0.0543 - mae: 0.1920 - val_loss: 0.0298 - val_mae: 0.1349
#
# Epoch 00006: val_mae improved from 0.14511 to 0.13494, saving model to ../../saved_models/price_E.h5
# Epoch 7/1000
# 2/2 - 0s - loss: 0.0271 - mae: 0.1319 - val_loss: 0.0176 - val_mae: 0.1003
#
# Epoch 00007: val_mae improved from 0.13494 to 0.10029, saving model to ../../saved_models/price_E.h5
# Epoch 8/1000
# 2/2 - 0s - loss: 0.0421 - mae: 0.1652 - val_loss: 0.0198 - val_mae: 0.1087
#
# Epoch 00008: val_mae did not improve from 0.10029
# Epoch 9/1000
# 2/2 - 0s - loss: 0.0457 - mae: 0.1725 - val_loss: 0.0193 - val_mae: 0.1040
#
# Epoch 00009: val_mae did not improve from 0.10029
# Epoch 10/1000
# 2/2 - 0s - loss: 0.0343 - mae: 0.1471 - val_loss: 0.0356 - val_mae: 0.1482
#
# Epoch 00010: val_mae did not improve from 0.10029
# Epoch 11/1000
# 2/2 - 0s - loss: 0.0314 - mae: 0.1423 - val_loss: 0.0556 - val_mae: 0.1980
#
# Epoch 00011: val_mae did not improve from 0.10029
# Epoch 12/1000
# 2/2 - 0s - loss: 0.0342 - mae: 0.1497 - val_loss: 0.0409 - val_mae: 0.1662
#
# Epoch 00012: val_mae did not improve from 0.10029
# Epoch 13/1000
# 2/2 - 0s - loss: 0.0261 - mae: 0.1301 - val_loss: 0.0229 - val_mae: 0.1161
#
# Epoch 00013: val_mae did not improve from 0.10029
# Epoch 14/1000
# 2/2 - 0s - loss: 0.0240 - mae: 0.1247 - val_loss: 0.0188 - val_mae: 0.1054
#
# Epoch 00014: val_mae did not improve from 0.10029
# Epoch 15/1000
# 2/2 - 0s - loss: 0.0268 - mae: 0.1315 - val_loss: 0.0211 - val_mae: 0.1128
#
# Epoch 00015: val_mae did not improve from 0.10029
# Epoch 16/1000
# 2/2 - 0s - loss: 0.0250 - mae: 0.1279 - val_loss: 0.0299 - val_mae: 0.1378
#
# Epoch 00016: val_mae did not improve from 0.10029
# Epoch 17/1000
# 2/2 - 0s - loss: 0.0228 - mae: 0.1222 - val_loss: 0.0422 - val_mae: 0.1695
#
# Epoch 00017: val_mae did not improve from 0.10029
# Epoch 18/1000
# 2/2 - 0s - loss: 0.0233 - mae: 0.1231 - val_loss: 0.0390 - val_mae: 0.1628
#
# Epoch 00018: val_mae did not improve from 0.10029
# Epoch 19/1000
# 2/2 - 0s - loss: 0.0211 - mae: 0.1173 - val_loss: 0.0264 - val_mae: 0.1292
#
# Epoch 00019: val_mae did not improve from 0.10029
# Epoch 20/1000
# 2/2 - 0s - loss: 0.0193 - mae: 0.1135 - val_loss: 0.0209 - val_mae: 0.1124
#
# Epoch 00020: val_mae did not improve from 0.10029
# Epoch 21/1000
# 2/2 - 0s - loss: 0.0195 - mae: 0.1138 - val_loss: 0.0244 - val_mae: 0.1238
#
# Epoch 00021: val_mae did not improve from 0.10029
# Epoch 22/1000
# 2/2 - 0s - loss: 0.0184 - mae: 0.1106 - val_loss: 0.0335 - val_mae: 0.1502
#
# Epoch 00022: val_mae did not improve from 0.10029
# Epoch 23/1000
# 2/2 - 0s - loss: 0.0186 - mae: 0.1106 - val_loss: 0.0331 - val_mae: 0.1495
#
# Epoch 00023: val_mae did not improve from 0.10029
# Epoch 24/1000
# 2/2 - 0s - loss: 0.0180 - mae: 0.1088 - val_loss: 0.0249 - val_mae: 0.1262
#
# Epoch 00024: val_mae did not improve from 0.10029
# Epoch 25/1000
# 2/2 - 0s - loss: 0.0176 - mae: 0.1081 - val_loss: 0.0230 - val_mae: 0.1208
#
# Epoch 00025: val_mae did not improve from 0.10029
# Epoch 26/1000
# 2/2 - 0s - loss: 0.0172 - mae: 0.1071 - val_loss: 0.0293 - val_mae: 0.1404
#
# Epoch 00026: val_mae did not improve from 0.10029
# Epoch 27/1000
# 2/2 - 0s - loss: 0.0164 - mae: 0.1044 - val_loss: 0.0342 - val_mae: 0.1547
#
# Epoch 00027: val_mae did not improve from 0.10029
# Epoch 28/1000
# 2/2 - 0s - loss: 0.0164 - mae: 0.1043 - val_loss: 0.0299 - val_mae: 0.1424
#
# Epoch 00028: val_mae did not improve from 0.10029
# Epoch 29/1000
# 2/2 - 0s - loss: 0.0159 - mae: 0.1028 - val_loss: 0.0258 - val_mae: 0.1299
#
# Epoch 00029: val_mae did not improve from 0.10029
# Epoch 30/1000
# 2/2 - 0s - loss: 0.0157 - mae: 0.1024 - val_loss: 0.0284 - val_mae: 0.1377
#
# Epoch 00030: val_mae did not improve from 0.10029
# Epoch 31/1000
# 2/2 - 0s - loss: 0.0153 - mae: 0.1009 - val_loss: 0.0327 - val_mae: 0.1500
#
# Epoch 00031: val_mae did not improve from 0.10029
# Epoch 32/1000
# 2/2 - 0s - loss: 0.0151 - mae: 0.1001 - val_loss: 0.0302 - val_mae: 0.1430
#
# Epoch 00032: val_mae did not improve from 0.10029
# Epoch 33/1000
# 2/2 - 0s - loss: 0.0146 - mae: 0.0988 - val_loss: 0.0274 - val_mae: 0.1351
#
# Epoch 00033: val_mae did not improve from 0.10029
# Epoch 34/1000
# 2/2 - 0s - loss: 0.0144 - mae: 0.0981 - val_loss: 0.0306 - val_mae: 0.1453
#
# Epoch 00034: val_mae did not improve from 0.10029
# Epoch 35/1000
# 2/2 - 0s - loss: 0.0142 - mae: 0.0972 - val_loss: 0.0299 - val_mae: 0.1438
#
# Epoch 00035: val_mae did not improve from 0.10029
# Epoch 36/1000
# 2/2 - 0s - loss: 0.0140 - mae: 0.0964 - val_loss: 0.0272 - val_mae: 0.1362
#
# Epoch 00036: val_mae did not improve from 0.10029
# Epoch 37/1000
# 2/2 - 0s - loss: 0.0140 - mae: 0.0963 - val_loss: 0.0295 - val_mae: 0.1438
#
# Epoch 00037: val_mae did not improve from 0.10029
# Epoch 38/1000
# 2/2 - 0s - loss: 0.0137 - mae: 0.0953 - val_loss: 0.0323 - val_mae: 0.1527
#
# Epoch 00038: val_mae did not improve from 0.10029
# Epoch 39/1000
# 2/2 - 0s - loss: 0.0135 - mae: 0.0944 - val_loss: 0.0323 - val_mae: 0.1530
#
# Epoch 00039: val_mae did not improve from 0.10029
# Epoch 40/1000
# 2/2 - 0s - loss: 0.0133 - mae: 0.0936 - val_loss: 0.0249 - val_mae: 0.1300
#
# Epoch 00040: val_mae did not improve from 0.10029
# Epoch 41/1000
# 2/2 - 0s - loss: 0.0133 - mae: 0.0939 - val_loss: 0.0291 - val_mae: 0.1435
#
# Epoch 00041: val_mae did not improve from 0.10029
# Epoch 42/1000
# 2/2 - 0s - loss: 0.0130 - mae: 0.0927 - val_loss: 0.0298 - val_mae: 0.1455
#
# Epoch 00042: val_mae did not improve from 0.10029
# Epoch 43/1000
# 2/2 - 0s - loss: 0.0126 - mae: 0.0916 - val_loss: 0.0223 - val_mae: 0.1207
#
# Epoch 00043: val_mae did not improve from 0.10029
# Epoch 44/1000
# 2/2 - 0s - loss: 0.0128 - mae: 0.0923 - val_loss: 0.0291 - val_mae: 0.1433
#
# Epoch 00044: val_mae did not improve from 0.10029
# Epoch 45/1000
# 2/2 - 0s - loss: 0.0124 - mae: 0.0904 - val_loss: 0.0298 - val_mae: 0.1456
#
# Epoch 00045: val_mae did not improve from 0.10029
# Epoch 46/1000
# 2/2 - 0s - loss: 0.0123 - mae: 0.0897 - val_loss: 0.0212 - val_mae: 0.1169
#
# Epoch 00046: val_mae did not improve from 0.10029
# Epoch 47/1000
# 2/2 - 0s - loss: 0.0121 - mae: 0.0898 - val_loss: 0.0282 - val_mae: 0.1407
#
# Epoch 00047: val_mae did not improve from 0.10029
# Epoch 48/1000
# 2/2 - 0s - loss: 0.0120 - mae: 0.0886 - val_loss: 0.0268 - val_mae: 0.1365
#
# Epoch 00048: val_mae did not improve from 0.10029
# Epoch 49/1000
# 2/2 - 0s - loss: 0.0116 - mae: 0.0872 - val_loss: 0.0185 - val_mae: 0.1071
#
# Epoch 00049: val_mae did not improve from 0.10029
# Epoch 50/1000
# 2/2 - 0s - loss: 0.0118 - mae: 0.0885 - val_loss: 0.0247 - val_mae: 0.1301
#
# Epoch 00050: val_mae did not improve from 0.10029
# Epoch 51/1000
# 2/2 - 0s - loss: 0.0111 - mae: 0.0852 - val_loss: 0.0253 - val_mae: 0.1327
#
# Epoch 00051: val_mae did not improve from 0.10029
# Epoch 52/1000
# 2/2 - 0s - loss: 0.0109 - mae: 0.0843 - val_loss: 0.0198 - val_mae: 0.1134
#
# Epoch 00052: val_mae did not improve from 0.10029
# Epoch 53/1000
# 2/2 - 0s - loss: 0.0107 - mae: 0.0838 - val_loss: 0.0218 - val_mae: 0.1211
#
# Epoch 00053: val_mae did not improve from 0.10029
# Epoch 54/1000
# 2/2 - 0s - loss: 0.0104 - mae: 0.0819 - val_loss: 0.0211 - val_mae: 0.1190
#
# Epoch 00054: val_mae did not improve from 0.10029
# Epoch 55/1000
# 2/2 - 0s - loss: 0.0100 - mae: 0.0806 - val_loss: 0.0196 - val_mae: 0.1137
#
# Epoch 00055: val_mae did not improve from 0.10029
# Epoch 56/1000
# 2/2 - 0s - loss: 0.0098 - mae: 0.0794 - val_loss: 0.0227 - val_mae: 0.1249
#
# Epoch 00056: val_mae did not improve from 0.10029
# Epoch 57/1000
# 2/2 - 0s - loss: 0.0095 - mae: 0.0776 - val_loss: 0.0196 - val_mae: 0.1130
#
# Epoch 00057: val_mae did not improve from 0.10029
# Epoch 58/1000
# 2/2 - 0s - loss: 0.0091 - mae: 0.0765 - val_loss: 0.0200 - val_mae: 0.1146
#
# Epoch 00058: val_mae did not improve from 0.10029
# Epoch 59/1000
# 2/2 - 0s - loss: 0.0087 - mae: 0.0746 - val_loss: 0.0205 - val_mae: 0.1162
#
# Epoch 00059: val_mae did not improve from 0.10029
# Epoch 60/1000
# 2/2 - 0s - loss: 0.0084 - mae: 0.0729 - val_loss: 0.0182 - val_mae: 0.1067
#
# Epoch 00060: val_mae did not improve from 0.10029
# Epoch 61/1000
# 2/2 - 0s - loss: 0.0081 - mae: 0.0714 - val_loss: 0.0203 - val_mae: 0.1151
#
# Epoch 00061: val_mae did not improve from 0.10029
# Epoch 62/1000
# 2/2 - 0s - loss: 0.0079 - mae: 0.0700 - val_loss: 0.0169 - val_mae: 0.1009
#
# Epoch 00062: val_mae did not improve from 0.10029
# Epoch 63/1000
# 2/2 - 0s - loss: 0.0076 - mae: 0.0689 - val_loss: 0.0182 - val_mae: 0.1063
#
# Epoch 00063: val_mae did not improve from 0.10029
# Epoch 64/1000
# 2/2 - 0s - loss: 0.0073 - mae: 0.0672 - val_loss: 0.0162 - val_mae: 0.0976
#
# Epoch 00064: val_mae improved from 0.10029 to 0.09758, saving model to ../../saved_models/price_E.h5
# Epoch 65/1000
# 2/2 - 0s - loss: 0.0071 - mae: 0.0666 - val_loss: 0.0182 - val_mae: 0.1061
#
# Epoch 00065: val_mae did not improve from 0.09758
# Epoch 66/1000
# 2/2 - 0s - loss: 0.0069 - mae: 0.0650 - val_loss: 0.0149 - val_mae: 0.0920
#
# Epoch 00066: val_mae improved from 0.09758 to 0.09195, saving model to ../../saved_models/price_E.h5
# Epoch 67/1000
# 2/2 - 0s - loss: 0.0067 - mae: 0.0654 - val_loss: 0.0209 - val_mae: 0.1175
#
# Epoch 00067: val_mae did not improve from 0.09195
# Epoch 68/1000
# 2/2 - 0s - loss: 0.0068 - mae: 0.0648 - val_loss: 0.0144 - val_mae: 0.0900
#
# Epoch 00068: val_mae improved from 0.09195 to 0.08997, saving model to ../../saved_models/price_E.h5
# Epoch 69/1000
# 2/2 - 0s - loss: 0.0064 - mae: 0.0638 - val_loss: 0.0202 - val_mae: 0.1145
#
# Epoch 00069: val_mae did not improve from 0.08997
# Epoch 70/1000
# 2/2 - 0s - loss: 0.0064 - mae: 0.0623 - val_loss: 0.0131 - val_mae: 0.0842
#
# Epoch 00070: val_mae improved from 0.08997 to 0.08417, saving model to ../../saved_models/price_E.h5
# Epoch 71/1000
# 2/2 - 0s - loss: 0.0063 - mae: 0.0637 - val_loss: 0.0211 - val_mae: 0.1179
#
# Epoch 00071: val_mae did not improve from 0.08417
# Epoch 72/1000
# 2/2 - 0s - loss: 0.0062 - mae: 0.0613 - val_loss: 0.0121 - val_mae: 0.0796
#
# Epoch 00072: val_mae improved from 0.08417 to 0.07965, saving model to ../../saved_models/price_E.h5
# Epoch 73/1000
# 2/2 - 0s - loss: 0.0063 - mae: 0.0640 - val_loss: 0.0183 - val_mae: 0.1074
#
# Epoch 00073: val_mae did not improve from 0.07965
# Epoch 74/1000
# 2/2 - 0s - loss: 0.0056 - mae: 0.0588 - val_loss: 0.0145 - val_mae: 0.0913
#
# Epoch 00074: val_mae did not improve from 0.07965
# Epoch 75/1000
# 2/2 - 0s - loss: 0.0055 - mae: 0.0588 - val_loss: 0.0183 - val_mae: 0.1075
#
# Epoch 00075: val_mae did not improve from 0.07965
# Epoch 76/1000
# 2/2 - 0s - loss: 0.0054 - mae: 0.0577 - val_loss: 0.0141 - val_mae: 0.0894
#
# Epoch 00076: val_mae did not improve from 0.07965
# Epoch 77/1000
# 2/2 - 0s - loss: 0.0052 - mae: 0.0576 - val_loss: 0.0165 - val_mae: 0.1001
#
# Epoch 00077: val_mae did not improve from 0.07965
# Epoch 78/1000
# 2/2 - 0s - loss: 0.0051 - mae: 0.0564 - val_loss: 0.0132 - val_mae: 0.0858
#
# Epoch 00078: val_mae did not improve from 0.07965
# Epoch 79/1000
# 2/2 - 0s - loss: 0.0051 - mae: 0.0570 - val_loss: 0.0175 - val_mae: 0.1048
#
# Epoch 00079: val_mae did not improve from 0.07965
# Epoch 80/1000
# 2/2 - 0s - loss: 0.0050 - mae: 0.0554 - val_loss: 0.0142 - val_mae: 0.0905
#
# Epoch 00080: val_mae did not improve from 0.07965
# Epoch 81/1000
# 2/2 - 0s - loss: 0.0047 - mae: 0.0546 - val_loss: 0.0149 - val_mae: 0.0935
#
# Epoch 00081: val_mae did not improve from 0.07965
# Epoch 82/1000
# 2/2 - 0s - loss: 0.0046 - mae: 0.0536 - val_loss: 0.0152 - val_mae: 0.0954
#
# Epoch 00082: val_mae did not improve from 0.07965
# Epoch 83/1000
# 2/2 - 0s - loss: 0.0046 - mae: 0.0534 - val_loss: 0.0135 - val_mae: 0.0879
#
# Epoch 00083: val_mae did not improve from 0.07965
# Epoch 84/1000
# 2/2 - 0s - loss: 0.0044 - mae: 0.0527 - val_loss: 0.0160 - val_mae: 0.0991
#
# Epoch 00084: val_mae did not improve from 0.07965
# Epoch 85/1000
# 2/2 - 0s - loss: 0.0045 - mae: 0.0526 - val_loss: 0.0105 - val_mae: 0.0742
#
# Epoch 00085: val_mae improved from 0.07965 to 0.07422, saving model to ../../saved_models/price_E.h5
# Epoch 86/1000
# 2/2 - 0s - loss: 0.0046 - mae: 0.0542 - val_loss: 0.0165 - val_mae: 0.1014
#
# Epoch 00086: val_mae did not improve from 0.07422
# Epoch 87/1000
# 2/2 - 0s - loss: 0.0045 - mae: 0.0529 - val_loss: 0.0111 - val_mae: 0.0773
#
# Epoch 00087: val_mae did not improve from 0.07422
# Epoch 88/1000
# 2/2 - 0s - loss: 0.0043 - mae: 0.0523 - val_loss: 0.0140 - val_mae: 0.0907
#
# Epoch 00088: val_mae did not improve from 0.07422
# Epoch 89/1000
# 2/2 - 0s - loss: 0.0041 - mae: 0.0510 - val_loss: 0.0121 - val_mae: 0.0824
#
# Epoch 00089: val_mae did not improve from 0.07422
# Epoch 90/1000
# 2/2 - 0s - loss: 0.0040 - mae: 0.0502 - val_loss: 0.0121 - val_mae: 0.0825
#
# Epoch 00090: val_mae did not improve from 0.07422
# Epoch 91/1000
# 2/2 - 0s - loss: 0.0039 - mae: 0.0497 - val_loss: 0.0117 - val_mae: 0.0808
#
# Epoch 00091: val_mae did not improve from 0.07422
# Epoch 92/1000
# 2/2 - 0s - loss: 0.0039 - mae: 0.0494 - val_loss: 0.0126 - val_mae: 0.0850
#
# Epoch 00092: val_mae did not improve from 0.07422
# Epoch 93/1000
# 2/2 - 0s - loss: 0.0038 - mae: 0.0489 - val_loss: 0.0121 - val_mae: 0.0828
#
# Epoch 00093: val_mae did not improve from 0.07422
# Epoch 94/1000
# 2/2 - 0s - loss: 0.0037 - mae: 0.0485 - val_loss: 0.0109 - val_mae: 0.0779
#
# Epoch 00094: val_mae did not improve from 0.07422
# Epoch 95/1000
# 2/2 - 0s - loss: 0.0037 - mae: 0.0484 - val_loss: 0.0117 - val_mae: 0.0817
#
# Epoch 00095: val_mae did not improve from 0.07422
# Epoch 96/1000
# 2/2 - 0s - loss: 0.0036 - mae: 0.0477 - val_loss: 0.0125 - val_mae: 0.0856
#
# Epoch 00096: val_mae did not improve from 0.07422
# Epoch 97/1000
# 2/2 - 0s - loss: 0.0036 - mae: 0.0474 - val_loss: 0.0100 - val_mae: 0.0749
#
# Epoch 00097: val_mae did not improve from 0.07422
# Epoch 98/1000
# 2/2 - 0s - loss: 0.0036 - mae: 0.0481 - val_loss: 0.0135 - val_mae: 0.0902
#
# Epoch 00098: val_mae did not improve from 0.07422
# Epoch 99/1000
# 2/2 - 0s - loss: 0.0036 - mae: 0.0478 - val_loss: 0.0109 - val_mae: 0.0789
#
# Epoch 00099: val_mae did not improve from 0.07422
# Epoch 100/1000
# 2/2 - 0s - loss: 0.0035 - mae: 0.0470 - val_loss: 0.0105 - val_mae: 0.0774
#
# Epoch 00100: val_mae did not improve from 0.07422
# Epoch 101/1000
# 2/2 - 0s - loss: 0.0034 - mae: 0.0463 - val_loss: 0.0097 - val_mae: 0.0738
#
# Epoch 00101: val_mae improved from 0.07422 to 0.07378, saving model to ../../saved_models/price_E.h5
# Epoch 102/1000
# 2/2 - 0s - loss: 0.0034 - mae: 0.0467 - val_loss: 0.0102 - val_mae: 0.0760
#
# Epoch 00102: val_mae did not improve from 0.07378
# Epoch 103/1000
# 2/2 - 0s - loss: 0.0033 - mae: 0.0461 - val_loss: 0.0130 - val_mae: 0.0886
#
# Epoch 00103: val_mae did not improve from 0.07378
# Epoch 104/1000
# 2/2 - 0s - loss: 0.0034 - mae: 0.0467 - val_loss: 0.0089 - val_mae: 0.0706
#
# Epoch 00104: val_mae improved from 0.07378 to 0.07064, saving model to ../../saved_models/price_E.h5
# Epoch 105/1000
# 2/2 - 0s - loss: 0.0034 - mae: 0.0466 - val_loss: 0.0117 - val_mae: 0.0828
#
# Epoch 00105: val_mae did not improve from 0.07064
# Epoch 106/1000
# 2/2 - 0s - loss: 0.0033 - mae: 0.0459 - val_loss: 0.0107 - val_mae: 0.0784
#
# Epoch 00106: val_mae did not improve from 0.07064
# Epoch 107/1000
# 2/2 - 0s - loss: 0.0031 - mae: 0.0447 - val_loss: 0.0095 - val_mae: 0.0732
#
# Epoch 00107: val_mae did not improve from 0.07064
# Epoch 108/1000
# 2/2 - 0s - loss: 0.0031 - mae: 0.0448 - val_loss: 0.0114 - val_mae: 0.0818
#
# Epoch 00108: val_mae did not improve from 0.07064
# Epoch 109/1000
# 2/2 - 0s - loss: 0.0031 - mae: 0.0446 - val_loss: 0.0109 - val_mae: 0.0799
#
# Epoch 00109: val_mae did not improve from 0.07064
# Epoch 110/1000
# 2/2 - 0s - loss: 0.0030 - mae: 0.0439 - val_loss: 0.0095 - val_mae: 0.0737
#
# Epoch 00110: val_mae did not improve from 0.07064
# Epoch 111/1000
# 2/2 - 0s - loss: 0.0030 - mae: 0.0437 - val_loss: 0.0106 - val_mae: 0.0781
#
# Epoch 00111: val_mae did not improve from 0.07064
# Epoch 112/1000
# 2/2 - 0s - loss: 0.0030 - mae: 0.0438 - val_loss: 0.0103 - val_mae: 0.0766
#
# Epoch 00112: val_mae did not improve from 0.07064
# Epoch 113/1000
# 2/2 - 0s - loss: 0.0029 - mae: 0.0432 - val_loss: 0.0082 - val_mae: 0.0679
# Epoch 00113: val_mae improved from 0.07064 to 0.06790, saving model to ../../saved_models/price_E.h5
# Epoch 114/1000
# 2/2 - 0s - loss: 0.0030 - mae: 0.0443 - val_loss: 0.0110 - val_mae: 0.0801
#
# Epoch 00114: val_mae did not improve from 0.06790
# Epoch 115/1000
# 2/2 - 0s - loss: 0.0030 - mae: 0.0435 - val_loss: 0.0093 - val_mae: 0.0729
#
# Epoch 00115: val_mae did not improve from 0.06790
# Epoch 116/1000
# 2/2 - 0s - loss: 0.0029 - mae: 0.0431 - val_loss: 0.0086 - val_mae: 0.0699
#
# Epoch 00116: val_mae did not improve from 0.06790
# Epoch 117/1000
# 2/2 - 0s - loss: 0.0029 - mae: 0.0434 - val_loss: 0.0114 - val_mae: 0.0819
#
# Epoch 00117: val_mae did not improve from 0.06790
# Epoch 118/1000
# 2/2 - 0s - loss: 0.0029 - mae: 0.0431 - val_loss: 0.0092 - val_mae: 0.0722
#
# Epoch 00118: val_mae did not improve from 0.06790
# Epoch 119/1000
# 2/2 - 0s - loss: 0.0027 - mae: 0.0417 - val_loss: 0.0093 - val_mae: 0.0729
#
# Epoch 00119: val_mae did not improve from 0.06790
# Epoch 120/1000
# 2/2 - 0s - loss: 0.0027 - mae: 0.0414 - val_loss: 0.0097 - val_mae: 0.0747
#
# Epoch 00120: val_mae did not improve from 0.06790
# Epoch 121/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0411 - val_loss: 0.0089 - val_mae: 0.0707
#
# Epoch 00121: val_mae did not improve from 0.06790
# Epoch 122/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0410 - val_loss: 0.0096 - val_mae: 0.0739
#
# Epoch 00122: val_mae did not improve from 0.06790
# Epoch 123/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0410 - val_loss: 0.0091 - val_mae: 0.0721
#
# Epoch 00123: val_mae did not improve from 0.06790
# Epoch 124/1000
# 2/2 - 0s - loss: 0.0025 - mae: 0.0404 - val_loss: 0.0090 - val_mae: 0.0715
#
# Epoch 00124: val_mae did not improve from 0.06790
# Epoch 125/1000
# 2/2 - 0s - loss: 0.0025 - mae: 0.0402 - val_loss: 0.0100 - val_mae: 0.0756
#
# Epoch 00125: val_mae did not improve from 0.06790
# Epoch 126/1000
# 2/2 - 0s - loss: 0.0025 - mae: 0.0401 - val_loss: 0.0084 - val_mae: 0.0691
#
# Epoch 00126: val_mae did not improve from 0.06790
# Epoch 127/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0405 - val_loss: 0.0082 - val_mae: 0.0683
#
# Epoch 00127: val_mae did not improve from 0.06790
# Epoch 128/1000
# 2/2 - 0s - loss: 0.0025 - mae: 0.0403 - val_loss: 0.0107 - val_mae: 0.0791
#
# Epoch 00128: val_mae did not improve from 0.06790
# Epoch 129/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0408 - val_loss: 0.0092 - val_mae: 0.0722
#
# Epoch 00129: val_mae did not improve from 0.06790
# Epoch 130/1000
# 2/2 - 0s - loss: 0.0024 - mae: 0.0390 - val_loss: 0.0080 - val_mae: 0.0671
#
# Epoch 00130: val_mae improved from 0.06790 to 0.06711, saving model to ../../saved_models/price_E.h5
# Epoch 131/1000
# 2/2 - 0s - loss: 0.0024 - mae: 0.0394 - val_loss: 0.0109 - val_mae: 0.0795
#
# Epoch 00131: val_mae did not improve from 0.06711
# Epoch 132/1000
# 2/2 - 0s - loss: 0.0026 - mae: 0.0402 - val_loss: 0.0089 - val_mae: 0.0714
#
# Epoch 00132: val_mae did not improve from 0.06711
# Epoch 133/1000
# 2/2 - 0s - loss: 0.0024 - mae: 0.0390 - val_loss: 0.0085 - val_mae: 0.0693
#
# Epoch 00133: val_mae did not improve from 0.06711
# Epoch 134/1000
# 2/2 - 0s - loss: 0.0024 - mae: 0.0388 - val_loss: 0.0110 - val_mae: 0.0797
#
# Epoch 00134: val_mae did not improve from 0.06711
# Epoch 135/1000
# 2/2 - 0s - loss: 0.0025 - mae: 0.0398 - val_loss: 0.0092 - val_mae: 0.0724
#
# Epoch 00135: val_mae did not improve from 0.06711
# Epoch 136/1000
# 2/2 - 0s - loss: 0.0023 - mae: 0.0380 - val_loss: 0.0087 - val_mae: 0.0702
#
# Epoch 00136: val_mae did not improve from 0.06711
# Epoch 137/1000
# 2/2 - 0s - loss: 0.0022 - mae: 0.0377 - val_loss: 0.0093 - val_mae: 0.0726
#
# Epoch 00137: val_mae did not improve from 0.06711
# Epoch 138/1000
# 2/2 - 0s - loss: 0.0022 - mae: 0.0372 - val_loss: 0.0085 - val_mae: 0.0692
#
# Epoch 00138: val_mae did not improve from 0.06711
# Epoch 139/1000
# 2/2 - 0s - loss: 0.0022 - mae: 0.0373 - val_loss: 0.0095 - val_mae: 0.0734
#
# Epoch 00139: val_mae did not improve from 0.06711
# Epoch 140/1000
# 2/2 - 0s - loss: 0.0021 - mae: 0.0367 - val_loss: 0.0092 - val_mae: 0.0721
#
# Epoch 00140: val_mae did not improve from 0.06711
# Epoch 141/1000
# 2/2 - 0s - loss: 0.0021 - mae: 0.0368 - val_loss: 0.0081 - val_mae: 0.0677
#
# Epoch 00141: val_mae did not improve from 0.06711
# Epoch 142/1000
# 2/2 - 0s - loss: 0.0024 - mae: 0.0392 - val_loss: 0.0104 - val_mae: 0.0764
#
# Epoch 00142: val_mae did not improve from 0.06711
# Epoch 143/1000
# 2/2 - 0s - loss: 0.0023 - mae: 0.0379 - val_loss: 0.0091 - val_mae: 0.0713
#
# Epoch 00143: val_mae did not improve from 0.06711
# Epoch 144/1000
# 2/2 - 0s - loss: 0.0021 - mae: 0.0362 - val_loss: 0.0085 - val_mae: 0.0692
#
# Epoch 00144: val_mae did not improve from 0.06711
# Epoch 145/1000
# 2/2 - 0s - loss: 0.0021 - mae: 0.0362 - val_loss: 0.0095 - val_mae: 0.0721
#
# Epoch 00145: val_mae did not improve from 0.06711
# Epoch 146/1000
# 2/2 - 0s - loss: 0.0020 - mae: 0.0355 - val_loss: 0.0083 - val_mae: 0.0682
#
# Epoch 00146: val_mae did not improve from 0.06711
# Epoch 147/1000
# 2/2 - 0s - loss: 0.0020 - mae: 0.0357 - val_loss: 0.0094 - val_mae: 0.0726
#
# Epoch 00147: val_mae did not improve from 0.06711
# Epoch 148/1000
# 2/2 - 0s - loss: 0.0020 - mae: 0.0351 - val_loss: 0.0101 - val_mae: 0.0746
#
# Epoch 00148: val_mae did not improve from 0.06711
# Epoch 149/1000
# 2/2 - 0s - loss: 0.0020 - mae: 0.0353 - val_loss: 0.0085 - val_mae: 0.0683
#
# Epoch 00149: val_mae did not improve from 0.06711
# Epoch 150/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0350 - val_loss: 0.0091 - val_mae: 0.0706
#
# Epoch 00150: val_mae did not improve from 0.06711
# Epoch 151/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0343 - val_loss: 0.0101 - val_mae: 0.0745
#
# Epoch 00151: val_mae did not improve from 0.06711
# Epoch 152/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0344 - val_loss: 0.0086 - val_mae: 0.0690
#
# Epoch 00152: val_mae did not improve from 0.06711
# Epoch 153/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0096 - val_mae: 0.0721
#
# Epoch 00153: val_mae did not improve from 0.06711
# Epoch 154/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0341 - val_loss: 0.0091 - val_mae: 0.0703
#
# Epoch 00154: val_mae did not improve from 0.06711
# Epoch 155/1000
# 2/2 - 0s - loss: 0.0018 - mae: 0.0337 - val_loss: 0.0083 - val_mae: 0.0685
#
# Epoch 00155: val_mae did not improve from 0.06711
# Epoch 156/1000
# 2/2 - 0s - loss: 0.0020 - mae: 0.0352 - val_loss: 0.0095 - val_mae: 0.0718
#
# Epoch 00156: val_mae did not improve from 0.06711
# Epoch 157/1000
# 2/2 - 0s - loss: 0.0019 - mae: 0.0342 - val_loss: 0.0092 - val_mae: 0.0706
#
# Epoch 00157: val_mae did not improve from 0.06711
# Epoch 158/1000
# 2/2 - 0s - loss: 0.0017 - mae: 0.0327 - val_loss: 0.0087 - val_mae: 0.0696
#
# Epoch 00158: val_mae did not improve from 0.06711
# Epoch 159/1000
# 2/2 - 0s - loss: 0.0017 - mae: 0.0330 - val_loss: 0.0091 - val_mae: 0.0703
#
# Epoch 00159: val_mae did not improve from 0.06711
# Epoch 160/1000
# 2/2 - 0s - loss: 0.0016 - mae: 0.0319 - val_loss: 0.0086 - val_mae: 0.0683
#
# Epoch 00160: val_mae did not improve from 0.06711
# Epoch 161/1000
# 2/2 - 0s - loss: 0.0017 - mae: 0.0321 - val_loss: 0.0085 - val_mae: 0.0685
#
# Epoch 00161: val_mae did not improve from 0.06711
# Epoch 162/1000
# 2/2 - 0s - loss: 0.0016 - mae: 0.0321 - val_loss: 0.0092 - val_mae: 0.0700
#
# Epoch 00162: val_mae did not improve from 0.06711
# Epoch 163/1000
# 2/2 - 0s - loss: 0.0016 - mae: 0.0315 - val_loss: 0.0081 - val_mae: 0.0668
#
# Epoch 00163: val_mae improved from 0.06711 to 0.06678, saving model to ../../saved_models/price_E.h5
# Epoch 164/1000
# 2/2 - 0s - loss: 0.0017 - mae: 0.0322 - val_loss: 0.0087 - val_mae: 0.0693
#
# Epoch 00164: val_mae did not improve from 0.06678
# Epoch 165/1000
# 2/2 - 0s - loss: 0.0016 - mae: 0.0312 - val_loss: 0.0090 - val_mae: 0.0692
#
# Epoch 00165: val_mae did not improve from 0.06678
# Epoch 166/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0310 - val_loss: 0.0083 - val_mae: 0.0672
#
# Epoch 00166: val_mae did not improve from 0.06678
# Epoch 167/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0306 - val_loss: 0.0092 - val_mae: 0.0703
#
# Epoch 00167: val_mae did not improve from 0.06678
# Epoch 168/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0304 - val_loss: 0.0087 - val_mae: 0.0689
#
# Epoch 00168: val_mae did not improve from 0.06678
# Epoch 169/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0302 - val_loss: 0.0085 - val_mae: 0.0687
#
# Epoch 00169: val_mae did not improve from 0.06678
# Epoch 170/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0302 - val_loss: 0.0094 - val_mae: 0.0717
#
# Epoch 00170: val_mae did not improve from 0.06678
# Epoch 171/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0301 - val_loss: 0.0089 - val_mae: 0.0697
#
# Epoch 00171: val_mae did not improve from 0.06678
# Epoch 172/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0296 - val_loss: 0.0082 - val_mae: 0.0672
#
# Epoch 00172: val_mae did not improve from 0.06678
# Epoch 173/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0299 - val_loss: 0.0087 - val_mae: 0.0693
#
# Epoch 00173: val_mae did not improve from 0.06678
# Epoch 174/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0294 - val_loss: 0.0087 - val_mae: 0.0694
#
# Epoch 00174: val_mae did not improve from 0.06678
# Epoch 175/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0293 - val_loss: 0.0087 - val_mae: 0.0687
#
# Epoch 00175: val_mae did not improve from 0.06678
# Epoch 176/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0291 - val_loss: 0.0086 - val_mae: 0.0688
#
# Epoch 00176: val_mae did not improve from 0.06678
# Epoch 177/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0291 - val_loss: 0.0089 - val_mae: 0.0704
#
# Epoch 00177: val_mae did not improve from 0.06678
# Epoch 178/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0290 - val_loss: 0.0088 - val_mae: 0.0694
#
# Epoch 00178: val_mae did not improve from 0.06678
# Epoch 179/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0285 - val_loss: 0.0084 - val_mae: 0.0683
#
# Epoch 00179: val_mae did not improve from 0.06678
# Epoch 180/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0089 - val_mae: 0.0698
#
# Epoch 00180: val_mae did not improve from 0.06678
# Epoch 181/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0285 - val_loss: 0.0094 - val_mae: 0.0709
#
# Epoch 00181: val_mae did not improve from 0.06678
# Epoch 182/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0293 - val_loss: 0.0087 - val_mae: 0.0690
#
# Epoch 00182: val_mae did not improve from 0.06678
# Epoch 183/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0281 - val_loss: 0.0088 - val_mae: 0.0701
#
# Epoch 00183: val_mae did not improve from 0.06678
# Epoch 184/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0283 - val_loss: 0.0088 - val_mae: 0.0695
#
# Epoch 00184: val_mae did not improve from 0.06678
# Epoch 185/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0278 - val_loss: 0.0095 - val_mae: 0.0717
#
# Epoch 00185: val_mae did not improve from 0.06678
# Epoch 186/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0088 - val_mae: 0.0698
#
# Epoch 00186: val_mae did not improve from 0.06678
# Epoch 187/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0280 - val_loss: 0.0081 - val_mae: 0.0673
#
# Epoch 00187: val_mae did not improve from 0.06678
# Epoch 188/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0280 - val_loss: 0.0101 - val_mae: 0.0737
#
# Epoch 00188: val_mae did not improve from 0.06678
# Epoch 189/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0308 - val_loss: 0.0098 - val_mae: 0.0724
#
# Epoch 00189: val_mae did not improve from 0.06678
# Epoch 190/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0282 - val_loss: 0.0082 - val_mae: 0.0682
#
# Epoch 00190: val_mae did not improve from 0.06678
# Epoch 191/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0297 - val_loss: 0.0087 - val_mae: 0.0682
#
# Epoch 00191: val_mae did not improve from 0.06678
# Epoch 192/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0278 - val_loss: 0.0097 - val_mae: 0.0723
#
# Epoch 00192: val_mae did not improve from 0.06678
# Epoch 193/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0277 - val_loss: 0.0082 - val_mae: 0.0688
#
# Epoch 00193: val_mae did not improve from 0.06678
# Epoch 194/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0300 - val_loss: 0.0092 - val_mae: 0.0708
#
# Epoch 00194: val_mae did not improve from 0.06678
# Epoch 195/1000
# 2/2 - 0s - loss: 0.0014 - mae: 0.0291 - val_loss: 0.0096 - val_mae: 0.0720
#
# Epoch 00195: val_mae did not improve from 0.06678
# Epoch 196/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0277 - val_loss: 0.0083 - val_mae: 0.0692
#
# Epoch 00196: val_mae did not improve from 0.06678
# Epoch 197/1000
# 2/2 - 0s - loss: 0.0015 - mae: 0.0307 - val_loss: 0.0093 - val_mae: 0.0704
#
# Epoch 00197: val_mae did not improve from 0.06678
# Epoch 198/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0275 - val_loss: 0.0089 - val_mae: 0.0696
#
# Epoch 00198: val_mae did not improve from 0.06678
# Epoch 199/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0084 - val_mae: 0.0689
#
# Epoch 00199: val_mae did not improve from 0.06678
# Epoch 200/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0277 - val_loss: 0.0102 - val_mae: 0.0744
#
# Epoch 00200: val_mae did not improve from 0.06678
# Epoch 201/1000
# 2/2 - 0s - loss: 0.0013 - mae: 0.0288 - val_loss: 0.0089 - val_mae: 0.0698
#
# Epoch 00201: val_mae did not improve from 0.06678
# Epoch 202/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0267 - val_loss: 0.0086 - val_mae: 0.0687
#
# Epoch 00202: val_mae did not improve from 0.06678
# Epoch 203/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0102 - val_mae: 0.0737
#
# Epoch 00203: val_mae did not improve from 0.06678
# Epoch 204/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0276 - val_loss: 0.0086 - val_mae: 0.0684
#
# Epoch 00204: val_mae did not improve from 0.06678
# Epoch 205/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0267 - val_loss: 0.0087 - val_mae: 0.0694
#
# Epoch 00205: val_mae did not improve from 0.06678
# Epoch 206/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0103 - val_mae: 0.0743
#
# Epoch 00206: val_mae did not improve from 0.06678
# Epoch 207/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0082 - val_mae: 0.0674
#
# Epoch 00207: val_mae did not improve from 0.06678
# Epoch 208/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0271 - val_loss: 0.0091 - val_mae: 0.0703
#
# Epoch 00208: val_mae did not improve from 0.06678
# Epoch 209/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0259 - val_loss: 0.0101 - val_mae: 0.0738
#
# Epoch 00209: val_mae did not improve from 0.06678
# Epoch 210/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0269 - val_loss: 0.0083 - val_mae: 0.0678
#
# Epoch 00210: val_mae did not improve from 0.06678
# Epoch 211/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0268 - val_loss: 0.0096 - val_mae: 0.0721
#
# Epoch 00211: val_mae did not improve from 0.06678
# Epoch 212/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0261 - val_loss: 0.0094 - val_mae: 0.0716
#
# Epoch 00212: val_mae did not improve from 0.06678
# Epoch 213/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0254 - val_loss: 0.0082 - val_mae: 0.0674
#
# Epoch 00213: val_mae did not improve from 0.06678
# Epoch 214/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0257 - val_loss: 0.0096 - val_mae: 0.0718
#
# Epoch 00214: val_mae did not improve from 0.06678
# Epoch 215/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0255 - val_loss: 0.0090 - val_mae: 0.0703
#
# Epoch 00215: val_mae did not improve from 0.06678
# Epoch 216/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0252 - val_loss: 0.0086 - val_mae: 0.0687
#
# Epoch 00216: val_mae did not improve from 0.06678
# Epoch 217/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0252 - val_loss: 0.0096 - val_mae: 0.0721
#
# Epoch 00217: val_mae did not improve from 0.06678
# Epoch 218/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0251 - val_loss: 0.0090 - val_mae: 0.0706
#
# Epoch 00218: val_mae did not improve from 0.06678
# Epoch 219/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0250 - val_loss: 0.0091 - val_mae: 0.0707
#
# Epoch 00219: val_mae did not improve from 0.06678
# Epoch 220/1000
# 2/2 - 0s - loss: 9.9818e-04 - mae: 0.0246 - val_loss: 0.0095 - val_mae: 0.0718
#
# Epoch 00220: val_mae did not improve from 0.06678
# Epoch 221/1000
# 2/2 - 0s - loss: 9.9469e-04 - mae: 0.0246 - val_loss: 0.0088 - val_mae: 0.0708
#
# Epoch 00221: val_mae did not improve from 0.06678
# Epoch 222/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0091 - val_mae: 0.0704
#
# Epoch 00222: val_mae did not improve from 0.06678
# Epoch 223/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0248 - val_loss: 0.0101 - val_mae: 0.0739
#
# Epoch 00223: val_mae did not improve from 0.06678
# Epoch 224/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0086 - val_mae: 0.0696
#
# Epoch 00224: val_mae did not improve from 0.06678
# Epoch 225/1000
# 2/2 - 0s - loss: 0.0012 - mae: 0.0273 - val_loss: 0.0091 - val_mae: 0.0708
#
# Epoch 00225: val_mae did not improve from 0.06678
# Epoch 226/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0249 - val_loss: 0.0105 - val_mae: 0.0756
#
# Epoch 00226: val_mae did not improve from 0.06678
# Epoch 227/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0265 - val_loss: 0.0091 - val_mae: 0.0709
#
# Epoch 00227: val_mae did not improve from 0.06678
# Epoch 228/1000
# 2/2 - 0s - loss: 9.8088e-04 - mae: 0.0245 - val_loss: 0.0092 - val_mae: 0.0712
#
# Epoch 00228: val_mae did not improve from 0.06678
# Epoch 229/1000
# 2/2 - 0s - loss: 9.7053e-04 - mae: 0.0244 - val_loss: 0.0107 - val_mae: 0.0762
# Epoch 00229: val_mae did not improve from 0.06678
# Epoch 230/1000
# 2/2 - 0s - loss: 0.0011 - mae: 0.0266 - val_loss: 0.0090 - val_mae: 0.0702
#
# Epoch 00230: val_mae did not improve from 0.06678
# Epoch 231/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0248 - val_loss: 0.0091 - val_mae: 0.0712
#
# Epoch 00231: val_mae did not improve from 0.06678
# Epoch 232/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0250 - val_loss: 0.0104 - val_mae: 0.0750
#
# Epoch 00232: val_mae did not improve from 0.06678
# Epoch 233/1000
# 2/2 - 0s - loss: 0.0010 - mae: 0.0254 - val_loss: 0.0092 - val_mae: 0.0705
#
# Epoch 00233: val_mae did not improve from 0.06678
# Epoch 234/1000
# 2/2 - 0s - loss: 9.5101e-04 - mae: 0.0241 - val_loss: 0.0091 - val_mae: 0.0709
#
# Epoch 00234: val_mae did not improve from 0.06678
# Epoch 235/1000
# 2/2 - 0s - loss: 9.7756e-04 - mae: 0.0245 - val_loss: 0.0101 - val_mae: 0.0738
#
# Epoch 00235: val_mae did not improve from 0.06678
# Epoch 236/1000
# 2/2 - 0s - loss: 9.7008e-04 - mae: 0.0243 - val_loss: 0.0093 - val_mae: 0.0709
#
# Epoch 00236: val_mae did not improve from 0.06678
# Epoch 237/1000
# 2/2 - 0s - loss: 9.2810e-04 - mae: 0.0237 - val_loss: 0.0091 - val_mae: 0.0712
#
# Epoch 00237: val_mae did not improve from 0.06678
# Epoch 238/1000
# 2/2 - 0s - loss: 9.8928e-04 - mae: 0.0248 - val_loss: 0.0097 - val_mae: 0.0725
#
# Epoch 00238: val_mae did not improve from 0.06678
# Epoch 239/1000
# 2/2 - 0s - loss: 9.2363e-04 - mae: 0.0238 - val_loss: 0.0098 - val_mae: 0.0728
#
# Epoch 00239: val_mae did not improve from 0.06678
# Epoch 240/1000
# 2/2 - 0s - loss: 9.1758e-04 - mae: 0.0236 - val_loss: 0.0097 - val_mae: 0.0733
#
# Epoch 00240: val_mae did not improve from 0.06678
# Epoch 241/1000
# 2/2 - 0s - loss: 9.3169e-04 - mae: 0.0239 - val_loss: 0.0098 - val_mae: 0.0728
#
# Epoch 00241: val_mae did not improve from 0.06678
# Epoch 242/1000
# 2/2 - 0s - loss: 8.8317e-04 - mae: 0.0232 - val_loss: 0.0095 - val_mae: 0.0716
#
# Epoch 00242: val_mae did not improve from 0.06678
# Epoch 243/1000
# 2/2 - 0s - loss: 8.7986e-04 - mae: 0.0232 - val_loss: 0.0096 - val_mae: 0.0728
#
# Epoch 00243: val_mae did not improve from 0.06678
# Epoch 244/1000
# 2/2 - 0s - loss: 8.8002e-04 - mae: 0.0232 - val_loss: 0.0100 - val_mae: 0.0737
#
# Epoch 00244: val_mae did not improve from 0.06678
# Epoch 245/1000
# 2/2 - 0s - loss: 8.9148e-04 - mae: 0.0234 - val_loss: 0.0096 - val_mae: 0.0724
#
# Epoch 00245: val_mae did not improve from 0.06678
# Epoch 246/1000
# 2/2 - 0s - loss: 8.6028e-04 - mae: 0.0229 - val_loss: 0.0098 - val_mae: 0.0731
#
# Epoch 00246: val_mae did not improve from 0.06678
# Epoch 247/1000
# 2/2 - 0s - loss: 8.6066e-04 - mae: 0.0229 - val_loss: 0.0095 - val_mae: 0.0717
#
# Epoch 00247: val_mae did not improve from 0.06678
# Epoch 248/1000
# 2/2 - 0s - loss: 8.5770e-04 - mae: 0.0229 - val_loss: 0.0094 - val_mae: 0.0721
#
# Epoch 00248: val_mae did not improve from 0.06678
# Epoch 249/1000
# 2/2 - 0s - loss: 8.8792e-04 - mae: 0.0233 - val_loss: 0.0097 - val_mae: 0.0733
#
# Epoch 00249: val_mae did not improve from 0.06678
# Epoch 250/1000
# 2/2 - 0s - loss: 8.7160e-04 - mae: 0.0231 - val_loss: 0.0094 - val_mae: 0.0714
#
# Epoch 00250: val_mae did not improve from 0.06678
# Epoch 251/1000
# 2/2 - 0s - loss: 8.4647e-04 - mae: 0.0227 - val_loss: 0.0099 - val_mae: 0.0738
#
# Epoch 00251: val_mae did not improve from 0.06678
# Epoch 252/1000
# 2/2 - 0s - loss: 8.3554e-04 - mae: 0.0226 - val_loss: 0.0098 - val_mae: 0.0732
#
# Epoch 00252: val_mae did not improve from 0.06678
# Epoch 253/1000
# 2/2 - 0s - loss: 8.2463e-04 - mae: 0.0224 - val_loss: 0.0096 - val_mae: 0.0723
#
# Epoch 00253: val_mae did not improve from 0.06678
# Epoch 254/1000
# 2/2 - 0s - loss: 8.2777e-04 - mae: 0.0224 - val_loss: 0.0098 - val_mae: 0.0736
#
# Epoch 00254: val_mae did not improve from 0.06678
# Epoch 255/1000
# 2/2 - 0s - loss: 8.5365e-04 - mae: 0.0228 - val_loss: 0.0094 - val_mae: 0.0718
#
# Epoch 00255: val_mae did not improve from 0.06678
# Epoch 256/1000
# 2/2 - 0s - loss: 8.3696e-04 - mae: 0.0226 - val_loss: 0.0100 - val_mae: 0.0740
#
# Epoch 00256: val_mae did not improve from 0.06678
# Epoch 257/1000
# 2/2 - 0s - loss: 8.7973e-04 - mae: 0.0232 - val_loss: 0.0102 - val_mae: 0.0748
#
# Epoch 00257: val_mae did not improve from 0.06678
# Epoch 258/1000
# 2/2 - 0s - loss: 8.2348e-04 - mae: 0.0224 - val_loss: 0.0094 - val_mae: 0.0721
#
# Epoch 00258: val_mae did not improve from 0.06678
# Epoch 259/1000
# 2/2 - 0s - loss: 8.2845e-04 - mae: 0.0225 - val_loss: 0.0100 - val_mae: 0.0742
#
# Epoch 00259: val_mae did not improve from 0.06678
# Epoch 260/1000
# 2/2 - 0s - loss: 8.0914e-04 - mae: 0.0222 - val_loss: 0.0103 - val_mae: 0.0751
#
# Epoch 00260: val_mae did not improve from 0.06678
# Epoch 261/1000
# 2/2 - 0s - loss: 8.0422e-04 - mae: 0.0222 - val_loss: 0.0095 - val_mae: 0.0725
#
# Epoch 00261: val_mae did not improve from 0.06678
# Epoch 262/1000
# 2/2 - 0s - loss: 8.1068e-04 - mae: 0.0222 - val_loss: 0.0096 - val_mae: 0.0727
#
# Epoch 00262: val_mae did not improve from 0.06678
# Epoch 263/1000
# 2/2 - 0s - loss: 7.9720e-04 - mae: 0.0220 - val_loss: 0.0102 - val_mae: 0.0752
#
# Epoch 00263: val_mae did not improve from 0.06678
# Epoch 00263: early stopping
