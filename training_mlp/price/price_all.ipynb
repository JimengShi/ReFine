# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from math import sqrt
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.mlp import mlp_layer
# Out:
# 2024-01-20 14:37:22.831304: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# import random

# random.seed(10)
# print(random.random())

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data

# %%
print(data['price'].min())
print(data['price'].max())
# Out:
# 9.33
# 116.8

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
# for col in data.columns:
#     plt.hist(data[col], bins=20)
#     plt.title(col)
#     plt.show()
#     plt.close()

# %%
np.percentile(data['price'], 95)
# Out:
# 79.17

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 0
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### Model & training

# %%
# plt.hist(train_y[:,0])

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0.0  # 0.1
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

# %%
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
#                                                           decay_steps=decay_steps,
#                                                           decay_rate=decay_rate)

# model.compile(optimizer=Adam(learning_rate=lr_schedule),
#               loss='mse',
#               metrics=['mae']
#              )

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )


es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models/price_all.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True
                    )


model.fit(train_X, train_y,
          validation_data=(val_X, val_y),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc]
         )
# Out:
# Epoch 1/1000
# 48/48 - 2s - loss: 0.0426 - mae: 0.1509 - val_loss: 0.0149 - val_mae: 0.0921
#
# Epoch 00001: val_mae improved from inf to 0.09212, saving model to ../../saved_models/energy_all.h5
# Epoch 2/1000
# 48/48 - 1s - loss: 0.0102 - mae: 0.0788 - val_loss: 0.0119 - val_mae: 0.0820
#
# Epoch 00002: val_mae improved from 0.09212 to 0.08196, saving model to ../../saved_models/energy_all.h5
# Epoch 3/1000
# 48/48 - 1s - loss: 0.0078 - mae: 0.0694 - val_loss: 0.0114 - val_mae: 0.0793
#
# Epoch 00003: val_mae improved from 0.08196 to 0.07930, saving model to ../../saved_models/energy_all.h5
# Epoch 4/1000
# 48/48 - 1s - loss: 0.0052 - mae: 0.0555 - val_loss: 0.0062 - val_mae: 0.0580
#
# Epoch 00004: val_mae improved from 0.07930 to 0.05802, saving model to ../../saved_models/energy_all.h5
# Epoch 5/1000
# 48/48 - 1s - loss: 0.0039 - mae: 0.0479 - val_loss: 0.0057 - val_mae: 0.0557
#
# Epoch 00005: val_mae improved from 0.05802 to 0.05575, saving model to ../../saved_models/energy_all.h5
# Epoch 6/1000
# 48/48 - 1s - loss: 0.0037 - mae: 0.0460 - val_loss: 0.0057 - val_mae: 0.0582
#
# Epoch 00006: val_mae did not improve from 0.05575
# Epoch 7/1000
# 48/48 - 1s - loss: 0.0035 - mae: 0.0447 - val_loss: 0.0060 - val_mae: 0.0600
#
# Epoch 00007: val_mae did not improve from 0.05575
# Epoch 8/1000
# 48/48 - 1s - loss: 0.0033 - mae: 0.0438 - val_loss: 0.0072 - val_mae: 0.0678
#
# Epoch 00008: val_mae did not improve from 0.05575
# Epoch 9/1000
# 48/48 - 1s - loss: 0.0032 - mae: 0.0433 - val_loss: 0.0055 - val_mae: 0.0566
#
# Epoch 00009: val_mae did not improve from 0.05575
# Epoch 10/1000
# 48/48 - 1s - loss: 0.0030 - mae: 0.0413 - val_loss: 0.0054 - val_mae: 0.0558
#
# Epoch 00010: val_mae did not improve from 0.05575
# Epoch 11/1000
# 48/48 - 1s - loss: 0.0029 - mae: 0.0404 - val_loss: 0.0053 - val_mae: 0.0549
#
# Epoch 00011: val_mae improved from 0.05575 to 0.05487, saving model to ../../saved_models/energy_all.h5
# Epoch 12/1000
# 48/48 - 1s - loss: 0.0029 - mae: 0.0406 - val_loss: 0.0055 - val_mae: 0.0568
#
# Epoch 00012: val_mae did not improve from 0.05487
# Epoch 13/1000
# 48/48 - 1s - loss: 0.0028 - mae: 0.0400 - val_loss: 0.0052 - val_mae: 0.0542
#
# Epoch 00013: val_mae improved from 0.05487 to 0.05423, saving model to ../../saved_models/energy_all.h5
# Epoch 14/1000
# 48/48 - 1s - loss: 0.0027 - mae: 0.0395 - val_loss: 0.0050 - val_mae: 0.0532
#
# Epoch 00014: val_mae improved from 0.05423 to 0.05316, saving model to ../../saved_models/energy_all.h5
# Epoch 15/1000
# 48/48 - 1s - loss: 0.0026 - mae: 0.0382 - val_loss: 0.0051 - val_mae: 0.0531
#
# Epoch 00015: val_mae improved from 0.05316 to 0.05314, saving model to ../../saved_models/energy_all.h5
# Epoch 16/1000
# 48/48 - 1s - loss: 0.0026 - mae: 0.0383 - val_loss: 0.0058 - val_mae: 0.0589
#
# Epoch 00016: val_mae did not improve from 0.05314
# Epoch 17/1000
# 48/48 - 1s - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0052 - val_mae: 0.0537
#
# Epoch 00017: val_mae did not improve from 0.05314
# Epoch 18/1000
# 48/48 - 1s - loss: 0.0024 - mae: 0.0372 - val_loss: 0.0053 - val_mae: 0.0542
#
# Epoch 00018: val_mae did not improve from 0.05314
# Epoch 19/1000
# 48/48 - 1s - loss: 0.0024 - mae: 0.0374 - val_loss: 0.0057 - val_mae: 0.0573
#
# Epoch 00019: val_mae did not improve from 0.05314
# Epoch 20/1000
# 48/48 - 1s - loss: 0.0022 - mae: 0.0360 - val_loss: 0.0055 - val_mae: 0.0562
#
# Epoch 00020: val_mae did not improve from 0.05314
# Epoch 21/1000
# 48/48 - 1s - loss: 0.0022 - mae: 0.0356 - val_loss: 0.0062 - val_mae: 0.0601
#
# Epoch 00021: val_mae did not improve from 0.05314
# Epoch 22/1000
# 48/48 - 1s - loss: 0.0021 - mae: 0.0345 - val_loss: 0.0059 - val_mae: 0.0583
#
# Epoch 00022: val_mae did not improve from 0.05314
# Epoch 23/1000
# 48/48 - 1s - loss: 0.0021 - mae: 0.0348 - val_loss: 0.0060 - val_mae: 0.0577
#
# Epoch 00023: val_mae did not improve from 0.05314
# Epoch 24/1000
# 48/48 - 1s - loss: 0.0019 - mae: 0.0336 - val_loss: 0.0062 - val_mae: 0.0592
#
# Epoch 00024: val_mae did not improve from 0.05314
# Epoch 25/1000
# 48/48 - 1s - loss: 0.0019 - mae: 0.0335 - val_loss: 0.0065 - val_mae: 0.0612
#
# Epoch 00025: val_mae did not improve from 0.05314
# Epoch 26/1000
# 48/48 - 1s - loss: 0.0019 - mae: 0.0331 - val_loss: 0.0065 - val_mae: 0.0612
#
# Epoch 00026: val_mae did not improve from 0.05314
# Epoch 27/1000
# 48/48 - 1s - loss: 0.0017 - mae: 0.0319 - val_loss: 0.0070 - val_mae: 0.0624
#
# Epoch 00027: val_mae did not improve from 0.05314
# Epoch 28/1000
# 48/48 - 1s - loss: 0.0018 - mae: 0.0326 - val_loss: 0.0072 - val_mae: 0.0645
#
# Epoch 00028: val_mae did not improve from 0.05314
# Epoch 29/1000
# 48/48 - 1s - loss: 0.0017 - mae: 0.0316 - val_loss: 0.0076 - val_mae: 0.0652
#
# Epoch 00029: val_mae did not improve from 0.05314
# Epoch 30/1000
# 48/48 - 1s - loss: 0.0016 - mae: 0.0309 - val_loss: 0.0074 - val_mae: 0.0640
#
# Epoch 00030: val_mae did not improve from 0.05314
# Epoch 31/1000
# 48/48 - 1s - loss: 0.0016 - mae: 0.0304 - val_loss: 0.0075 - val_mae: 0.0649
#
# Epoch 00031: val_mae did not improve from 0.05314
# Epoch 32/1000
# 48/48 - 1s - loss: 0.0015 - mae: 0.0298 - val_loss: 0.0083 - val_mae: 0.0692
#
# Epoch 00032: val_mae did not improve from 0.05314
# Epoch 33/1000
# 48/48 - 1s - loss: 0.0014 - mae: 0.0292 - val_loss: 0.0086 - val_mae: 0.0706
#
# Epoch 00033: val_mae did not improve from 0.05314
# Epoch 34/1000
# 48/48 - 1s - loss: 0.0014 - mae: 0.0292 - val_loss: 0.0082 - val_mae: 0.0684
#
# Epoch 00034: val_mae did not improve from 0.05314
# Epoch 35/1000
# 48/48 - 1s - loss: 0.0014 - mae: 0.0293 - val_loss: 0.0086 - val_mae: 0.0695
#
# Epoch 00035: val_mae did not improve from 0.05314
# Epoch 36/1000
# 48/48 - 1s - loss: 0.0013 - mae: 0.0278 - val_loss: 0.0089 - val_mae: 0.0701
#
# Epoch 00036: val_mae did not improve from 0.05314
# Epoch 37/1000
# 48/48 - 1s - loss: 0.0012 - mae: 0.0272 - val_loss: 0.0097 - val_mae: 0.0739
#
# Epoch 00037: val_mae did not improve from 0.05314
# Epoch 38/1000
# 48/48 - 1s - loss: 0.0013 - mae: 0.0274 - val_loss: 0.0092 - val_mae: 0.0719
#
# Epoch 00038: val_mae did not improve from 0.05314
# Epoch 39/1000
# 48/48 - 1s - loss: 0.0012 - mae: 0.0271 - val_loss: 0.0092 - val_mae: 0.0715
#
# Epoch 00039: val_mae did not improve from 0.05314
# Epoch 40/1000
# 48/48 - 1s - loss: 0.0012 - mae: 0.0268 - val_loss: 0.0100 - val_mae: 0.0750
#
# Epoch 00040: val_mae did not improve from 0.05314
# Epoch 41/1000
# 48/48 - 1s - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0099 - val_mae: 0.0747
#
# Epoch 00041: val_mae did not improve from 0.05314
# Epoch 42/1000
# 48/48 - 1s - loss: 0.0011 - mae: 0.0253 - val_loss: 0.0099 - val_mae: 0.0744
#
# Epoch 00042: val_mae did not improve from 0.05314
# Epoch 43/1000
# 48/48 - 1s - loss: 0.0011 - mae: 0.0256 - val_loss: 0.0102 - val_mae: 0.0758
#
# Epoch 00043: val_mae did not improve from 0.05314
# Epoch 44/1000
# 48/48 - 1s - loss: 0.0010 - mae: 0.0251 - val_loss: 0.0104 - val_mae: 0.0762
#
# Epoch 00044: val_mae did not improve from 0.05314
# Epoch 45/1000
# 48/48 - 1s - loss: 9.9653e-04 - mae: 0.0245 - val_loss: 0.0107 - val_mae: 0.0774
#
# Epoch 00045: val_mae did not improve from 0.05314
# Epoch 46/1000
# 48/48 - 1s - loss: 0.0011 - mae: 0.0254 - val_loss: 0.0107 - val_mae: 0.0767
#
# Epoch 00046: val_mae did not improve from 0.05314
# Epoch 47/1000
# 48/48 - 1s - loss: 9.7680e-04 - mae: 0.0243 - val_loss: 0.0106 - val_mae: 0.0771
#
# Epoch 00047: val_mae did not improve from 0.05314
# Epoch 48/1000
# 48/48 - 1s - loss: 9.5384e-04 - mae: 0.0240 - val_loss: 0.0111 - val_mae: 0.0791
#
# Epoch 00048: val_mae did not improve from 0.05314
# Epoch 49/1000
# 48/48 - 1s - loss: 8.9803e-04 - mae: 0.0232 - val_loss: 0.0111 - val_mae: 0.0785
#
# Epoch 00049: val_mae did not improve from 0.05314
# Epoch 50/1000
# 48/48 - 1s - loss: 9.0055e-04 - mae: 0.0233 - val_loss: 0.0119 - val_mae: 0.0817
#
# Epoch 00050: val_mae did not improve from 0.05314
# Epoch 51/1000
# 48/48 - 1s - loss: 8.8135e-04 - mae: 0.0230 - val_loss: 0.0114 - val_mae: 0.0799
#
# Epoch 00051: val_mae did not improve from 0.05314
# Epoch 52/1000
# 48/48 - 1s - loss: 8.5870e-04 - mae: 0.0227 - val_loss: 0.0120 - val_mae: 0.0816
#
# Epoch 00052: val_mae did not improve from 0.05314
# Epoch 53/1000
# 48/48 - 1s - loss: 8.7560e-04 - mae: 0.0230 - val_loss: 0.0119 - val_mae: 0.0817
#
# Epoch 00053: val_mae did not improve from 0.05314
# Epoch 54/1000
# 48/48 - 1s - loss: 8.5832e-04 - mae: 0.0228 - val_loss: 0.0119 - val_mae: 0.0820
#
# Epoch 00054: val_mae did not improve from 0.05314
# Epoch 55/1000
# 48/48 - 1s - loss: 8.1911e-04 - mae: 0.0222 - val_loss: 0.0115 - val_mae: 0.0808
# Epoch 00055: val_mae did not improve from 0.05314
# Epoch 56/1000
# 48/48 - 1s - loss: 8.1652e-04 - mae: 0.0222 - val_loss: 0.0121 - val_mae: 0.0818
#
# Epoch 00056: val_mae did not improve from 0.05314
# Epoch 57/1000
# 48/48 - 1s - loss: 8.0583e-04 - mae: 0.0221 - val_loss: 0.0123 - val_mae: 0.0823
#
# Epoch 00057: val_mae did not improve from 0.05314
# Epoch 58/1000
# 48/48 - 1s - loss: 7.7875e-04 - mae: 0.0217 - val_loss: 0.0124 - val_mae: 0.0832
#
# Epoch 00058: val_mae did not improve from 0.05314
# Epoch 59/1000
# 48/48 - 1s - loss: 8.1596e-04 - mae: 0.0223 - val_loss: 0.0131 - val_mae: 0.0852
#
# Epoch 00059: val_mae did not improve from 0.05314
# Epoch 60/1000
# 48/48 - 1s - loss: 8.2121e-04 - mae: 0.0223 - val_loss: 0.0124 - val_mae: 0.0829
#
# Epoch 00060: val_mae did not improve from 0.05314
# Epoch 61/1000
# 48/48 - 1s - loss: 7.5665e-04 - mae: 0.0214 - val_loss: 0.0123 - val_mae: 0.0831
#
# Epoch 00061: val_mae did not improve from 0.05314
# Epoch 62/1000
# 48/48 - 1s - loss: 7.2857e-04 - mae: 0.0210 - val_loss: 0.0125 - val_mae: 0.0840
#
# Epoch 00062: val_mae did not improve from 0.05314
# Epoch 63/1000
# 48/48 - 1s - loss: 7.4003e-04 - mae: 0.0212 - val_loss: 0.0130 - val_mae: 0.0852
#
# Epoch 00063: val_mae did not improve from 0.05314
# Epoch 64/1000
# 48/48 - 1s - loss: 7.5890e-04 - mae: 0.0215 - val_loss: 0.0129 - val_mae: 0.0856
#
# Epoch 00064: val_mae did not improve from 0.05314
# Epoch 65/1000
# 48/48 - 1s - loss: 6.8852e-04 - mae: 0.0204 - val_loss: 0.0134 - val_mae: 0.0865
#
# Epoch 00065: val_mae did not improve from 0.05314
# Epoch 66/1000
# 48/48 - 1s - loss: 6.6252e-04 - mae: 0.0199 - val_loss: 0.0134 - val_mae: 0.0870
#
# Epoch 00066: val_mae did not improve from 0.05314
# Epoch 67/1000
# 48/48 - 1s - loss: 6.6938e-04 - mae: 0.0201 - val_loss: 0.0137 - val_mae: 0.0872
#
# Epoch 00067: val_mae did not improve from 0.05314
# Epoch 68/1000
# 48/48 - 1s - loss: 6.8069e-04 - mae: 0.0203 - val_loss: 0.0132 - val_mae: 0.0857
#
# Epoch 00068: val_mae did not improve from 0.05314
# Epoch 69/1000
# 48/48 - 1s - loss: 7.0877e-04 - mae: 0.0207 - val_loss: 0.0134 - val_mae: 0.0865
#
# Epoch 00069: val_mae did not improve from 0.05314
# Epoch 70/1000
# 48/48 - 1s - loss: 6.8588e-04 - mae: 0.0204 - val_loss: 0.0147 - val_mae: 0.0899
#
# Epoch 00070: val_mae did not improve from 0.05314
# Epoch 71/1000
# 48/48 - 1s - loss: 7.1534e-04 - mae: 0.0208 - val_loss: 0.0144 - val_mae: 0.0890
#
# Epoch 00071: val_mae did not improve from 0.05314
# Epoch 72/1000
# 48/48 - 1s - loss: 6.4838e-04 - mae: 0.0198 - val_loss: 0.0142 - val_mae: 0.0891
#
# Epoch 00072: val_mae did not improve from 0.05314
# Epoch 73/1000
# 48/48 - 1s - loss: 6.0537e-04 - mae: 0.0191 - val_loss: 0.0145 - val_mae: 0.0893
#
# Epoch 00073: val_mae did not improve from 0.05314
# Epoch 74/1000
# 48/48 - 1s - loss: 5.9171e-04 - mae: 0.0189 - val_loss: 0.0150 - val_mae: 0.0911
#
# Epoch 00074: val_mae did not improve from 0.05314
# Epoch 75/1000
# 48/48 - 1s - loss: 6.2987e-04 - mae: 0.0195 - val_loss: 0.0145 - val_mae: 0.0903
#
# Epoch 00075: val_mae did not improve from 0.05314
# Epoch 76/1000
# 48/48 - 1s - loss: 6.0513e-04 - mae: 0.0191 - val_loss: 0.0151 - val_mae: 0.0908
#
# Epoch 00076: val_mae did not improve from 0.05314
# Epoch 77/1000
# 48/48 - 1s - loss: 6.0337e-04 - mae: 0.0191 - val_loss: 0.0147 - val_mae: 0.0898
#
# Epoch 00077: val_mae did not improve from 0.05314
# Epoch 78/1000
# 48/48 - 1s - loss: 6.6018e-04 - mae: 0.0201 - val_loss: 0.0153 - val_mae: 0.0919
#
# Epoch 00078: val_mae did not improve from 0.05314
# Epoch 79/1000
# 48/48 - 1s - loss: 5.8730e-04 - mae: 0.0188 - val_loss: 0.0144 - val_mae: 0.0893
#
# Epoch 00079: val_mae did not improve from 0.05314
# Epoch 80/1000
# 48/48 - 1s - loss: 6.0121e-04 - mae: 0.0191 - val_loss: 0.0144 - val_mae: 0.0898
#
# Epoch 00080: val_mae did not improve from 0.05314
# Epoch 81/1000
# 48/48 - 1s - loss: 5.4450e-04 - mae: 0.0181 - val_loss: 0.0155 - val_mae: 0.0925
#
# Epoch 00081: val_mae did not improve from 0.05314
# Epoch 82/1000
# 48/48 - 1s - loss: 5.6656e-04 - mae: 0.0185 - val_loss: 0.0153 - val_mae: 0.0913
#
# Epoch 00082: val_mae did not improve from 0.05314
# Epoch 83/1000
# 48/48 - 1s - loss: 5.3770e-04 - mae: 0.0180 - val_loss: 0.0150 - val_mae: 0.0907
#
# Epoch 00083: val_mae did not improve from 0.05314
# Epoch 84/1000
# 48/48 - 1s - loss: 5.4837e-04 - mae: 0.0182 - val_loss: 0.0160 - val_mae: 0.0943
#
# Epoch 00084: val_mae did not improve from 0.05314
# Epoch 85/1000
# 48/48 - 1s - loss: 6.0716e-04 - mae: 0.0192 - val_loss: 0.0157 - val_mae: 0.0936
#
# Epoch 00085: val_mae did not improve from 0.05314
# Epoch 86/1000
# 48/48 - 1s - loss: 5.5592e-04 - mae: 0.0183 - val_loss: 0.0155 - val_mae: 0.0923
#
# Epoch 00086: val_mae did not improve from 0.05314
# Epoch 87/1000
# 48/48 - 1s - loss: 5.3353e-04 - mae: 0.0179 - val_loss: 0.0157 - val_mae: 0.0927
#
# Epoch 00087: val_mae did not improve from 0.05314
# Epoch 88/1000
# 48/48 - 1s - loss: 6.1875e-04 - mae: 0.0194 - val_loss: 0.0156 - val_mae: 0.0926
#
# Epoch 00088: val_mae did not improve from 0.05314
# Epoch 89/1000
# 48/48 - 1s - loss: 5.0187e-04 - mae: 0.0174 - val_loss: 0.0153 - val_mae: 0.0916
#
# Epoch 00089: val_mae did not improve from 0.05314
# Epoch 90/1000
# 48/48 - 1s - loss: 5.5257e-04 - mae: 0.0183 - val_loss: 0.0161 - val_mae: 0.0942
#
# Epoch 00090: val_mae did not improve from 0.05314
# Epoch 91/1000
# 48/48 - 1s - loss: 4.8539e-04 - mae: 0.0171 - val_loss: 0.0166 - val_mae: 0.0952
#
# Epoch 00091: val_mae did not improve from 0.05314
# Epoch 92/1000
# 48/48 - 1s - loss: 5.8248e-04 - mae: 0.0188 - val_loss: 0.0160 - val_mae: 0.0936
#
# Epoch 00092: val_mae did not improve from 0.05314
# Epoch 93/1000
# 48/48 - 1s - loss: 4.9720e-04 - mae: 0.0173 - val_loss: 0.0160 - val_mae: 0.0935
#
# Epoch 00093: val_mae did not improve from 0.05314
# Epoch 94/1000
# 48/48 - 1s - loss: 5.0982e-04 - mae: 0.0176 - val_loss: 0.0160 - val_mae: 0.0934
#
# Epoch 00094: val_mae did not improve from 0.05314
# Epoch 95/1000
# 48/48 - 1s - loss: 5.5283e-04 - mae: 0.0184 - val_loss: 0.0170 - val_mae: 0.0962
#
# Epoch 00095: val_mae did not improve from 0.05314
# Epoch 96/1000
# 48/48 - 1s - loss: 5.0023e-04 - mae: 0.0174 - val_loss: 0.0157 - val_mae: 0.0931
#
# Epoch 00096: val_mae did not improve from 0.05314
# Epoch 97/1000
# 48/48 - 1s - loss: 4.7629e-04 - mae: 0.0170 - val_loss: 0.0166 - val_mae: 0.0951
#
# Epoch 00097: val_mae did not improve from 0.05314
# Epoch 98/1000
# 48/48 - 1s - loss: 5.2687e-04 - mae: 0.0179 - val_loss: 0.0169 - val_mae: 0.0963
#
# Epoch 00098: val_mae did not improve from 0.05314
# Epoch 99/1000
# 48/48 - 1s - loss: 5.5430e-04 - mae: 0.0183 - val_loss: 0.0160 - val_mae: 0.0935
#
# Epoch 00099: val_mae did not improve from 0.05314
# Epoch 100/1000
# 48/48 - 1s - loss: 4.4339e-04 - mae: 0.0163 - val_loss: 0.0166 - val_mae: 0.0950
#
# Epoch 00100: val_mae did not improve from 0.05314
# Epoch 101/1000
# 48/48 - 1s - loss: 4.5698e-04 - mae: 0.0166 - val_loss: 0.0169 - val_mae: 0.0959
#
# Epoch 00101: val_mae did not improve from 0.05314
# Epoch 102/1000
# 48/48 - 1s - loss: 4.5858e-04 - mae: 0.0166 - val_loss: 0.0168 - val_mae: 0.0961
#
# Epoch 00102: val_mae did not improve from 0.05314
# Epoch 103/1000
# 48/48 - 1s - loss: 4.3932e-04 - mae: 0.0162 - val_loss: 0.0170 - val_mae: 0.0961
#
# Epoch 00103: val_mae did not improve from 0.05314
# Epoch 104/1000
# 48/48 - 1s - loss: 4.6843e-04 - mae: 0.0168 - val_loss: 0.0170 - val_mae: 0.0961
#
# Epoch 00104: val_mae did not improve from 0.05314
# Epoch 105/1000
# 48/48 - 1s - loss: 4.3708e-04 - mae: 0.0162 - val_loss: 0.0174 - val_mae: 0.0972
#
# Epoch 00105: val_mae did not improve from 0.05314
# Epoch 106/1000
# 48/48 - 1s - loss: 4.6826e-04 - mae: 0.0168 - val_loss: 0.0169 - val_mae: 0.0963
#
# Epoch 00106: val_mae did not improve from 0.05314
# Epoch 107/1000
# 48/48 - 1s - loss: 6.0929e-04 - mae: 0.0193 - val_loss: 0.0159 - val_mae: 0.0935
#
# Epoch 00107: val_mae did not improve from 0.05314
# Epoch 108/1000
# 48/48 - 1s - loss: 4.4905e-04 - mae: 0.0164 - val_loss: 0.0166 - val_mae: 0.0954
#
# Epoch 00108: val_mae did not improve from 0.05314
# Epoch 109/1000
# 48/48 - 1s - loss: 4.0304e-04 - mae: 0.0155 - val_loss: 0.0167 - val_mae: 0.0956
#
# Epoch 00109: val_mae did not improve from 0.05314
# Epoch 110/1000
# 48/48 - 1s - loss: 4.0424e-04 - mae: 0.0156 - val_loss: 0.0166 - val_mae: 0.0958
#
# Epoch 00110: val_mae did not improve from 0.05314
# Epoch 111/1000
# 48/48 - 1s - loss: 4.7694e-04 - mae: 0.0170 - val_loss: 0.0172 - val_mae: 0.0971
#
# Epoch 00111: val_mae did not improve from 0.05314
# Epoch 112/1000
# 48/48 - 1s - loss: 4.6988e-04 - mae: 0.0169 - val_loss: 0.0168 - val_mae: 0.0959
#
# Epoch 00112: val_mae did not improve from 0.05314
# Epoch 113/1000
# 48/48 - 1s - loss: 4.1251e-04 - mae: 0.0157 - val_loss: 0.0167 - val_mae: 0.0959
#
# Epoch 00113: val_mae did not improve from 0.05314
# Epoch 114/1000
# 48/48 - 1s - loss: 4.3999e-04 - mae: 0.0163 - val_loss: 0.0170 - val_mae: 0.0966
#
# Epoch 00114: val_mae did not improve from 0.05314
# Epoch 115/1000
# 48/48 - 1s - loss: 4.5276e-04 - mae: 0.0166 - val_loss: 0.0165 - val_mae: 0.0952
#
# Epoch 00115: val_mae did not improve from 0.05314
# Epoch 116/1000
# 48/48 - 1s - loss: 4.8805e-04 - mae: 0.0173 - val_loss: 0.0157 - val_mae: 0.0930
#
# Epoch 00116: val_mae did not improve from 0.05314
# Epoch 117/1000
# 48/48 - 1s - loss: 4.0280e-04 - mae: 0.0155 - val_loss: 0.0164 - val_mae: 0.0953
#
# Epoch 00117: val_mae did not improve from 0.05314
# Epoch 118/1000
# 48/48 - 1s - loss: 3.9345e-04 - mae: 0.0154 - val_loss: 0.0171 - val_mae: 0.0968
#
# Epoch 00118: val_mae did not improve from 0.05314
# Epoch 119/1000
# 48/48 - 1s - loss: 4.5433e-04 - mae: 0.0165 - val_loss: 0.0172 - val_mae: 0.0974
#
# Epoch 00119: val_mae did not improve from 0.05314
# Epoch 120/1000
# 48/48 - 1s - loss: 4.1466e-04 - mae: 0.0158 - val_loss: 0.0169 - val_mae: 0.0967
#
# Epoch 00120: val_mae did not improve from 0.05314
# Epoch 121/1000
# 48/48 - 1s - loss: 4.0511e-04 - mae: 0.0156 - val_loss: 0.0168 - val_mae: 0.0962
#
# Epoch 00121: val_mae did not improve from 0.05314
# Epoch 122/1000
# 48/48 - 1s - loss: 4.2654e-04 - mae: 0.0161 - val_loss: 0.0167 - val_mae: 0.0963
#
# Epoch 00122: val_mae did not improve from 0.05314
# Epoch 123/1000
# 48/48 - 1s - loss: 4.4133e-04 - mae: 0.0164 - val_loss: 0.0166 - val_mae: 0.0960
#
# Epoch 00123: val_mae did not improve from 0.05314
# Epoch 124/1000
# 48/48 - 1s - loss: 3.8427e-04 - mae: 0.0152 - val_loss: 0.0168 - val_mae: 0.0966
#
# Epoch 00124: val_mae did not improve from 0.05314
# Epoch 125/1000
# 48/48 - 1s - loss: 3.7801e-04 - mae: 0.0151 - val_loss: 0.0176 - val_mae: 0.0987
#
# Epoch 00125: val_mae did not improve from 0.05314
# Epoch 126/1000
# 48/48 - 1s - loss: 4.4149e-04 - mae: 0.0164 - val_loss: 0.0165 - val_mae: 0.0959
#
# Epoch 00126: val_mae did not improve from 0.05314
# Epoch 127/1000
# 48/48 - 1s - loss: 4.2069e-04 - mae: 0.0160 - val_loss: 0.0167 - val_mae: 0.0965
#
# Epoch 00127: val_mae did not improve from 0.05314
# Epoch 128/1000
# 48/48 - 1s - loss: 3.9918e-04 - mae: 0.0155 - val_loss: 0.0176 - val_mae: 0.0982
#
# Epoch 00128: val_mae did not improve from 0.05314
# Epoch 129/1000
# 48/48 - 1s - loss: 4.8963e-04 - mae: 0.0173 - val_loss: 0.0165 - val_mae: 0.0957
#
# Epoch 00129: val_mae did not improve from 0.05314
# Epoch 130/1000
# 48/48 - 1s - loss: 3.6163e-04 - mae: 0.0147 - val_loss: 0.0167 - val_mae: 0.0959
#
# Epoch 00130: val_mae did not improve from 0.05314
# Epoch 131/1000
# 48/48 - 1s - loss: 3.4964e-04 - mae: 0.0145 - val_loss: 0.0168 - val_mae: 0.0968
#
# Epoch 00131: val_mae did not improve from 0.05314
# Epoch 132/1000
# 48/48 - 1s - loss: 3.8038e-04 - mae: 0.0151 - val_loss: 0.0171 - val_mae: 0.0975
#
# Epoch 00132: val_mae did not improve from 0.05314
# Epoch 133/1000
# 48/48 - 1s - loss: 3.7171e-04 - mae: 0.0149 - val_loss: 0.0167 - val_mae: 0.0961
#
# Epoch 00133: val_mae did not improve from 0.05314
# Epoch 134/1000
# 48/48 - 1s - loss: 4.5620e-04 - mae: 0.0167 - val_loss: 0.0161 - val_mae: 0.0949
#
# Epoch 00134: val_mae did not improve from 0.05314
# Epoch 135/1000
# 48/48 - 1s - loss: 3.5179e-04 - mae: 0.0145 - val_loss: 0.0167 - val_mae: 0.0966
#
# Epoch 00135: val_mae did not improve from 0.05314
# Epoch 136/1000
# 48/48 - 1s - loss: 3.4288e-04 - mae: 0.0143 - val_loss: 0.0166 - val_mae: 0.0962
#
# Epoch 00136: val_mae did not improve from 0.05314
# Epoch 137/1000
# 48/48 - 1s - loss: 4.1098e-04 - mae: 0.0158 - val_loss: 0.0159 - val_mae: 0.0943
#
# Epoch 00137: val_mae did not improve from 0.05314
# Epoch 138/1000
# 48/48 - 1s - loss: 3.4517e-04 - mae: 0.0144 - val_loss: 0.0174 - val_mae: 0.0984
#
# Epoch 00138: val_mae did not improve from 0.05314
# Epoch 139/1000
# 48/48 - 1s - loss: 3.7143e-04 - mae: 0.0150 - val_loss: 0.0164 - val_mae: 0.0959
#
# Epoch 00139: val_mae did not improve from 0.05314
# Epoch 140/1000
# 48/48 - 1s - loss: 3.9422e-04 - mae: 0.0155 - val_loss: 0.0166 - val_mae: 0.0965
#
# Epoch 00140: val_mae did not improve from 0.05314
# Epoch 141/1000
# 48/48 - 1s - loss: 4.6456e-04 - mae: 0.0169 - val_loss: 0.0165 - val_mae: 0.0962
#
# Epoch 00141: val_mae did not improve from 0.05314
# Epoch 142/1000
# 48/48 - 1s - loss: 4.1219e-04 - mae: 0.0158 - val_loss: 0.0162 - val_mae: 0.0952
#
# Epoch 00142: val_mae did not improve from 0.05314
# Epoch 143/1000
# 48/48 - 1s - loss: 3.5383e-04 - mae: 0.0146 - val_loss: 0.0158 - val_mae: 0.0939
#
# Epoch 00143: val_mae did not improve from 0.05314
# Epoch 144/1000
# 48/48 - 1s - loss: 3.6724e-04 - mae: 0.0149 - val_loss: 0.0161 - val_mae: 0.0947
#
# Epoch 00144: val_mae did not improve from 0.05314
# Epoch 145/1000
# 48/48 - 1s - loss: 3.2687e-04 - mae: 0.0140 - val_loss: 0.0167 - val_mae: 0.0964
#
# Epoch 00145: val_mae did not improve from 0.05314
# Epoch 146/1000
# 48/48 - 1s - loss: 3.3977e-04 - mae: 0.0143 - val_loss: 0.0166 - val_mae: 0.0965
#
# Epoch 00146: val_mae did not improve from 0.05314
# Epoch 147/1000
# 48/48 - 1s - loss: 3.3283e-04 - mae: 0.0141 - val_loss: 0.0169 - val_mae: 0.0972
#
# Epoch 00147: val_mae did not improve from 0.05314
# Epoch 148/1000
# 48/48 - 1s - loss: 3.6127e-04 - mae: 0.0148 - val_loss: 0.0165 - val_mae: 0.0961
#
# Epoch 00148: val_mae did not improve from 0.05314
# Epoch 149/1000
# 48/48 - 1s - loss: 3.9982e-04 - mae: 0.0156 - val_loss: 0.0165 - val_mae: 0.0959
#
# Epoch 00149: val_mae did not improve from 0.05314
# Epoch 150/1000
# 48/48 - 1s - loss: 3.2148e-04 - mae: 0.0139 - val_loss: 0.0163 - val_mae: 0.0958
#
# Epoch 00150: val_mae did not improve from 0.05314
# Epoch 151/1000
# 48/48 - 1s - loss: 3.6430e-04 - mae: 0.0149 - val_loss: 0.0164 - val_mae: 0.0954
#
# Epoch 00151: val_mae did not improve from 0.05314
# Epoch 152/1000
# 48/48 - 1s - loss: 3.1522e-04 - mae: 0.0137 - val_loss: 0.0165 - val_mae: 0.0964
#
# Epoch 00152: val_mae did not improve from 0.05314
# Epoch 153/1000
# 48/48 - 1s - loss: 3.8993e-04 - mae: 0.0154 - val_loss: 0.0164 - val_mae: 0.0958
#
# Epoch 00153: val_mae did not improve from 0.05314
# Epoch 154/1000
# 48/48 - 1s - loss: 3.7885e-04 - mae: 0.0152 - val_loss: 0.0159 - val_mae: 0.0947
#
# Epoch 00154: val_mae did not improve from 0.05314
# Epoch 155/1000
# 48/48 - 1s - loss: 3.2270e-04 - mae: 0.0139 - val_loss: 0.0167 - val_mae: 0.0967
#
# Epoch 00155: val_mae did not improve from 0.05314
# Epoch 156/1000
# 48/48 - 1s - loss: 3.9380e-04 - mae: 0.0155 - val_loss: 0.0169 - val_mae: 0.0971
#
# Epoch 00156: val_mae did not improve from 0.05314
# Epoch 157/1000
# 48/48 - 1s - loss: 3.4022e-04 - mae: 0.0143 - val_loss: 0.0165 - val_mae: 0.0965
#
# Epoch 00157: val_mae did not improve from 0.05314
# Epoch 158/1000
# 48/48 - 1s - loss: 3.1421e-04 - mae: 0.0137 - val_loss: 0.0162 - val_mae: 0.0953
#
# Epoch 00158: val_mae did not improve from 0.05314
# Epoch 159/1000
# 48/48 - 1s - loss: 4.3667e-04 - mae: 0.0163 - val_loss: 0.0155 - val_mae: 0.0938
#
# Epoch 00159: val_mae did not improve from 0.05314
# Epoch 160/1000
# 48/48 - 1s - loss: 3.1601e-04 - mae: 0.0138 - val_loss: 0.0161 - val_mae: 0.0950
#
# Epoch 00160: val_mae did not improve from 0.05314
# Epoch 161/1000
# 48/48 - 1s - loss: 3.1775e-04 - mae: 0.0138 - val_loss: 0.0161 - val_mae: 0.0957
#
# Epoch 00161: val_mae did not improve from 0.05314
# Epoch 162/1000
# 48/48 - 1s - loss: 4.0827e-04 - mae: 0.0158 - val_loss: 0.0158 - val_mae: 0.0942
#
# Epoch 00162: val_mae did not improve from 0.05314
# Epoch 163/1000
# 48/48 - 1s - loss: 3.1450e-04 - mae: 0.0137 - val_loss: 0.0162 - val_mae: 0.0956
#
# Epoch 00163: val_mae did not improve from 0.05314
# Epoch 164/1000
# 48/48 - 1s - loss: 3.6917e-04 - mae: 0.0150 - val_loss: 0.0159 - val_mae: 0.0947
#
# Epoch 00164: val_mae did not improve from 0.05314
# Epoch 165/1000
# 48/48 - 1s - loss: 3.5331e-04 - mae: 0.0146 - val_loss: 0.0161 - val_mae: 0.0951
#
# Epoch 00165: val_mae did not improve from 0.05314
# Epoch 166/1000
# 48/48 - 1s - loss: 3.1794e-04 - mae: 0.0138 - val_loss: 0.0158 - val_mae: 0.0943
#
# Epoch 00166: val_mae did not improve from 0.05314
# Epoch 167/1000
# 48/48 - 1s - loss: 2.9058e-04 - mae: 0.0132 - val_loss: 0.0163 - val_mae: 0.0957
#
# Epoch 00167: val_mae did not improve from 0.05314
# Epoch 168/1000
# 48/48 - 1s - loss: 3.0151e-04 - mae: 0.0135 - val_loss: 0.0166 - val_mae: 0.0970
#
# Epoch 00168: val_mae did not improve from 0.05314
# Epoch 169/1000
# 48/48 - 1s - loss: 4.8775e-04 - mae: 0.0174 - val_loss: 0.0153 - val_mae: 0.0930
#
# Epoch 00169: val_mae did not improve from 0.05314
# Epoch 170/1000
# 48/48 - 1s - loss: 3.3684e-04 - mae: 0.0143 - val_loss: 0.0159 - val_mae: 0.0945
#
# Epoch 00170: val_mae did not improve from 0.05314
# Epoch 171/1000
# 48/48 - 1s - loss: 2.8675e-04 - mae: 0.0131 - val_loss: 0.0163 - val_mae: 0.0960
#
# Epoch 00171: val_mae did not improve from 0.05314
# Epoch 172/1000
# 48/48 - 1s - loss: 2.9630e-04 - mae: 0.0133 - val_loss: 0.0155 - val_mae: 0.0937
#
# Epoch 00172: val_mae did not improve from 0.05314
# Epoch 173/1000
# 48/48 - 1s - loss: 3.1105e-04 - mae: 0.0137 - val_loss: 0.0163 - val_mae: 0.0960
#
# Epoch 00173: val_mae did not improve from 0.05314
# Epoch 174/1000
# 48/48 - 1s - loss: 2.8965e-04 - mae: 0.0132 - val_loss: 0.0164 - val_mae: 0.0961
#
# Epoch 00174: val_mae did not improve from 0.05314
# Epoch 175/1000
# 48/48 - 1s - loss: 2.9180e-04 - mae: 0.0132 - val_loss: 0.0160 - val_mae: 0.0949
#
# Epoch 00175: val_mae did not improve from 0.05314
# Epoch 176/1000
# 48/48 - 1s - loss: 4.1707e-04 - mae: 0.0160 - val_loss: 0.0153 - val_mae: 0.0934
#
# Epoch 00176: val_mae did not improve from 0.05314
# Epoch 177/1000
# 48/48 - 1s - loss: 2.8599e-04 - mae: 0.0131 - val_loss: 0.0156 - val_mae: 0.0942
#
# Epoch 00177: val_mae did not improve from 0.05314
# Epoch 178/1000
# 48/48 - 1s - loss: 3.1461e-04 - mae: 0.0138 - val_loss: 0.0157 - val_mae: 0.0946
#
# Epoch 00178: val_mae did not improve from 0.05314
# Epoch 179/1000
# 48/48 - 1s - loss: 2.9463e-04 - mae: 0.0133 - val_loss: 0.0158 - val_mae: 0.0951
#
# Epoch 00179: val_mae did not improve from 0.05314
# Epoch 180/1000
# 48/48 - 1s - loss: 2.6827e-04 - mae: 0.0126 - val_loss: 0.0161 - val_mae: 0.0950
#
# Epoch 00180: val_mae did not improve from 0.05314
# Epoch 181/1000
# 48/48 - 1s - loss: 2.9389e-04 - mae: 0.0133 - val_loss: 0.0161 - val_mae: 0.0959
#
# Epoch 00181: val_mae did not improve from 0.05314
# Epoch 182/1000
# 48/48 - 1s - loss: 3.0759e-04 - mae: 0.0136 - val_loss: 0.0159 - val_mae: 0.0950
#
# Epoch 00182: val_mae did not improve from 0.05314
# Epoch 183/1000
# 48/48 - 1s - loss: 2.8589e-04 - mae: 0.0131 - val_loss: 0.0159 - val_mae: 0.0952
#
# Epoch 00183: val_mae did not improve from 0.05314
# Epoch 184/1000
# 48/48 - 1s - loss: 2.8547e-04 - mae: 0.0131 - val_loss: 0.0159 - val_mae: 0.0948
#
# Epoch 00184: val_mae did not improve from 0.05314
# Epoch 185/1000
# 48/48 - 1s - loss: 3.4563e-04 - mae: 0.0145 - val_loss: 0.0154 - val_mae: 0.0934
#
# Epoch 00185: val_mae did not improve from 0.05314
# Epoch 186/1000
# 48/48 - 1s - loss: 3.4741e-04 - mae: 0.0146 - val_loss: 0.0158 - val_mae: 0.0941
#
# Epoch 00186: val_mae did not improve from 0.05314
# Epoch 187/1000
# 48/48 - 1s - loss: 3.6187e-04 - mae: 0.0148 - val_loss: 0.0159 - val_mae: 0.0950
#
# Epoch 00187: val_mae did not improve from 0.05314
# Epoch 188/1000
# 48/48 - 1s - loss: 2.7994e-04 - mae: 0.0130 - val_loss: 0.0154 - val_mae: 0.0932
#
# Epoch 00188: val_mae did not improve from 0.05314
# Epoch 189/1000
# 48/48 - 1s - loss: 2.5646e-04 - mae: 0.0123 - val_loss: 0.0160 - val_mae: 0.0951
#
# Epoch 00189: val_mae did not improve from 0.05314
# Epoch 190/1000
# 48/48 - 1s - loss: 3.0890e-04 - mae: 0.0136 - val_loss: 0.0157 - val_mae: 0.0940
#
# Epoch 00190: val_mae did not improve from 0.05314
# Epoch 191/1000
# 48/48 - 1s - loss: 3.1411e-04 - mae: 0.0138 - val_loss: 0.0157 - val_mae: 0.0945
#
# Epoch 00191: val_mae did not improve from 0.05314
# Epoch 192/1000
# 48/48 - 1s - loss: 3.6756e-04 - mae: 0.0150 - val_loss: 0.0149 - val_mae: 0.0923
#
# Epoch 00192: val_mae did not improve from 0.05314
# Epoch 193/1000
# 48/48 - 1s - loss: 3.2095e-04 - mae: 0.0139 - val_loss: 0.0152 - val_mae: 0.0930
#
# Epoch 00193: val_mae did not improve from 0.05314
# Epoch 194/1000
# 48/48 - 1s - loss: 2.6540e-04 - mae: 0.0126 - val_loss: 0.0156 - val_mae: 0.0941
#
# Epoch 00194: val_mae did not improve from 0.05314
# Epoch 195/1000
# 48/48 - 1s - loss: 2.4374e-04 - mae: 0.0120 - val_loss: 0.0157 - val_mae: 0.0941
#
# Epoch 00195: val_mae did not improve from 0.05314
# Epoch 196/1000
# 48/48 - 1s - loss: 2.9006e-04 - mae: 0.0132 - val_loss: 0.0159 - val_mae: 0.0950
#
# Epoch 00196: val_mae did not improve from 0.05314
# Epoch 197/1000
# 48/48 - 1s - loss: 3.1723e-04 - mae: 0.0139 - val_loss: 0.0159 - val_mae: 0.0945
#
# Epoch 00197: val_mae did not improve from 0.05314
# Epoch 198/1000
# 48/48 - 1s - loss: 2.7112e-04 - mae: 0.0127 - val_loss: 0.0158 - val_mae: 0.0946
#
# Epoch 00198: val_mae did not improve from 0.05314
# Epoch 199/1000
# 48/48 - 1s - loss: 2.8239e-04 - mae: 0.0130 - val_loss: 0.0159 - val_mae: 0.0948
#
# Epoch 00199: val_mae did not improve from 0.05314
# Epoch 200/1000
# 48/48 - 1s - loss: 3.1665e-04 - mae: 0.0138 - val_loss: 0.0157 - val_mae: 0.0942
#
# Epoch 00200: val_mae did not improve from 0.05314
# Epoch 201/1000
# 48/48 - 1s - loss: 3.2052e-04 - mae: 0.0140 - val_loss: 0.0153 - val_mae: 0.0929
#
# Epoch 00201: val_mae did not improve from 0.05314
# Epoch 202/1000
# 48/48 - 1s - loss: 2.6562e-04 - mae: 0.0126 - val_loss: 0.0158 - val_mae: 0.0946
#
# Epoch 00202: val_mae did not improve from 0.05314
# Epoch 203/1000
# 48/48 - 1s - loss: 3.8832e-04 - mae: 0.0155 - val_loss: 0.0151 - val_mae: 0.0925
#
# Epoch 00203: val_mae did not improve from 0.05314
# Epoch 204/1000
# 48/48 - 1s - loss: 3.2445e-04 - mae: 0.0140 - val_loss: 0.0153 - val_mae: 0.0929
#
# Epoch 00204: val_mae did not improve from 0.05314
# Epoch 205/1000
# 48/48 - 1s - loss: 2.4625e-04 - mae: 0.0121 - val_loss: 0.0156 - val_mae: 0.0937
#
# Epoch 00205: val_mae did not improve from 0.05314
# Epoch 206/1000
# 48/48 - 1s - loss: 2.5378e-04 - mae: 0.0123 - val_loss: 0.0155 - val_mae: 0.0941
#
# Epoch 00206: val_mae did not improve from 0.05314
# Epoch 207/1000
# 48/48 - 1s - loss: 3.3237e-04 - mae: 0.0143 - val_loss: 0.0155 - val_mae: 0.0937
#
# Epoch 00207: val_mae did not improve from 0.05314
# Epoch 208/1000
# 48/48 - 1s - loss: 3.1112e-04 - mae: 0.0137 - val_loss: 0.0147 - val_mae: 0.0911
#
# Epoch 00208: val_mae did not improve from 0.05314
# Epoch 209/1000
# 48/48 - 1s - loss: 2.5653e-04 - mae: 0.0124 - val_loss: 0.0153 - val_mae: 0.0932
#
# Epoch 00209: val_mae did not improve from 0.05314
# Epoch 210/1000
# 48/48 - 1s - loss: 2.5401e-04 - mae: 0.0123 - val_loss: 0.0154 - val_mae: 0.0934
#
# Epoch 00210: val_mae did not improve from 0.05314
# Epoch 211/1000
# 48/48 - 1s - loss: 2.8785e-04 - mae: 0.0132 - val_loss: 0.0154 - val_mae: 0.0932
#
# Epoch 00211: val_mae did not improve from 0.05314
# Epoch 212/1000
# 48/48 - 1s - loss: 2.7842e-04 - mae: 0.0130 - val_loss: 0.0151 - val_mae: 0.0925
#
# Epoch 00212: val_mae did not improve from 0.05314
# Epoch 213/1000
# 48/48 - 1s - loss: 2.7338e-04 - mae: 0.0128 - val_loss: 0.0155 - val_mae: 0.0934
#
# Epoch 00213: val_mae did not improve from 0.05314
# Epoch 214/1000
# 48/48 - 1s - loss: 3.0786e-04 - mae: 0.0137 - val_loss: 0.0151 - val_mae: 0.0920
#
# Epoch 00214: val_mae did not improve from 0.05314
# Epoch 215/1000
# 48/48 - 1s - loss: 2.6382e-04 - mae: 0.0126 - val_loss: 0.0151 - val_mae: 0.0926
#
# Epoch 00215: val_mae did not improve from 0.05314
# Epoch 00215: early stopping
