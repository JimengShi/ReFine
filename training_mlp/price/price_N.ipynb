# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../..'))

if module_path not in sys.path:
    sys.path.append(module_path)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from math import sqrt
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

from helper import series_to_supervised
from model.mlp import mlp_layer
# Out:
# 2024-02-02 15:18:40.911508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
# import random

# random.seed(10)
# print(random.random())

# %%
dataset = pd.read_csv('../../data/energy_weather.csv', index_col=0)
# https://www.kaggle.com/datasets/nicholasjhana/energy-consumption-generation-prices-and-weather

dataset.fillna(0, inplace=True)
data = dataset
data
# Out:
#                            price  price_dayahead  gen_coal  gen_gas  \
# time
# 2015-01-01 00:00:00+00:00  64.92           48.10    4755.0   5196.0
# 2015-01-01 01:00:00+00:00  64.48           47.33    4581.0   4857.0
# 2015-01-01 02:00:00+00:00  59.32           42.27    4131.0   4314.0
# 2015-01-01 03:00:00+00:00  56.04           38.41    3840.0   4130.0
# 2015-01-01 04:00:00+00:00  53.63           35.72    3590.0   4038.0
# ...                          ...             ...       ...      ...
# 2018-12-31 18:00:00+00:00  77.02           68.85    2628.0   7634.0
# 2018-12-31 19:00:00+00:00  76.16           68.40    2566.0   7241.0
# 2018-12-31 20:00:00+00:00  74.30           66.88    2422.0   7025.0
# 2018-12-31 21:00:00+00:00  69.89           63.93    2293.0   6562.0
# 2018-12-31 22:00:00+00:00  69.88           64.27    2166.0   6926.0
#
#                            load_actual  gen_lig  gen_oil  gen_oth_renew  \
# time
# 2015-01-01 00:00:00+00:00      24382.0    328.0    158.0           71.0
# 2015-01-01 01:00:00+00:00      22734.0    323.0    157.0           73.0
# 2015-01-01 02:00:00+00:00      21286.0    254.0    160.0           75.0
# 2015-01-01 03:00:00+00:00      20264.0    187.0    156.0           74.0
# 2015-01-01 04:00:00+00:00      19905.0    178.0    156.0           74.0
# ...                                ...      ...      ...            ...
# 2018-12-31 18:00:00+00:00      30653.0      0.0    178.0           95.0
# 2018-12-31 19:00:00+00:00      29735.0      0.0    174.0           95.0
# 2018-12-31 20:00:00+00:00      28071.0      0.0    168.0           94.0
# 2018-12-31 21:00:00+00:00      25801.0      0.0    163.0           93.0
# 2018-12-31 22:00:00+00:00      24455.0      0.0    163.0           92.0
#
#                            pressure_Barcelona  pressure_Bilbao  ...  \
# time                                                            ...
# 2015-01-01 00:00:00+00:00              1035.0           1035.0  ...
# 2015-01-01 01:00:00+00:00              1036.0           1036.0  ...
# 2015-01-01 02:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 03:00:00+00:00              1036.0           1035.0  ...
# 2015-01-01 04:00:00+00:00              1037.0           1035.0  ...
# ...                                       ...              ...  ...
# 2018-12-31 18:00:00+00:00              1027.0           1033.0  ...
# 2018-12-31 19:00:00+00:00              1027.0           1034.0  ...
# 2018-12-31 20:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 21:00:00+00:00              1028.0           1034.0  ...
# 2018-12-31 22:00:00+00:00              1028.0           1034.0  ...
#
#                            wind_deg_Bilbao  clouds_all_Bilbao  gen_hyd_river  \
# time
# 2015-01-01 00:00:00+00:00            229.0                0.0         1009.0
# 2015-01-01 01:00:00+00:00            224.0                0.0          973.0
# 2015-01-01 02:00:00+00:00            225.0                0.0          949.0
# 2015-01-01 03:00:00+00:00            221.0                0.0          953.0
# 2015-01-01 04:00:00+00:00            224.0                0.0          952.0
# ...                                    ...                ...            ...
# 2018-12-31 18:00:00+00:00             57.0                0.0         1135.0
# 2018-12-31 19:00:00+00:00              0.0                0.0         1172.0
# 2018-12-31 20:00:00+00:00            140.0                0.0         1148.0
# 2018-12-31 21:00:00+00:00            120.0                0.0         1128.0
# 2018-12-31 22:00:00+00:00            100.0                0.0         1069.0
#
#                            wind_deg_Seville  wind_speed_Barcelona  \
# time
# 2015-01-01 00:00:00+00:00              21.0                   7.0
# 2015-01-01 01:00:00+00:00              27.0                   7.0
# 2015-01-01 02:00:00+00:00              27.0                   7.0
# 2015-01-01 03:00:00+00:00              27.0                   7.0
# 2015-01-01 04:00:00+00:00              57.0                   5.0
# ...                                     ...                   ...
# 2018-12-31 18:00:00+00:00              30.0                   1.0
# 2018-12-31 19:00:00+00:00              30.0                   3.0
# 2018-12-31 20:00:00+00:00              50.0                   4.0
# 2018-12-31 21:00:00+00:00              60.0                   5.0
# 2018-12-31 22:00:00+00:00              50.0                   5.0
#
#                            wind_speed_Valencia  wind_speed_Bilbao  gen_wind  \
# time
# 2015-01-01 00:00:00+00:00                  1.0                0.0    5890.0
# 2015-01-01 01:00:00+00:00                  0.0                1.0    5461.0
# 2015-01-01 02:00:00+00:00                  0.0                1.0    5238.0
# 2015-01-01 03:00:00+00:00                  0.0                1.0    4935.0
# 2015-01-01 04:00:00+00:00                  2.0                1.0    4618.0
# ...                                        ...                ...       ...
# 2018-12-31 18:00:00+00:00                  2.0                0.0    3113.0
# 2018-12-31 19:00:00+00:00                  1.0                1.0    3288.0
# 2018-12-31 20:00:00+00:00                  3.0                1.0    3503.0
# 2018-12-31 21:00:00+00:00                  2.0                1.0    3586.0
# 2018-12-31 22:00:00+00:00                  2.0                2.0    3651.0
#
#                            wind_speed_Madrid  gen_hyd_pump
# time
# 2015-01-01 00:00:00+00:00                1.0         920.0
# 2015-01-01 01:00:00+00:00                1.0        1164.0
# 2015-01-01 02:00:00+00:00                1.0        1503.0
# 2015-01-01 03:00:00+00:00                1.0        1826.0
# 2015-01-01 04:00:00+00:00                0.0        2109.0
# ...                                      ...           ...
# 2018-12-31 18:00:00+00:00                1.0           1.0
# 2018-12-31 19:00:00+00:00                1.0           1.0
# 2018-12-31 20:00:00+00:00                1.0          50.0
# 2018-12-31 21:00:00+00:00                2.0         108.0
# 2018-12-31 22:00:00+00:00                1.0         108.0
#
# [35063 rows x 26 columns]

# %%
print(data['price'].min())
print(data['price'].max())
# Out:
# 9.33
# 116.8

# %%
data.columns
# Out:
# Index(['price', 'price_dayahead', 'gen_coal', 'gen_gas', 'load_actual',
#        'gen_lig', 'gen_oil', 'gen_oth_renew', 'pressure_Barcelona',
#        'pressure_Bilbao', 'gen_waste', 'gen_bio', 'temp_min_Valencia',
#        'pressure_Valencia', 'temp_min_Barcelona', 'humidity_Seville',
#        'wind_deg_Bilbao', 'clouds_all_Bilbao', 'gen_hyd_river',
#        'wind_deg_Seville', 'wind_speed_Barcelona', 'wind_speed_Valencia',
#        'wind_speed_Bilbao', 'gen_wind', 'wind_speed_Madrid', 'gen_hyd_pump'],
#       dtype='object')

# %%
# for col in data.columns:
#     plt.hist(data[col], bins=20)
#     plt.title(col)
#     plt.show()
#     plt.close()

# %%
np.percentile(data['price'], 95)
# Out:
# 79.17

# %% [markdown]
# ### Preprocess

# %%
values = data.values

# specify the number of lag hours
n_hours = 24*3
n_features = data.shape[-1]
k = 12
split1 = 0.7
split2 = 0.85

# frame as supervised learning
reframed = series_to_supervised(values, n_hours, k)
print("reframed.shape:", reframed.shape)
# Out:
# reframed.shape: (34980, 2184)

# %%
# split into train and test sets
reframed_values = reframed.values
n_train_hours = int(len(reframed_values)*split1)
n_valid_hours = int(len(reframed_values)*split2)

train = reframed_values[:n_train_hours, :]
val = reframed_values[n_train_hours:n_valid_hours, :]
test = reframed_values[n_valid_hours:, :]


# split into input and outputs
n_obs = n_hours * n_features
feature_idx = 0
train_X, train_y = train[:, :n_obs], train[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
val_X, val_y = val[:, :n_obs], val[:, [n_obs + feature_idx + n_features * i for i in range(k)]]
test_X, test_y = test[:, :n_obs], test[:, [n_obs + feature_idx + n_features * i for i in range(k)]]


print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 1872) (24486, 12) (5247, 1872) (5247, 12) (5247, 1872) (5247, 12)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

train_X = scaler.fit_transform(train_X)
train_y = scaler.fit_transform(train_y)

val_X = scaler.fit_transform(val_X)
val_y = scaler.fit_transform(val_y)

test_X = scaler.fit_transform(test_X)
test_y = scaler.fit_transform(test_y)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
val_X = val_X.reshape((val_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))

print("train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape", 
      train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape
     )
# Out:
# train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape (24486, 72, 26) (24486, 12) (5247, 72, 26) (5247, 12) (5247, 72, 26) (5247, 12)

# %% [markdown]
# ### Price threshold

# %%
train_X_pm = train_X[:, 0, feature_idx]
print(train_X_pm.shape)

val_X_pm = val_X[:, 0, feature_idx]
print(val_X_pm.shape)

test_X_pm = test_X[:, 0, feature_idx]
print(test_X_pm.shape)
# Out:
# (24486,)
# (5247,)
# (5247,)

# %%
percentile = 95

merged_array = np.concatenate((train_X_pm, val_X_pm, test_X_pm))

percentile_pm = np.percentile(merged_array, percentile)

print("{}th Percentile of Daily Rain:".format(percentile), percentile_pm)
# Out:
# 95th Percentile of Daily Rain: 0.7037105569454176

# %% [markdown]
# ### train_X_filter

# %%
train_X_extreme = train_X[train_X_pm > percentile_pm]
print(train_X_extreme.shape)

train_y_extreme = train_y[train_X_pm > percentile_pm]
print(train_y_extreme.shape)
# Out:
# (696, 72, 26)
# (696, 12)

# %%
train_X_normal = train_X[train_X_pm <= percentile_pm]
print(train_X_normal.shape)

train_y_normal = train_y[train_X_pm <= percentile_pm]
print(train_y_normal.shape)
# Out:
# (23790, 72, 26)
# (23790, 12)

# %% [markdown]
# ### val_X_filter

# %%
val_X_extreme = val_X[val_X_pm > percentile_pm]
print(val_X_extreme.shape)

val_y_extreme = val_y[val_X_pm > percentile_pm]
print(val_y_extreme.shape)
# Out:
# (55, 72, 26)
# (55, 12)

# %%
val_X_normal = val_X[val_X_pm <= percentile_pm]
print(val_X_normal.shape)

val_y_normal = val_y[val_X_pm <= percentile_pm]
print(val_y_normal.shape)
# Out:
# (5192, 72, 26)
# (5192, 12)

# %% [markdown]
# ### test_X_filter

# %%
test_X_extreme = test_X[test_X_pm > percentile_pm]
print(test_X_extreme.shape)

test_y_extreme = test_y[test_X_pm > percentile_pm]
print(test_y_extreme.shape)
# Out:
# (998, 72, 26)
# (998, 12)

# %%
test_X_normal = test_X[test_X_pm <= percentile_pm]
print(test_X_normal.shape)

test_y_normal = test_y[test_X_pm <= percentile_pm]
print(test_y_normal.shape)
# Out:
# (4249, 72, 26)
# (4249, 12)

# %% [markdown]
# ### Model & training

# %%
# plt.hist(train_y[:,0])

# %%
# ===== model parameters ======
mlp_unit1 = 128
mlp_unit2 = 128
mlp_unit3 = 64
mlp_unit4 = 64
mlp_unit5 = 32
mlp_unit6 = 32
mlp_unit7 = 16
mlp_unit8 = 16
dropout = 0.0  # 0.1
kernel_size = 2
pool_size = 2
learning_rate = 1e-4
decay_steps = 10000
decay_rate = 0.95
PATIENCE = 100
EPOCHS = 1000
BATCH = 512
opt_num = k
input_shape = train_X.shape[1:]

# %%
model = mlp_layer(input_shape=input_shape,
                   mlp_unit1=mlp_unit1,
                   mlp_unit2=mlp_unit2,
                   mlp_unit3=mlp_unit3,
                   mlp_unit4=mlp_unit4,
                   mlp_unit5=mlp_unit5,
                   mlp_unit6=mlp_unit6,
                   mlp_unit7=mlp_unit7,
                   mlp_unit8=mlp_unit8,
                   dropout=dropout,
                   masked_value=-1,
                   opt_num=opt_num
                  )
# model.summary()

# %%
# lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=learning_rate, 
#                                                           decay_steps=decay_steps,
#                                                           decay_rate=decay_rate)

# model.compile(optimizer=Adam(learning_rate=lr_schedule),
#               loss='mse',
#               metrics=['mae']
#              )

model.compile(optimizer='adam',
              loss='mse',
              metrics=['mae']
             )


es = EarlyStopping(monitor='val_mae', mode='min', verbose=2, patience=PATIENCE)
mc = ModelCheckpoint('../../saved_models/price_N.h5', 
                     monitor='val_mae', 
                     mode='min', 
                     verbose=2, 
                     save_best_only=True
                    )


model.fit(train_X_normal, train_y_normal,
          validation_data=(val_X_normal, val_y_normal),
          epochs=EPOCHS,
          batch_size=BATCH,
          verbose=2,
          shuffle=True,
          callbacks=[es, mc]
         )
# Out:
# 2024-02-02 15:20:50.819807: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-02-02 15:20:50.820693: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 1700105000 Hz
# Epoch 1/1000
# 2024-02-02 15:20:52.380354: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 47/47 - 4s - loss: 0.0256 - mae: 0.1173 - val_loss: 0.0142 - val_mae: 0.0897
#
# Epoch 00001: val_mae improved from inf to 0.08966, saving model to ../../saved_models/price_N.h5
# Epoch 2/1000
# 47/47 - 1s - loss: 0.0092 - mae: 0.0750 - val_loss: 0.0120 - val_mae: 0.0842
#
# Epoch 00002: val_mae improved from 0.08966 to 0.08416, saving model to ../../saved_models/price_N.h5
# Epoch 3/1000
# 47/47 - 1s - loss: 0.0079 - mae: 0.0699 - val_loss: 0.0107 - val_mae: 0.0791
#
# Epoch 00003: val_mae improved from 0.08416 to 0.07912, saving model to ../../saved_models/price_N.h5
# Epoch 4/1000
# 47/47 - 1s - loss: 0.0070 - mae: 0.0649 - val_loss: 0.0095 - val_mae: 0.0730
#
# Epoch 00004: val_mae improved from 0.07912 to 0.07301, saving model to ../../saved_models/price_N.h5
# Epoch 5/1000
# 47/47 - 1s - loss: 0.0056 - mae: 0.0569 - val_loss: 0.0089 - val_mae: 0.0699
#
# Epoch 00005: val_mae improved from 0.07301 to 0.06990, saving model to ../../saved_models/price_N.h5
# Epoch 6/1000
# 47/47 - 1s - loss: 0.0047 - mae: 0.0522 - val_loss: 0.0071 - val_mae: 0.0632
#
# Epoch 00006: val_mae improved from 0.06990 to 0.06319, saving model to ../../saved_models/price_N.h5
# Epoch 7/1000
# 47/47 - 1s - loss: 0.0043 - mae: 0.0499 - val_loss: 0.0069 - val_mae: 0.0616
#
# Epoch 00007: val_mae improved from 0.06319 to 0.06164, saving model to ../../saved_models/price_N.h5
# Epoch 8/1000
# 47/47 - 1s - loss: 0.0039 - mae: 0.0472 - val_loss: 0.0066 - val_mae: 0.0598
#
# Epoch 00008: val_mae improved from 0.06164 to 0.05976, saving model to ../../saved_models/price_N.h5
# Epoch 9/1000
# 47/47 - 1s - loss: 0.0037 - mae: 0.0461 - val_loss: 0.0060 - val_mae: 0.0569
#
# Epoch 00009: val_mae improved from 0.05976 to 0.05689, saving model to ../../saved_models/price_N.h5
# Epoch 10/1000
# 47/47 - 1s - loss: 0.0036 - mae: 0.0453 - val_loss: 0.0059 - val_mae: 0.0573
#
# Epoch 00010: val_mae did not improve from 0.05689
# Epoch 11/1000
# 47/47 - 1s - loss: 0.0033 - mae: 0.0432 - val_loss: 0.0062 - val_mae: 0.0592
#
# Epoch 00011: val_mae did not improve from 0.05689
# Epoch 12/1000
# 47/47 - 1s - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0057 - val_mae: 0.0554
#
# Epoch 00012: val_mae improved from 0.05689 to 0.05543, saving model to ../../saved_models/price_N.h5
# Epoch 13/1000
# 47/47 - 1s - loss: 0.0030 - mae: 0.0414 - val_loss: 0.0057 - val_mae: 0.0554
#
# Epoch 00013: val_mae improved from 0.05543 to 0.05536, saving model to ../../saved_models/price_N.h5
# Epoch 14/1000
# 47/47 - 1s - loss: 0.0030 - mae: 0.0415 - val_loss: 0.0058 - val_mae: 0.0558
#
# Epoch 00014: val_mae did not improve from 0.05536
# Epoch 15/1000
# 47/47 - 1s - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0057 - val_mae: 0.0562
#
# Epoch 00015: val_mae did not improve from 0.05536
# Epoch 16/1000
# 47/47 - 1s - loss: 0.0028 - mae: 0.0400 - val_loss: 0.0059 - val_mae: 0.0576
#
# Epoch 00016: val_mae did not improve from 0.05536
# Epoch 17/1000
# 47/47 - 1s - loss: 0.0028 - mae: 0.0403 - val_loss: 0.0057 - val_mae: 0.0557
#
# Epoch 00017: val_mae did not improve from 0.05536
# Epoch 18/1000
# 47/47 - 1s - loss: 0.0025 - mae: 0.0376 - val_loss: 0.0058 - val_mae: 0.0569
#
# Epoch 00018: val_mae did not improve from 0.05536
# Epoch 19/1000
# 47/47 - 1s - loss: 0.0025 - mae: 0.0379 - val_loss: 0.0060 - val_mae: 0.0577
#
# Epoch 00019: val_mae did not improve from 0.05536
# Epoch 20/1000
# 47/47 - 1s - loss: 0.0024 - mae: 0.0370 - val_loss: 0.0060 - val_mae: 0.0577
#
# Epoch 00020: val_mae did not improve from 0.05536
# Epoch 21/1000
# 47/47 - 1s - loss: 0.0023 - mae: 0.0369 - val_loss: 0.0064 - val_mae: 0.0610
#
# Epoch 00021: val_mae did not improve from 0.05536
# Epoch 22/1000
# 47/47 - 1s - loss: 0.0022 - mae: 0.0357 - val_loss: 0.0062 - val_mae: 0.0588
#
# Epoch 00022: val_mae did not improve from 0.05536
# Epoch 23/1000
# 47/47 - 1s - loss: 0.0021 - mae: 0.0353 - val_loss: 0.0067 - val_mae: 0.0627
#
# Epoch 00023: val_mae did not improve from 0.05536
# Epoch 24/1000
# 47/47 - 1s - loss: 0.0021 - mae: 0.0351 - val_loss: 0.0062 - val_mae: 0.0582
#
# Epoch 00024: val_mae did not improve from 0.05536
# Epoch 25/1000
# 47/47 - 1s - loss: 0.0019 - mae: 0.0339 - val_loss: 0.0063 - val_mae: 0.0589
#
# Epoch 00025: val_mae did not improve from 0.05536
# Epoch 26/1000
# 47/47 - 1s - loss: 0.0018 - mae: 0.0327 - val_loss: 0.0071 - val_mae: 0.0644
#
# Epoch 00026: val_mae did not improve from 0.05536
# Epoch 27/1000
# 47/47 - 1s - loss: 0.0018 - mae: 0.0330 - val_loss: 0.0065 - val_mae: 0.0598
#
# Epoch 00027: val_mae did not improve from 0.05536
# Epoch 28/1000
# 47/47 - 1s - loss: 0.0016 - mae: 0.0310 - val_loss: 0.0067 - val_mae: 0.0612
#
# Epoch 00028: val_mae did not improve from 0.05536
# Epoch 29/1000
# 47/47 - 1s - loss: 0.0016 - mae: 0.0315 - val_loss: 0.0076 - val_mae: 0.0645
#
# Epoch 00029: val_mae did not improve from 0.05536
# Epoch 30/1000
# 47/47 - 1s - loss: 0.0015 - mae: 0.0297 - val_loss: 0.0072 - val_mae: 0.0631
#
# Epoch 00030: val_mae did not improve from 0.05536
# Epoch 31/1000
# 47/47 - 1s - loss: 0.0014 - mae: 0.0295 - val_loss: 0.0074 - val_mae: 0.0639
#
# Epoch 00031: val_mae did not improve from 0.05536
# Epoch 32/1000
# 47/47 - 1s - loss: 0.0013 - mae: 0.0284 - val_loss: 0.0082 - val_mae: 0.0670
#
# Epoch 00032: val_mae did not improve from 0.05536
# Epoch 33/1000
# 47/47 - 1s - loss: 0.0014 - mae: 0.0286 - val_loss: 0.0083 - val_mae: 0.0673
#
# Epoch 00033: val_mae did not improve from 0.05536
# Epoch 34/1000
# 47/47 - 1s - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0087 - val_mae: 0.0684
#
# Epoch 00034: val_mae did not improve from 0.05536
# Epoch 35/1000
# 47/47 - 1s - loss: 0.0012 - mae: 0.0272 - val_loss: 0.0089 - val_mae: 0.0691
#
# Epoch 00035: val_mae did not improve from 0.05536
# Epoch 36/1000
# 47/47 - 1s - loss: 0.0012 - mae: 0.0266 - val_loss: 0.0087 - val_mae: 0.0687
#
# Epoch 00036: val_mae did not improve from 0.05536
# Epoch 37/1000
# 47/47 - 1s - loss: 0.0011 - mae: 0.0262 - val_loss: 0.0098 - val_mae: 0.0730
#
# Epoch 00037: val_mae did not improve from 0.05536
# Epoch 38/1000
# 47/47 - 1s - loss: 0.0011 - mae: 0.0257 - val_loss: 0.0104 - val_mae: 0.0760
#
# Epoch 00038: val_mae did not improve from 0.05536
# Epoch 39/1000
# 47/47 - 1s - loss: 0.0011 - mae: 0.0262 - val_loss: 0.0097 - val_mae: 0.0721
#
# Epoch 00039: val_mae did not improve from 0.05536
# Epoch 40/1000
# 47/47 - 1s - loss: 0.0010 - mae: 0.0252 - val_loss: 0.0096 - val_mae: 0.0719
#
# Epoch 00040: val_mae did not improve from 0.05536
# Epoch 41/1000
# 47/47 - 1s - loss: 9.8813e-04 - mae: 0.0245 - val_loss: 0.0113 - val_mae: 0.0776
#
# Epoch 00041: val_mae did not improve from 0.05536
# Epoch 42/1000
# 47/47 - 1s - loss: 9.8838e-04 - mae: 0.0245 - val_loss: 0.0105 - val_mae: 0.0747
#
# Epoch 00042: val_mae did not improve from 0.05536
# Epoch 43/1000
# 47/47 - 1s - loss: 9.1650e-04 - mae: 0.0236 - val_loss: 0.0112 - val_mae: 0.0774
#
# Epoch 00043: val_mae did not improve from 0.05536
# Epoch 44/1000
# 47/47 - 1s - loss: 8.9981e-04 - mae: 0.0234 - val_loss: 0.0106 - val_mae: 0.0744
#
# Epoch 00044: val_mae did not improve from 0.05536
# Epoch 45/1000
# 47/47 - 1s - loss: 9.6593e-04 - mae: 0.0242 - val_loss: 0.0116 - val_mae: 0.0793
#
# Epoch 00045: val_mae did not improve from 0.05536
# Epoch 46/1000
# 47/47 - 1s - loss: 8.9818e-04 - mae: 0.0234 - val_loss: 0.0115 - val_mae: 0.0782
#
# Epoch 00046: val_mae did not improve from 0.05536
# Epoch 47/1000
# 47/47 - 1s - loss: 8.3263e-04 - mae: 0.0225 - val_loss: 0.0115 - val_mae: 0.0786
#
# Epoch 00047: val_mae did not improve from 0.05536
# Epoch 48/1000
# 47/47 - 1s - loss: 8.0814e-04 - mae: 0.0221 - val_loss: 0.0117 - val_mae: 0.0793
#
# Epoch 00048: val_mae did not improve from 0.05536
# Epoch 49/1000
# 47/47 - 1s - loss: 8.0218e-04 - mae: 0.0220 - val_loss: 0.0117 - val_mae: 0.0787
#
# Epoch 00049: val_mae did not improve from 0.05536
# Epoch 50/1000
# 47/47 - 1s - loss: 7.8293e-04 - mae: 0.0218 - val_loss: 0.0115 - val_mae: 0.0775
#
# Epoch 00050: val_mae did not improve from 0.05536
# Epoch 51/1000
# 47/47 - 1s - loss: 7.9456e-04 - mae: 0.0220 - val_loss: 0.0132 - val_mae: 0.0842
#
# Epoch 00051: val_mae did not improve from 0.05536
# Epoch 52/1000
# 47/47 - 1s - loss: 8.1986e-04 - mae: 0.0224 - val_loss: 0.0131 - val_mae: 0.0835
#
# Epoch 00052: val_mae did not improve from 0.05536
# Epoch 53/1000
# 47/47 - 1s - loss: 7.4416e-04 - mae: 0.0213 - val_loss: 0.0126 - val_mae: 0.0826
#
# Epoch 00053: val_mae did not improve from 0.05536
# Epoch 54/1000
# 47/47 - 1s - loss: 7.3521e-04 - mae: 0.0211 - val_loss: 0.0120 - val_mae: 0.0791
# Epoch 00054: val_mae did not improve from 0.05536
# Epoch 55/1000
# 47/47 - 1s - loss: 7.5207e-04 - mae: 0.0214 - val_loss: 0.0123 - val_mae: 0.0803
#
# Epoch 00055: val_mae did not improve from 0.05536
# Epoch 56/1000
# 47/47 - 1s - loss: 7.0155e-04 - mae: 0.0206 - val_loss: 0.0128 - val_mae: 0.0825
#
# Epoch 00056: val_mae did not improve from 0.05536
# Epoch 57/1000
# 47/47 - 1s - loss: 6.6859e-04 - mae: 0.0201 - val_loss: 0.0126 - val_mae: 0.0811
#
# Epoch 00057: val_mae did not improve from 0.05536
# Epoch 58/1000
# 47/47 - 1s - loss: 6.5931e-04 - mae: 0.0200 - val_loss: 0.0124 - val_mae: 0.0811
#
# Epoch 00058: val_mae did not improve from 0.05536
# Epoch 59/1000
# 47/47 - 1s - loss: 7.5545e-04 - mae: 0.0215 - val_loss: 0.0127 - val_mae: 0.0822
#
# Epoch 00059: val_mae did not improve from 0.05536
# Epoch 60/1000
# 47/47 - 1s - loss: 6.9052e-04 - mae: 0.0205 - val_loss: 0.0123 - val_mae: 0.0804
#
# Epoch 00060: val_mae did not improve from 0.05536
# Epoch 61/1000
# 47/47 - 1s - loss: 7.2335e-04 - mae: 0.0210 - val_loss: 0.0141 - val_mae: 0.0864
#
# Epoch 00061: val_mae did not improve from 0.05536
# Epoch 62/1000
# 47/47 - 1s - loss: 6.3398e-04 - mae: 0.0196 - val_loss: 0.0131 - val_mae: 0.0825
#
# Epoch 00062: val_mae did not improve from 0.05536
# Epoch 63/1000
# 47/47 - 1s - loss: 5.9599e-04 - mae: 0.0190 - val_loss: 0.0130 - val_mae: 0.0826
#
# Epoch 00063: val_mae did not improve from 0.05536
# Epoch 64/1000
# 47/47 - 1s - loss: 6.0684e-04 - mae: 0.0192 - val_loss: 0.0134 - val_mae: 0.0835
#
# Epoch 00064: val_mae did not improve from 0.05536
# Epoch 65/1000
# 47/47 - 1s - loss: 5.9345e-04 - mae: 0.0190 - val_loss: 0.0138 - val_mae: 0.0854
#
# Epoch 00065: val_mae did not improve from 0.05536
# Epoch 66/1000
# 47/47 - 1s - loss: 6.2032e-04 - mae: 0.0194 - val_loss: 0.0131 - val_mae: 0.0828
#
# Epoch 00066: val_mae did not improve from 0.05536
# Epoch 67/1000
# 47/47 - 1s - loss: 7.1933e-04 - mae: 0.0210 - val_loss: 0.0146 - val_mae: 0.0885
#
# Epoch 00067: val_mae did not improve from 0.05536
# Epoch 68/1000
# 47/47 - 1s - loss: 7.1665e-04 - mae: 0.0210 - val_loss: 0.0133 - val_mae: 0.0832
#
# Epoch 00068: val_mae did not improve from 0.05536
# Epoch 69/1000
# 47/47 - 1s - loss: 5.6660e-04 - mae: 0.0185 - val_loss: 0.0138 - val_mae: 0.0856
#
# Epoch 00069: val_mae did not improve from 0.05536
# Epoch 70/1000
# 47/47 - 1s - loss: 5.4991e-04 - mae: 0.0183 - val_loss: 0.0134 - val_mae: 0.0839
#
# Epoch 00070: val_mae did not improve from 0.05536
# Epoch 71/1000
# 47/47 - 1s - loss: 5.7940e-04 - mae: 0.0188 - val_loss: 0.0142 - val_mae: 0.0876
#
# Epoch 00071: val_mae did not improve from 0.05536
# Epoch 72/1000
# 47/47 - 1s - loss: 5.6764e-04 - mae: 0.0185 - val_loss: 0.0140 - val_mae: 0.0863
#
# Epoch 00072: val_mae did not improve from 0.05536
# Epoch 73/1000
# 47/47 - 1s - loss: 5.5477e-04 - mae: 0.0183 - val_loss: 0.0135 - val_mae: 0.0843
#
# Epoch 00073: val_mae did not improve from 0.05536
# Epoch 74/1000
# 47/47 - 1s - loss: 5.9346e-04 - mae: 0.0190 - val_loss: 0.0140 - val_mae: 0.0863
#
# Epoch 00074: val_mae did not improve from 0.05536
# Epoch 75/1000
# 47/47 - 1s - loss: 5.2859e-04 - mae: 0.0179 - val_loss: 0.0141 - val_mae: 0.0868
#
# Epoch 00075: val_mae did not improve from 0.05536
# Epoch 76/1000
# 47/47 - 1s - loss: 5.4195e-04 - mae: 0.0181 - val_loss: 0.0153 - val_mae: 0.0908
#
# Epoch 00076: val_mae did not improve from 0.05536
# Epoch 77/1000
# 47/47 - 1s - loss: 5.6400e-04 - mae: 0.0185 - val_loss: 0.0144 - val_mae: 0.0883
#
# Epoch 00077: val_mae did not improve from 0.05536
# Epoch 78/1000
# 47/47 - 1s - loss: 5.7929e-04 - mae: 0.0188 - val_loss: 0.0143 - val_mae: 0.0875
#
# Epoch 00078: val_mae did not improve from 0.05536
# Epoch 79/1000
# 47/47 - 1s - loss: 5.3582e-04 - mae: 0.0181 - val_loss: 0.0141 - val_mae: 0.0866
#
# Epoch 00079: val_mae did not improve from 0.05536
# Epoch 80/1000
# 47/47 - 1s - loss: 5.3835e-04 - mae: 0.0181 - val_loss: 0.0139 - val_mae: 0.0863
#
# Epoch 00080: val_mae did not improve from 0.05536
# Epoch 81/1000
# 47/47 - 1s - loss: 5.5762e-04 - mae: 0.0185 - val_loss: 0.0141 - val_mae: 0.0873
#
# Epoch 00081: val_mae did not improve from 0.05536
# Epoch 82/1000
# 47/47 - 1s - loss: 5.1673e-04 - mae: 0.0177 - val_loss: 0.0142 - val_mae: 0.0868
#
# Epoch 00082: val_mae did not improve from 0.05536
# Epoch 83/1000
# 47/47 - 1s - loss: 4.9745e-04 - mae: 0.0174 - val_loss: 0.0142 - val_mae: 0.0867
#
# Epoch 00083: val_mae did not improve from 0.05536
# Epoch 84/1000
# 47/47 - 1s - loss: 5.7301e-04 - mae: 0.0188 - val_loss: 0.0143 - val_mae: 0.0877
#
# Epoch 00084: val_mae did not improve from 0.05536
# Epoch 85/1000
# 47/47 - 1s - loss: 4.9967e-04 - mae: 0.0174 - val_loss: 0.0134 - val_mae: 0.0840
#
# Epoch 00085: val_mae did not improve from 0.05536
# Epoch 86/1000
# 47/47 - 1s - loss: 4.8629e-04 - mae: 0.0172 - val_loss: 0.0150 - val_mae: 0.0902
#
# Epoch 00086: val_mae did not improve from 0.05536
# Epoch 87/1000
# 47/47 - 1s - loss: 4.9382e-04 - mae: 0.0173 - val_loss: 0.0144 - val_mae: 0.0876
#
# Epoch 00087: val_mae did not improve from 0.05536
# Epoch 88/1000
# 47/47 - 1s - loss: 6.0900e-04 - mae: 0.0194 - val_loss: 0.0145 - val_mae: 0.0883
#
# Epoch 00088: val_mae did not improve from 0.05536
# Epoch 89/1000
# 47/47 - 1s - loss: 5.1564e-04 - mae: 0.0178 - val_loss: 0.0146 - val_mae: 0.0891
#
# Epoch 00089: val_mae did not improve from 0.05536
# Epoch 90/1000
# 47/47 - 1s - loss: 5.3656e-04 - mae: 0.0182 - val_loss: 0.0149 - val_mae: 0.0900
#
# Epoch 00090: val_mae did not improve from 0.05536
# Epoch 91/1000
# 47/47 - 1s - loss: 4.6278e-04 - mae: 0.0168 - val_loss: 0.0146 - val_mae: 0.0890
#
# Epoch 00091: val_mae did not improve from 0.05536
# Epoch 92/1000
# 47/47 - 1s - loss: 4.6192e-04 - mae: 0.0168 - val_loss: 0.0143 - val_mae: 0.0883
#
# Epoch 00092: val_mae did not improve from 0.05536
# Epoch 93/1000
# 47/47 - 1s - loss: 4.5919e-04 - mae: 0.0167 - val_loss: 0.0146 - val_mae: 0.0894
#
# Epoch 00093: val_mae did not improve from 0.05536
# Epoch 94/1000
# 47/47 - 1s - loss: 4.3817e-04 - mae: 0.0163 - val_loss: 0.0140 - val_mae: 0.0871
#
# Epoch 00094: val_mae did not improve from 0.05536
# Epoch 95/1000
# 47/47 - 1s - loss: 4.9268e-04 - mae: 0.0173 - val_loss: 0.0142 - val_mae: 0.0878
#
# Epoch 00095: val_mae did not improve from 0.05536
# Epoch 96/1000
# 47/47 - 1s - loss: 4.4624e-04 - mae: 0.0165 - val_loss: 0.0144 - val_mae: 0.0888
#
# Epoch 00096: val_mae did not improve from 0.05536
# Epoch 97/1000
# 47/47 - 1s - loss: 4.3138e-04 - mae: 0.0162 - val_loss: 0.0150 - val_mae: 0.0903
#
# Epoch 00097: val_mae did not improve from 0.05536
# Epoch 98/1000
# 47/47 - 1s - loss: 5.5421e-04 - mae: 0.0185 - val_loss: 0.0146 - val_mae: 0.0895
#
# Epoch 00098: val_mae did not improve from 0.05536
# Epoch 99/1000
# 47/47 - 1s - loss: 4.4864e-04 - mae: 0.0165 - val_loss: 0.0142 - val_mae: 0.0876
#
# Epoch 00099: val_mae did not improve from 0.05536
# Epoch 100/1000
# 47/47 - 1s - loss: 4.5842e-04 - mae: 0.0167 - val_loss: 0.0143 - val_mae: 0.0879
#
# Epoch 00100: val_mae did not improve from 0.05536
# Epoch 101/1000
# 47/47 - 1s - loss: 4.5513e-04 - mae: 0.0167 - val_loss: 0.0142 - val_mae: 0.0877
#
# Epoch 00101: val_mae did not improve from 0.05536
# Epoch 102/1000
# 47/47 - 1s - loss: 4.3115e-04 - mae: 0.0162 - val_loss: 0.0145 - val_mae: 0.0887
#
# Epoch 00102: val_mae did not improve from 0.05536
# Epoch 103/1000
# 47/47 - 1s - loss: 4.5842e-04 - mae: 0.0167 - val_loss: 0.0141 - val_mae: 0.0875
#
# Epoch 00103: val_mae did not improve from 0.05536
# Epoch 104/1000
# 47/47 - 1s - loss: 4.9310e-04 - mae: 0.0174 - val_loss: 0.0148 - val_mae: 0.0899
#
# Epoch 00104: val_mae did not improve from 0.05536
# Epoch 105/1000
# 47/47 - 1s - loss: 3.9661e-04 - mae: 0.0155 - val_loss: 0.0149 - val_mae: 0.0902
#
# Epoch 00105: val_mae did not improve from 0.05536
# Epoch 106/1000
# 47/47 - 1s - loss: 3.7072e-04 - mae: 0.0150 - val_loss: 0.0146 - val_mae: 0.0891
#
# Epoch 00106: val_mae did not improve from 0.05536
# Epoch 107/1000
# 47/47 - 1s - loss: 4.1516e-04 - mae: 0.0159 - val_loss: 0.0158 - val_mae: 0.0933
#
# Epoch 00107: val_mae did not improve from 0.05536
# Epoch 108/1000
# 47/47 - 1s - loss: 4.8548e-04 - mae: 0.0173 - val_loss: 0.0152 - val_mae: 0.0910
#
# Epoch 00108: val_mae did not improve from 0.05536
# Epoch 109/1000
# 47/47 - 1s - loss: 4.0772e-04 - mae: 0.0157 - val_loss: 0.0157 - val_mae: 0.0930
#
# Epoch 00109: val_mae did not improve from 0.05536
# Epoch 110/1000
# 47/47 - 1s - loss: 3.9649e-04 - mae: 0.0155 - val_loss: 0.0150 - val_mae: 0.0906
#
# Epoch 00110: val_mae did not improve from 0.05536
# Epoch 111/1000
# 47/47 - 1s - loss: 4.2757e-04 - mae: 0.0162 - val_loss: 0.0145 - val_mae: 0.0886
#
# Epoch 00111: val_mae did not improve from 0.05536
# Epoch 112/1000
# 47/47 - 1s - loss: 4.0385e-04 - mae: 0.0157 - val_loss: 0.0151 - val_mae: 0.0908
#
# Epoch 00112: val_mae did not improve from 0.05536
# Epoch 113/1000
# 47/47 - 1s - loss: 4.2079e-04 - mae: 0.0160 - val_loss: 0.0146 - val_mae: 0.0892
#
# Epoch 00113: val_mae did not improve from 0.05536
# Epoch 00113: early stopping
